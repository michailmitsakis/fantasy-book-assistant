# %% [markdown]
# # Ingestion pipeline

# %%
import pandas as pd

# Load raw LLM-generated data after much cleaning
df = pd.read_json("data/data.json")

# %%
print(df.columns)
# Out:
# Index(['id', 'book_name', 'author_name', 'series_name', 'series_position',
#        'subgenres', 'themes', 'summary', 'page_count', 'publication_year',
#        'publisher', 'target_audience', 'pacing', 'tone', 'writing_style',
#        'setting_type', 'technology_focus', 'content_warnings'],
#       dtype='object')

# %%
df
# Out:
#       id                  book_name        author_name  \
# 0      0                       Dune      Frank Herbert
# 1      1                Neuromancer     William Gibson
# 2      2  The Left Hand of Darkness  Ursula K. Le Guin
# 3      3                 Foundation       Isaac Asimov
# 4      4                 The Hobbit     J.R.R. Tolkien
# ..   ...                        ...                ...
# 187  187            The Bonehunters     Steven Erikson
# 188  188              Reaper’s Gale     Steven Erikson
# 189  189            Toll the Hounds     Steven Erikson
# 190  190             Dust of Dreams     Steven Erikson
# 191  191           The Crippled God     Steven Erikson
#
#                     series_name  series_position  \
# 0               Dune Chronicles                1
# 1                Sprawl Trilogy                1
# 2                 Hainish Cycle                4
# 3             Foundation Series                1
# 4                  Middle-earth                0
# ..                          ...              ...
# 187  Malazan Book of the Fallen                6
# 188  Malazan Book of the Fallen                7
# 189  Malazan Book of the Fallen                8
# 190  Malazan Book of the Fallen                9
# 191  Malazan Book of the Fallen               10
#
#                              subgenres  \
# 0            Space Opera; Political SF
# 1                            Cyberpunk
# 2              Social SF; Planetary SF
# 3               Social SF; Space Opera
# 4              High Fantasy; Adventure
# ..                                 ...
# 187     Epic fantasy; Military fantasy
# 188  Epic fantasy; Cataclysmic fantasy
# 189         Epic fantasy; Dark fantasy
# 190      Epic fantasy; Endgame fantasy
# 191  Epic fantasy; Apocalyptic fantasy
#
#                                                 themes  \
# 0    Ecology; Religion; Politics; Resource Control;...
# 1    Artificial Intelligence; Corporate Control; Vi...
# 2    Gender; Politics; Cultural Difference; Loyalty...
# 3    Psychohistory; Empire; Civilization; Knowledge...
# 4     Heroism; Greed; Home; Adventure; Personal Growth
# ..                                                 ...
# 187                Survival; Betrayal; Duty; Endurance
# 188        Collapse; Rebirth; Sacrifice; Cosmic stakes
# 189                   Memory; Regret; Fate; Redemption
# 190        Perseverance; Fate; Transition; Consequence
# 191              Fulfillment; Sacrifice; Fate; Renewal
#
#                                                summary  page_count  \
# 0    On the desert planet Arrakis, control over the...         608
# 1    A washed-out hacker is drawn into a dangerous ...         271
# 2    An envoy to the icy world of Winter must navig...         336
# 3    As a galactic empire declines, a Foundation is...         255
# 4    Bilbo Baggins sets out on a quest with dwarves...         310
# ..                                                 ...         ...
# 187  The Malazan armies push deeper into enemy terr...        1232
# 188  As gods, armies, and ancient machinations conv...        1280
# 189  Amid political and spiritual upheavals in Daru...        1296
# 190  As the Malazan forces march eastward through t...        1280
# 191  The final battle of the Malazan saga unfolds. ...         944
#
#      publication_year              publisher               target_audience  \
# 0                1965          Chilton Books                         Adult
# 1                1984              Ace Books                         Adult
# 2                1969              Ace Books                         Adult
# 3                1951            Gnome Press                         Adult
# 4                1937   George Allen & Unwin            Young Adult; Adult
# ..                ...                    ...                           ...
# 187              2006  Bantam (UK); Tor (US)  Adult / epic fantasy readers
# 188              2007  Bantam (UK); Tor (US)  Adult / epic fantasy readers
# 189              2008  Bantam (UK); Tor (US)  Adult / epic fantasy readers
# 190              2010  Bantam (UK); Tor (US)  Adult / epic fantasy readers
# 191              2011  Bantam (UK); Tor (US)  Adult / epic fantasy readers
#
#                                   pacing  \
# 0            Slow-burn; Character-driven
# 1              Fast-paced; Action-driven
# 2            Slow-burn; Character-driven
# 3                  Moderate; Idea-driven
# 4             Moderate; Adventure-driven
# ..                                   ...
# 187             Moderate; tension rising
# 188  Moderate to fast; multiple climaxes
# 189               Moderate; deep tension
# 190   Moderate; heavy with foreshadowing
# 191           Fast; climactic resolution
#
#                                         tone  \
# 0             Philosophical; Epic; Political
# 1                         Dark; Gritty; Noir
# 2    Philosophical; Contemplative; Political
# 3             Intellectual; Epic; Optimistic
# 4              Whimsical; Adventurous; Light
# ..                                       ...
# 187           Dark; Gritty; Heroic undertone
# 188                    Epic; Tense; Dramatic
# 189                 Somber; Reflective; Dark
# 190                Ominous; Reflective; Grim
# 191                Epic; Emotional; Resolute
#
#                                 writing_style  \
# 0           Dense; Descriptive; Multi-layered
# 1                  Dense; Technical; Stylized
# 2           Literary; Descriptive; Thoughtful
# 3      Clear; Dialogue-heavy; Concept-focused
# 4    Accessible; Descriptive; Fairy-tale-like
# ..                                        ...
# 187               Third-person; expansive POV
# 188                 Third-person multiple POV
# 189                 Third-person multiple POV
# 190                 Third-person multiple POV
# 191                 Third-person multiple POV
#
#                                       setting_type  \
# 0               Desert planet; Feudal space empire
# 1                    Near-future Earth; Cyberspace
# 2                     Ice planet; Feudal societies
# 3                 Galactic empire; Multiple worlds
# 4                      Middle-earth; Fantasy world
# ..                                             ...
# 187  Battlefields, cities, warrens, besieged zones
# 188             Continents, warrens, divine realms
# 189                    City, warrens, mythic zones
# 190         Wastelands, borderlands, rising menace
# 191        All major battlefronts, realms, warrens
#
#                                       technology_focus  \
# 0             Mentats; Spice-based space travel; No AI
# 1    AI; Cyberspace; Neural interfaces; Body modifi...
# 2            Minimal technology; Ansible communication
# 3            Atomic power; Space travel; Psychohistory
# 4                          Pre-industrial; Magic items
# ..                                                 ...
# 187               Magic; divine interference; war tech
# 188                   Magic; divine-mortal interaction
# 189                           Magic; prophecy; warrens
# 190                   Magic; ancient weapons; prophecy
# 191              Magic; divine forces; endgame systems
#
#                       content_warnings
# 0         Violence; Political intrigue
# 1    Violence; Drug use; Mature themes
# 2                   Political intrigue
# 3                                 None
# 4                     Fantasy violence
# ..                                 ...
# 187           Violence; Death; Disease
# 188      Violence; Death; Cosmic peril
# 189          Violence; Vengeance; Loss
# 190           Violence; Death; Despair
# 191  Violence; Death; Epic destruction
#
# [192 rows x 18 columns]

# %%
# Check for NaN values:
text_fields = [
    "book_name","author_name","series_name","subgenres","themes","summary",
    "publisher","target_audience","pacing","tone","writing_style",
    "setting_type","technology_focus","content_warnings"
]

print(df[text_fields].isna().sum().sort_values(ascending=False))
# Out:
# book_name           0
# author_name         0
# series_name         0
# subgenres           0
# themes              0
# summary             0
# publisher           0
# target_audience     0
# pacing              0
# tone                0
# writing_style       0
# setting_type        0
# technology_focus    0
# content_warnings    0
# dtype: int64

# %%
documents = df.to_dict(orient="records")

# %%
import minsearch

# Create and fit the index with enriched metadata fields
index = minsearch.Index(
    text_fields=[
        'book_name',
        'author_name',
        'series_name',
        'subgenres',
        'themes',
        'summary',
        'publisher',
        'target_audience',
        'pacing',
        'tone',
        'writing_style',
        'setting_type',
        'technology_focus',
        'content_warnings'
    ],
    keyword_fields=[
        'id',
        'series_position',
        'page_count',
        'publication_year'
    ]
)

index.fit(documents)

# %%
query = "Which books are written by Robert Jordan?"
results = index.search(query, num_results=5)

# %%
results
# Out:
# [{'id': 93,
#   'book_name': 'The Eye of the World',
#   'author_name': 'Robert Jordan',
#   'series_name': 'The Wheel of Time',
#   'series_position': 1,
#   'subgenres': 'High fantasy; Epic fantasy',
#   'themes': 'Prophecy; Coming of age; Light vs Shadow; Fellowship',
#   'summary': 'Villagers are driven from their home by dark forces and join Moiraine and Lan on a journey that reveals a prophesied hero and a world-spanning conflict.',
#   'page_count': 782,
#   'publication_year': 1990,
#   'publisher': 'Tor Books (US); Orbit (UK)',
#   'target_audience': 'Adult / epic fantasy readers',
#   'pacing': 'Moderate; quest-driven with dense worldbuilding',
#   'tone': 'Mythic; Adventurous; Foreboding',
#   'writing_style': 'Third-person limited; multiple POVs',
#   'setting_type': 'Broad secondary world across nations and wilds',
#   'technology_focus': 'The One Power; Artifacts; Ancient lore',
#   'content_warnings': 'Fantasy violence; Dark magic; Monsters'},
#  {'id': 103,
#   'book_name': 'Knife of Dreams',
#   'author_name': 'Robert Jordan',
#   'series_name': 'The Wheel of Time',
#   'series_position': 11,
#   'subgenres': 'High fantasy; Epic fantasy',
#   'themes': 'Resolution; Reckoning; Gathering storm',
#   'summary': 'Long-running plotlines snap into action as key enemies are confronted and momentum toward the Last Battle accelerates.',
#   'page_count': 784,
#   'publication_year': 2005,
#   'publisher': 'Tor Books (US); Orbit (UK)',
#   'target_audience': 'Adult / epic fantasy readers',
#   'pacing': 'Faster; event-dense',
#   'tone': 'Urgent; Triumphant; Dark undertow',
#   'writing_style': 'Third-person limited; ensemble POV',
#   'setting_type': 'Across nations and battlefields',
#   'technology_focus': 'Battle weaves; Wolfbrother abilities; Dreamwalking',
#   'content_warnings': 'Warfare; Torture; Dark magic'},
#  {'id': 96,
#   'book_name': 'The Shadow Rising',
#   'author_name': 'Robert Jordan',
#   'series_name': 'The Wheel of Time',
#   'series_position': 4,
#   'subgenres': 'High fantasy; Epic fantasy',
#   'themes': 'Heritage; Culture clash; Fate; Power',
#   'summary': 'The party divides: to Tanchico, the Two Rivers, and the Aiel Waste, where deep history and prophecy reshape the war against the Shadow.',
#   'page_count': 704,
#   'publication_year': 1992,
#   'publisher': 'Tor Books (US)',
#   'target_audience': 'Adult / epic fantasy readers',
#   'pacing': 'Moderate to slow; layered worldbuilding',
#   'tone': 'Expansive; Reflective; Tense',
#   'writing_style': 'Third-person limited; broad ensemble',
#   'setting_type': 'Aiel Waste, Two Rivers, Tanchico and beyond',
#   'technology_focus': 'The One Power; Ter’angreal; Rhuidean visions',
#   'content_warnings': 'War; Oppression; Supernatural peril'},
#  {'id': 95,
#   'book_name': 'The Dragon Reborn',
#   'author_name': 'Robert Jordan',
#   'series_name': 'The Wheel of Time',
#   'series_position': 3,
#   'subgenres': 'High fantasy; Epic fantasy',
#   'themes': 'Burden of destiny; Trust; Control of power',
#   'summary': 'As signs of the Dragon multiply, allies and enemies maneuver while Rand’s path leads to Tear and Callandor.',
#   'page_count': 624,
#   'publication_year': 1991,
#   'publisher': 'Tor Books (US); Orbit (UK)',
#   'target_audience': 'Adult / epic fantasy readers',
#   'pacing': 'Moderate; parallel chases and intrigues',
#   'tone': 'Ominous; Determined; Heroic',
#   'writing_style': 'Third-person limited; rotating POVs',
#   'setting_type': 'Roads, White Tower politics, city-states',
#   'technology_focus': 'The One Power; Dreaming; Callandor',
#   'content_warnings': 'Violence; Mind control; Dark magic'},
#  {'id': 94,
#   'book_name': 'The Great Hunt',
#   'author_name': 'Robert Jordan',
#   'series_name': 'The Wheel of Time',
#   'series_position': 2,
#   'subgenres': 'High fantasy; Epic quest',
#   'themes': 'Duty; Temptation; Identity; Politics',
#   'summary': 'A race to recover the Horn of Valere splits the heroes while the world’s powers and invading forces close in.',
#   'page_count': 600,
#   'publication_year': 1990,
#   'publisher': 'Tor Books (US); Orbit (UK)',
#   'target_audience': 'Adult / epic fantasy readers',
#   'pacing': 'Moderate; alternating pursuit lines',
#   'tone': 'Heroic; Tense; Expansive',
#   'writing_style': 'Third-person limited; ensemble POV',
#   'setting_type': 'Cities, borderlands, and seaways of the Westlands',
#   'technology_focus': 'The One Power; Ter’angreal; Portal Stones',
#   'content_warnings': 'Fantasy warfare; Possession; Torture'}]

# %% [markdown]
# # Retrieval (RAG) Flow

# %%
def search(query):
    boost = {}

    results = index.search(
        query=query,
        filter_dict={},
        boost_dict=boost,
        num_results=10
    )

    return results

# %%
prompt_template = """
You are an assistant for helping people decide on which fantasy and sci-fi books to read. Answer the QUESTION based on the CONTEXT from the FAQ database.
Use only the facts from the CONTEXT when answering the QUESTION.

QUESTION: {question}

CONTEXT: {context}
""".strip()
    
entry_template = """
book_name: {book_name}
author_name: {author_name}
series_name: {series_name}
subgenres: {subgenres}
themes: {themes}
summary: {summary}
publisher: {publisher}
target_audience: {target_audience}
pacing: {pacing}
tone: {tone}
writing_style: {writing_style}
setting_type: {setting_type}
technology_focus: {technology_focus}
content_warnings: {content_warnings}
"""


def build_prompt(query, search_results):
    context = ""
    
    for doc in search_results:
        context = context + entry_template.format(**doc) + "\n\n"
    
    prompt = prompt_template.format(question=query, context=context).strip()
    return prompt

# %%
def llm(prompt):
    from ollama import chat
    from ollama import ChatResponse

    response: ChatResponse = chat(
        
        model='llama3.2:latest', 
        messages=[ {'role': 'user','content': prompt}]
        )
    
    return response.message.content

# %%
query = 'What is the release order of Steven Erikson books? Include all 10 books written by the author.'

def rag(query):
    search_results = search(query)
    prompt = build_prompt(query, search_results)
    answer = llm(prompt)
    return answer

# %%
answer = rag(query)
print(answer)
# Out:
# Based on the provided context, here is the release order of Steven Erikson's books in the Malazan Book of the Fallen series:
#
# 1. Gardens of the Moon (1999)
# 2. Deadhouse Gates (not listed in the provided context, but released in 2000)
# 3. Memories of Ice (2001)
# 4. House of Chains (2002)
# 5. Midnight Tides (2004)
# 6. The Bonehunters (2006)
# 7. Reaper's Gale (2007)
# 8. Toll the Hounds (2008)
# 9. Dust of Dreams (2010)
# 10. The Crippled God (2010)
#
# Note: This list only includes the main books in the series and does not include any companion novels, short stories, or other works by Steven Erikson.

# %% [markdown]
# # Retrieval evaluation

# %% [markdown]
# ## Data generation

# %%
import pandas as pd
df = pd.read_json('data/data.json')
documents = df.to_dict(orient='records')

# %%
documents
# Out:
# [{'id': 0,
#   'book_name': 'Dune',
#   'author_name': 'Frank Herbert',
#   'series_name': 'Dune Chronicles',
#   'series_position': 1,
#   'subgenres': 'Space Opera; Political SF',
#   'themes': 'Ecology; Religion; Politics; Resource Control; Prophecy',
#   'summary': 'On the desert planet Arrakis, control over the spice melange triggers a clash of prophecy, politics, and power.',
#   'page_count': 608,
#   'publication_year': 1965,
#   'publisher': 'Chilton Books',
#   'target_audience': 'Adult',
#   'pacing': 'Slow-burn; Character-driven',
#   'tone': 'Philosophical; Epic; Political',
#   'writing_style': 'Dense; Descriptive; Multi-layered',
#   'setting_type': 'Desert planet; Feudal space empire',
#   'technology_focus': 'Mentats; Spice-based space travel; No AI',
#   'content_warnings': 'Violence; Political intrigue'},
#  {'id': 1,
#   'book_name': 'Neuromancer',
#   'author_name': 'William Gibson',
#   'series_name': 'Sprawl Trilogy',
#   'series_position': 1,
#   'subgenres': 'Cyberpunk',
#   'themes': 'Artificial Intelligence; Corporate Control; Virtual Reality; Identity; Technology',
#   'summary': 'A washed-out hacker is drawn into a dangerous AI heist across cyberspace and corporate intrigue.',
#   'page_count': 271,
#   'publication_year': 1984,
#   'publisher': 'Ace Books',
#   'target_audience': 'Adult',
#   'pacing': 'Fast-paced; Action-driven',
#   'tone': 'Dark; Gritty; Noir',
#   'writing_style': 'Dense; Technical; Stylized',
#   'setting_type': 'Near-future Earth; Cyberspace',
#   'technology_focus': 'AI; Cyberspace; Neural interfaces; Body modification',
#   'content_warnings': 'Violence; Drug use; Mature themes'},
#  {'id': 2,
#   'book_name': 'The Left Hand of Darkness',
#   'author_name': 'Ursula K. Le Guin',
#   'series_name': 'Hainish Cycle',
#   'series_position': 4,
#   'subgenres': 'Social SF; Planetary SF',
#   'themes': 'Gender; Politics; Cultural Difference; Loyalty; Identity',
#   'summary': 'An envoy to the icy world of Winter must navigate a culture without fixed gender amid political tension.',
#   'page_count': 336,
#   'publication_year': 1969,
#   'publisher': 'Ace Books',
#   'target_audience': 'Adult',
#   'pacing': 'Slow-burn; Character-driven',
#   'tone': 'Philosophical; Contemplative; Political',
#   'writing_style': 'Literary; Descriptive; Thoughtful',
#   'setting_type': 'Ice planet; Feudal societies',
#   'technology_focus': 'Minimal technology; Ansible communication',
#   'content_warnings': 'Political intrigue'},
#  {'id': 3,
#   'book_name': 'Foundation',
#   'author_name': 'Isaac Asimov',
#   'series_name': 'Foundation Series',
#   'series_position': 1,
#   'subgenres': 'Social SF; Space Opera',
#   'themes': 'Psychohistory; Empire; Civilization; Knowledge Preservation; Prediction',
#   'summary': "As a galactic empire declines, a Foundation is created to preserve knowledge and guide humanity's future.",
#   'page_count': 255,
#   'publication_year': 1951,
#   'publisher': 'Gnome Press',
#   'target_audience': 'Adult',
#   'pacing': 'Moderate; Idea-driven',
#   'tone': 'Intellectual; Epic; Optimistic',
#   'writing_style': 'Clear; Dialogue-heavy; Concept-focused',
#   'setting_type': 'Galactic empire; Multiple worlds',
#   'technology_focus': 'Atomic power; Space travel; Psychohistory',
#   'content_warnings': 'None'},
#  {'id': 4,
#   'book_name': 'The Hobbit',
#   'author_name': 'J.R.R. Tolkien',
#   'series_name': 'Middle-earth',
#   'series_position': 0,
#   'subgenres': 'High Fantasy; Adventure',
#   'themes': 'Heroism; Greed; Home; Adventure; Personal Growth',
#   'summary': 'Bilbo Baggins sets out on a quest with dwarves and a wizard to reclaim treasure from a dragon.',
#   'page_count': 310,
#   'publication_year': 1937,
#   'publisher': 'George Allen & Unwin',
#   'target_audience': 'Young Adult; Adult',
#   'pacing': 'Moderate; Adventure-driven',
#   'tone': 'Whimsical; Adventurous; Light',
#   'writing_style': 'Accessible; Descriptive; Fairy-tale-like',
#   'setting_type': 'Middle-earth; Fantasy world',
#   'technology_focus': 'Pre-industrial; Magic items',
#   'content_warnings': 'Fantasy violence'},
#  {'id': 5,
#   'book_name': 'A Game of Thrones',
#   'author_name': 'George R. R. Martin',
#   'series_name': 'A Song of Ice and Fire',
#   'series_position': 1,
#   'subgenres': 'Epic Fantasy; Political Fantasy',
#   'themes': 'Power; Politics; War; Family; Honor; Betrayal',
#   'summary': 'Noble families vie for control of the Iron Throne while an ancient evil awakens in the frozen North.',
#   'page_count': 694,
#   'publication_year': 1996,
#   'publisher': 'Bantam Books',
#   'target_audience': 'Adult',
#   'pacing': 'Moderate; Character and plot-driven',
#   'tone': 'Dark; Gritty; Morally ambiguous',
#   'writing_style': 'Detailed; Descriptive; Multi-perspective',
#   'setting_type': 'Medieval-inspired fantasy world',
#   'technology_focus': 'Medieval technology; Minimal magic',
#   'content_warnings': 'Violence; Sexual content; Mature themes'},
#  {'id': 6,
#   'book_name': 'Mistborn: The Final Empire',
#   'author_name': 'Brandon Sanderson',
#   'series_name': 'Mistborn Era 1',
#   'series_position': 1,
#   'subgenres': 'Epic Fantasy; Heist Fantasy',
#   'themes': 'Revolution; Power; Trust; Faith; Sacrifice',
#   'summary': 'A street urchin with magical powers joins a crew planning to overthrow an immortal emperor.',
#   'page_count': 541,
#   'publication_year': 2006,
#   'publisher': 'Tor Books',
#   'target_audience': 'Young Adult; Adult',
#   'pacing': 'Fast-paced; Action-driven',
#   'tone': 'Dark; Hopeful; Action-packed',
#   'writing_style': 'Accessible; Clear; Action-focused',
#   'setting_type': 'Dark dystopian empire; Ash-covered world',
#   'technology_focus': 'Hard magic system (Allomancy); Industrial age',
#   'content_warnings': 'Violence; Oppression themes'},
#  {'id': 7,
#   'book_name': 'The Way of Kings',
#   'author_name': 'Brandon Sanderson',
#   'series_name': 'The Stormlight Archive',
#   'series_position': 1,
#   'subgenres': 'Epic Fantasy',
#   'themes': 'Honor; Leadership; Depression; War; Redemption',
#   'summary': 'Three individuals navigate war and personal struggles in a storm-ravaged world of ancient mysteries.',
#   'page_count': 1007,
#   'publication_year': 2010,
#   'publisher': 'Tor Books',
#   'target_audience': 'Adult',
#   'pacing': 'Slow-burn; Character-driven',
#   'tone': 'Epic; Hopeful; Complex',
#   'writing_style': 'Detailed; Descriptive; World-building heavy',
#   'setting_type': 'Storm-swept world; Medieval fantasy',
#   'technology_focus': 'Hard magic system (Surgebinding); Shardblades',
#   'content_warnings': 'Violence; Slavery; Mental health themes'},
#  {'id': 8,
#   'book_name': 'The Fifth Season',
#   'author_name': 'N. K. Jemisin',
#   'series_name': 'The Broken Earth',
#   'series_position': 1,
#   'subgenres': 'Apocalyptic Fantasy; Science Fantasy',
#   'themes': 'Oppression; Survival; Motherhood; Prejudice; Environmental Catastrophe',
#   'summary': 'In a catastrophe-ravaged world, a woman searches for her daughter while civilization collapses.',
#   'page_count': 468,
#   'publication_year': 2015,
#   'publisher': 'Orbit Books',
#   'target_audience': 'Adult',
#   'pacing': 'Moderate; Character-driven',
#   'tone': 'Dark; Intense; Emotional',
#   'writing_style': 'Literary; Innovative; Second-person narrative',
#   'setting_type': 'Post-apocalyptic supercontinent; Geologically active',
#   'technology_focus': 'Orogeny (earth magic); Post-tech civilization',
#   'content_warnings': 'Violence; Child death; Oppression'},
#  {'id': 9,
#   'book_name': "Ender's Game",
#   'author_name': 'Orson Scott Card',
#   'series_name': 'Ender Saga',
#   'series_position': 1,
#   'subgenres': 'Military SF; Young Adult SF',
#   'themes': 'War; Childhood; Strategy; Morality; Leadership',
#   'summary': 'A brilliant child is trained in military tactics to defend humanity against an alien threat.',
#   'page_count': 324,
#   'publication_year': 1985,
#   'publisher': 'Tor Books',
#   'target_audience': 'Young Adult; Adult',
#   'pacing': 'Fast-paced; Plot-driven',
#   'tone': 'Thoughtful; Intense; Moral complexity',
#   'writing_style': 'Accessible; Clear; Engaging',
#   'setting_type': 'Space stations; Future Earth',
#   'technology_focus': 'Space warfare; Zero-gravity combat; Ansible',
#   'content_warnings': 'Violence; Bullying; Child soldiers'},
#  {'id': 10,
#   'book_name': 'Hyperion',
#   'author_name': 'Dan Simmons',
#   'series_name': 'Hyperion Cantos',
#   'series_position': 1,
#   'subgenres': 'Space Opera; Literary SF',
#   'themes': 'Time; Religion; Pilgrimage; Technology; Humanity',
#   'summary': 'Seven pilgrims travel to the Time Tombs, each telling their tale while seeking the mysterious Shrike.',
#   'page_count': 482,
#   'publication_year': 1989,
#   'publisher': 'Doubleday',
#   'target_audience': 'Adult',
#   'pacing': 'Moderate; Character-driven',
#   'tone': 'Literary; Complex; Varied',
#   'writing_style': 'Literary; Dense; Multi-genre',
#   'setting_type': 'Far-future galaxy; Multiple worlds',
#   'technology_focus': 'AI; Time manipulation; Farcasters; Resurrection',
#   'content_warnings': 'Violence; Disturbing imagery'},
#  {'id': 11,
#   'book_name': 'Leviathan Wakes',
#   'author_name': 'James S. A. Corey',
#   'series_name': 'The Expanse',
#   'series_position': 1,
#   'subgenres': 'Space Opera; Hard SF',
#   'themes': 'Class Conflict; Survival; Politics; Conspiracy; Humanity',
#   'summary': 'A detective and a ship captain uncover a conspiracy that threatens the fragile peace in the solar system.',
#   'page_count': 561,
#   'publication_year': 2011,
#   'publisher': 'Orbit Books',
#   'target_audience': 'Adult',
#   'pacing': 'Fast-paced; Action-driven',
#   'tone': 'Gritty; Noir; Action-packed',
#   'writing_style': 'Accessible; Cinematic; Fast-paced',
#   'setting_type': 'Solar system colonization; Space stations',
#   'technology_focus': 'Realistic space travel; Epstein Drive; Protomolecule',
#   'content_warnings': 'Violence; Gore; Language'},
#  {'id': 12,
#   'book_name': 'The Obelisk Gate',
#   'author_name': 'N. K. Jemisin',
#   'series_name': 'The Broken Earth',
#   'series_position': 2,
#   'subgenres': 'Apocalyptic Fantasy; Science Fantasy',
#   'themes': 'Survival; Family; Power; Oppression; Transformation',
#   'summary': 'As the world ends, orogenes must decide whether to save humanity or let it perish.',
#   'page_count': 410,
#   'publication_year': 2016,
#   'publisher': 'Orbit Books',
#   'target_audience': 'Adult',
#   'pacing': 'Moderate; Character-driven',
#   'tone': 'Dark; Intense; Emotional',
#   'writing_style': 'Literary; Innovative; Multi-perspective',
#   'setting_type': 'Post-apocalyptic supercontinent; Underground refuges',
#   'technology_focus': 'Orogeny; Ancient obelisks; Moon manipulation',
#   'content_warnings': 'Violence; Oppression; Child endangerment'},
#  {'id': 13,
#   'book_name': 'The Stone Sky',
#   'author_name': 'N. K. Jemisin',
#   'series_name': 'The Broken Earth',
#   'series_position': 3,
#   'subgenres': 'Apocalyptic Fantasy; Science Fantasy',
#   'themes': 'Redemption; Family; Cycles; Power; Transformation',
#   'summary': 'The final confrontation approaches as mother and daughter hold the fate of the world in their hands.',
#   'page_count': 398,
#   'publication_year': 2017,
#   'publisher': 'Orbit Books',
#   'target_audience': 'Adult',
#   'pacing': 'Fast-paced; Resolution-focused',
#   'tone': 'Epic; Emotional; Hopeful',
#   'writing_style': 'Literary; Powerful; Conclusive',
#   'setting_type': 'Post-apocalyptic world; The Moon',
#   'technology_focus': 'Advanced orogeny; Moon technology; Ancient civilizations',
#   'content_warnings': 'Violence; Oppression themes'},
#  {'id': 14,
#   'book_name': 'Children of Time',
#   'author_name': 'Adrian Tchaikovsky',
#   'series_name': 'Children of Time',
#   'series_position': 1,
#   'subgenres': 'Hard SF; Evolutionary SF',
#   'themes': 'Evolution; Survival; Intelligence; Civilization; Species Conflict',
#   'summary': "Humanity's last survivors encounter an alien civilization born from an experiment gone wrong.",
#   'page_count': 600,
#   'publication_year': 2015,
#   'publisher': 'Tor Books',
#   'target_audience': 'Adult',
#   'pacing': 'Moderate; Idea-driven',
#   'tone': 'Thoughtful; Epic; Scientific',
#   'writing_style': 'Detailed; Scientific; Multi-perspective',
#   'setting_type': 'Terraformed planet; Generation ship',
#   'technology_focus': 'Terraforming; Genetic engineering; AI; Space travel',
#   'content_warnings': 'Violence between species'},
#  {'id': 15,
#   'book_name': 'Children of Ruin',
#   'author_name': 'Adrian Tchaikovsky',
#   'series_name': 'Children of Time',
#   'series_position': 2,
#   'subgenres': 'Hard SF; First Contact',
#   'themes': 'Communication; Intelligence; Cooperation; Alien Minds; Survival',
#   'summary': 'An alliance of species encounters a terrifying intelligence that challenges their understanding of consciousness.',
#   'page_count': 576,
#   'publication_year': 2019,
#   'publisher': 'Tor Books',
#   'target_audience': 'Adult',
#   'pacing': 'Moderate; Idea and plot-driven',
#   'tone': 'Thoughtful; Tense; Scientific',
#   'writing_style': 'Dense; Scientific; Multi-perspective',
#   'setting_type': 'Multiple terraformed worlds; Space',
#   'technology_focus': 'Terraforming; Genetic engineering; Alien biology',
#   'content_warnings': 'Body horror; Disturbing imagery'},
#  {'id': 16,
#   'book_name': 'The Forever War',
#   'author_name': 'Joe Haldeman',
#   'series_name': 'The Forever War',
#   'series_position': 1,
#   'subgenres': 'Military SF; Hard SF',
#   'themes': 'War; Time Dilation; Alienation; PTSD; Social Change',
#   'summary': 'A soldier fights an interstellar war across centuries due to relativistic time dilation.',
#   'page_count': 278,
#   'publication_year': 1974,
#   'publisher': "St. Martin's Press",
#   'target_audience': 'Adult',
#   'pacing': 'Fast-paced; Action-driven',
#   'tone': 'Dark; Anti-war; Reflective',
#   'writing_style': 'Clear; Direct; Military prose',
#   'setting_type': 'Multiple planets; Space warfare',
#   'technology_focus': 'Relativity; Space combat; Collapsar jumps',
#   'content_warnings': 'War violence; Sexual content'},
#  {'id': 17,
#   'book_name': "Old Man's War",
#   'author_name': 'John Scalzi',
#   'series_name': "Old Man's War",
#   'series_position': 1,
#   'subgenres': 'Military SF; Space Opera',
#   'themes': 'War; Aging; Second Chances; Morality; Humanity',
#   'summary': 'Senior citizens are recruited to fight aliens in exchange for youth and a new body.',
#   'page_count': 320,
#   'publication_year': 2005,
#   'publisher': 'Tor Books',
#   'target_audience': 'Adult',
#   'pacing': 'Fast-paced; Action-driven',
#   'tone': 'Humorous; Action-packed; Thoughtful',
#   'writing_style': 'Accessible; Witty; Engaging',
#   'setting_type': 'Multiple alien worlds; Space',
#   'technology_focus': 'Genetic enhancement; BrainPal; Space warfare',
#   'content_warnings': 'War violence; Gore'},
#  {'id': 18,
#   'book_name': 'Red Mars',
#   'author_name': 'Kim Stanley Robinson',
#   'series_name': 'Mars Trilogy',
#   'series_position': 1,
#   'subgenres': 'Hard SF; Colonization SF',
#   'themes': 'Colonization; Terraforming; Politics; Science; Environmentalism',
#   'summary': 'The first hundred colonists struggle to terraform Mars while facing political and ideological conflicts.',
#   'page_count': 572,
#   'publication_year': 1992,
#   'publisher': 'Bantam Books',
#   'target_audience': 'Adult',
#   'pacing': 'Slow-burn; Idea-driven',
#   'tone': 'Scientific; Political; Detailed',
#   'writing_style': 'Dense; Technical; Descriptive',
#   'setting_type': 'Mars colonization',
#   'technology_focus': 'Terraforming; Hard science; Longevity treatments',
#   'content_warnings': 'Political violence'},
#  {'id': 19,
#   'book_name': 'Green Mars',
#   'author_name': 'Kim Stanley Robinson',
#   'series_name': 'Mars Trilogy',
#   'series_position': 2,
#   'subgenres': 'Hard SF; Colonization SF',
#   'themes': 'Terraforming; Revolution; Politics; Ecology; Utopia',
#   'summary': 'As Mars transforms, colonists must decide between preserving the planet or reshaping it for humanity.',
#   'page_count': 640,
#   'publication_year': 1993,
#   'publisher': 'Bantam Books',
#   'target_audience': 'Adult',
#   'pacing': 'Slow-burn; Idea-driven',
#   'tone': 'Scientific; Political; Hopeful',
#   'writing_style': 'Dense; Technical; World-building heavy',
#   'setting_type': 'Partially terraformed Mars',
#   'technology_focus': 'Advanced terraforming; Longevity; Ecology science',
#   'content_warnings': 'Political violence'},
#  {'id': 20,
#   'book_name': 'Blue Mars',
#   'author_name': 'Kim Stanley Robinson',
#   'series_name': 'Mars Trilogy',
#   'series_position': 3,
#   'subgenres': 'Hard SF; Terraforming SF; Sociopolitical SF',
#   'themes': 'Terraforming; Colonialism; Politics; Ecology; Longevity; Identity',
#   'summary': 'Mars is becoming increasingly habitable and politically mature, while Earth faces ecological crisis and immigration pressures. The colonists struggle with governance, migration disputes, and the transformation of both Mars and humanity.',
#   'page_count': 624,
#   'publication_year': 1996,
#   'publisher': 'Bantam Spectra',
#   'target_audience': 'Adult',
#   'pacing': 'Moderate to slow; idea-heavy',
#   'tone': 'Serious; Political; Hopeful with conflict',
#   'writing_style': 'Dense; Technical; Multi-strand worldbuilding',
#   'setting_type': 'Partially terraformed Mars with Earth interactions',
#   'technology_focus': 'Terraforming; Genetic engineering; Longevity; Ecology science',
#   'content_warnings': 'Political violence; Social turmoil; Environmental crisis'},
#  {'id': 21,
#   'book_name': 'Snow Crash',
#   'author_name': 'Neal Stephenson',
#   'series_name': 'N/A',
#   'series_position': 0,
#   'subgenres': 'Cyberpunk; Postcyberpunk; Techno-thriller SF',
#   'themes': 'Language & consciousness; Virtual reality; Information control; Corporate power; Myth',
#   'summary': 'In a near-future America dominated by corporate enclaves, hacker Hiro Protagonist uncovers “Snow Crash,” a linguistic/viral threat in the Metaverse. Together with Y.T., he delves into conspiracies linking ancient myth, technology, and the nature of mind.',
#   'page_count': 480,
#   'publication_year': 1992,
#   'publisher': 'Bantam Books',
#   'target_audience': 'Adult / SF readers',
#   'pacing': 'Fast; action-oriented with expository interludes',
#   'tone': 'Energetic; Satirical; Serious undertones',
#   'writing_style': 'Accessible but layered with technical digressions',
#   'setting_type': 'Near-future Earth + virtual Metaverse',
#   'technology_focus': 'VR / Metaverse; Linguistics; Cryptography; Networks',
#   'content_warnings': 'Violence; Drug use; Corporate dystopia'},
#  {'id': 22,
#   'book_name': 'Cryptonomicon',
#   'author_name': 'Neal Stephenson',
#   'series_name': 'N/A',
#   'series_position': 0,
#   'subgenres': 'Historical fiction; Techno-thriller; Speculative SF',
#   'themes': 'Cryptography; War; Finance; Information freedom; Legacy',
#   'summary': 'Parallel narratives in WWII and the late 1990s follow codebreakers and their descendants as they build a data haven. Conflicts arise about secrecy, power, and the enduring legacy of encryption.',
#   'page_count': 918,
#   'publication_year': 1999,
#   'publisher': 'Avon / HarperCollins',
#   'target_audience': 'Adult / Technophile readers',
#   'pacing': 'Varied: dense exposition with bursts of action',
#   'tone': 'Ambitious; Intellectual; Tense; Occasional humor',
#   'writing_style': 'Highly detailed; multiple narrative threads',
#   'setting_type': '20th century and late 20th century, global',
#   'technology_focus': 'Cryptography; Networking; Data infrastructure',
#   'content_warnings': 'War violence; Espionage; Ethical ambiguity'},
#  {'id': 23,
#   'book_name': 'The Three-Body Problem',
#   'author_name': 'Liu Cixin',
#   'series_name': 'Remembrance of Earth’s Past',
#   'series_position': 1,
#   'subgenres': 'Hard SF; First-contact SF; Astrophysical SF',
#   'themes': 'Alien contact; Science & belief; Civilizational risk; Sociology of science',
#   'summary': 'When Earth makes contact with an alien civilization in a chaotic orbital system, humanity becomes enmeshed in far-reaching consequences — exploring limits of rationality, cosmic danger, and diverse human reactions.',
#   'page_count': 400,
#   'publication_year': 2008,
#   'publisher': 'Chongqing Press; English translation by Tor Books',
#   'target_audience': 'Adult / SF readers',
#   'pacing': 'Moderate to fast',
#   'tone': 'Grand scale; Serious; Existential',
#   'writing_style': 'Expansive; Technical; Occasionally poetic',
#   'setting_type': 'Earth, outer space, alien systems',
#   'technology_focus': 'Physics; Astrophysics; Communication; Simulation',
#   'content_warnings': 'Existential threat; Political intrigue'},
#  {'id': 24,
#   'book_name': 'The Dark Forest',
#   'author_name': 'Liu Cixin',
#   'series_name': 'Remembrance of Earth’s Past',
#   'series_position': 2,
#   'subgenres': 'Hard SF; Galactic politics; First-contact SF',
#   'themes': 'Cosmic sociology; Survival; Deception; Trust vs suspicion',
#   'summary': "As the alien threat looms, humanity must craft survival strategies in a universe where silence may be essential. The 'dark forest' metaphor frames interstellar relationships as fraught with danger and preemptive logic.",
#   'page_count': 512,
#   'publication_year': 2008,
#   'publisher': 'Chongqing Press; English by Tor Books',
#   'target_audience': 'Adult / SF readers',
#   'pacing': 'Moderate; strategic pacing',
#   'tone': 'Tense; Foreboding; Intellectual',
#   'writing_style': 'Dense; Multi-layered',
#   'setting_type': 'Earth and interstellar space / communication',
#   'technology_focus': 'Advanced communication; Deception tech',
#   'content_warnings': 'War; Betrayal; Existential threat'},
#  {'id': 25,
#   'book_name': 'Death’s End',
#   'author_name': 'Liu Cixin',
#   'series_name': 'Remembrance of Earth’s Past',
#   'series_position': 3,
#   'subgenres': 'Hard SF; Cosmic-scale SF; First-contact SF',
#   'themes': 'Ultimate survival; Time and scale; Transcendence; Communication',
#   'summary': 'Humanity confronts cosmic stakes. Time, space, and dimensional frontiers become the arena of existential struggle. The fate of civilizations and paradoxes of action across cosmic distances unfold.',
#   'page_count': 784,
#   'publication_year': 2010,
#   'publisher': 'Chongqing Press; English by Tor Books',
#   'target_audience': 'Adult / SF readers',
#   'pacing': 'Varied — slow build with climactic peaks',
#   'tone': 'Grand; Philosophical; Bleak yet persistent hope',
#   'writing_style': 'Ambitious; High technical complexity',
#   'setting_type': 'Earth, space, cosmic realms',
#   'technology_focus': 'Cosmic engineering; Dimensional physics',
#   'content_warnings': 'Existential danger; Destruction; Cosmic horror'},
#  {'id': 26,
#   'book_name': 'Ringworld',
#   'author_name': 'Larry Niven',
#   'series_name': 'Ringworld / Known Space',
#   'series_position': 4,
#   'subgenres': 'Hard SF; Megastructure SF',
#   'themes': 'Exploration; Alien artifacts; Survival; Scale',
#   'summary': 'A massive artificial ring encircles a star. A crew is sent to survey it and confronts strange environments, dangers, and traces of ancient civilizations. The novel probes scale, engineering, and the unknown.',
#   'page_count': 342,
#   'publication_year': 1970,
#   'publisher': 'Ballantine Books',
#   'target_audience': 'Adult / SF fans',
#   'pacing': 'Moderate; mix of discovery and action',
#   'tone': 'Adventurous; Wonder; Caution about alien motives',
#   'writing_style': 'Clear; Technically minded; Exploratory',
#   'setting_type': 'Inside a megastructure + space',
#   'technology_focus': 'Megastructure engineering; Alien tech; Gravity manipulation',
#   'content_warnings': 'Violence; Strange biology'},
#  {'id': 27,
#   'book_name': 'The Mote in God’s Eye',
#   'author_name': 'Larry Niven & Jerry Pournelle',
#   'series_name': 'CoDominium universe',
#   'series_position': 0,
#   'subgenres': 'First-contact SF; Military SF; Hard SF',
#   'themes': 'Alien contact; Miscommunication; Political protocol; Risk of unknown',
#   'summary': 'Humans in an interstellar empire meet the Moties, a technically adept but troubled alien species. The encounter forces diplomatic, ethical, and existential decisions about contact and risk.',
#   'page_count': 496,
#   'publication_year': 1974,
#   'publisher': 'Simon & Schuster',
#   'target_audience': 'Adult / SF readers',
#   'pacing': 'Moderate; deliberative arcs with tension spikes',
#   'tone': 'Serious; Tense; Speculative',
#   'writing_style': 'Clear; Technical; Dialogue-heavy',
#   'setting_type': 'Interstellar systems; alien worlds',
#   'technology_focus': 'Interstellar travel; Alien biology; Communication tech',
#   'content_warnings': 'Violence; Unintended consequences'},
#  {'id': 28,
#   'book_name': 'Altered Carbon',
#   'author_name': 'Richard K. Morgan',
#   'series_name': 'Takeshi Kovacs',
#   'series_position': 1,
#   'subgenres': 'Cyberpunk; Noir SF; Transhumanist SF',
#   'themes': 'Identity; Consciousness; Mortality; Power; Technology and inequality',
#   'summary': 'In a future where human minds are digitized and stored, ex-soldier Takeshi Kovacs is reactivated to solve a rich man’s murder. He uncovers conspiracy, corruption, and existential questions of what makes us human.',
#   'page_count': 376,
#   'publication_year': 2002,
#   'publisher': 'Del Rey / Gollancz',
#   'target_audience': 'Adult / Cyberpunk & SF readers',
#   'pacing': 'Fast; noir and investigative',
#   'tone': 'Dark; Moody; Cynical; Philosophical',
#   'writing_style': 'Sharp; Gritty; Tech-noir flavor',
#   'setting_type': 'Futuristic Earth + off-world settings',
#   'technology_focus': 'Mind transfer; Body modification; AI; Biotech',
#   'content_warnings': 'Violence; Sexual content; Body horror; Corruption'},
#  {'id': 29,
#   'book_name': 'Revelation Space',
#   'author_name': 'Alastair Reynolds',
#   'series_name': 'Revelation Space universe',
#   'series_position': 1,
#   'subgenres': 'Hard SF; Space opera; Dark SF',
#   'themes': 'Extinction risk; Alien ruins; Time; Human ambition',
#   'summary': 'Archaeologist Dan Sylveste pursues the secrets of a vanished alien civilization. Multiple factions clash — including cults, mercenaries, and conspirators — in a tale of cosmic mystery and apocalyptic stakes.',
#   'page_count': 560,
#   'publication_year': 2000,
#   'publisher': 'Gollancz / Tor',
#   'target_audience': 'Adult / SF readers',
#   'pacing': 'Moderate to fast; mystery + action blend',
#   'tone': 'Dark; Brooding; Melancholic',
#   'writing_style': 'Dense; Multi-layered; Technically rich',
#   'setting_type': 'Interstellar space; alien ruins',
#   'technology_focus': 'Starships; Nanotech; Alien artifacts',
#   'content_warnings': 'Violence; Cosmic danger; Grim outcomes'},
#  {'id': 30,
#   'book_name': 'Chasm City',
#   'author_name': 'Alastair Reynolds',
#   'series_name': 'Revelation Space universe',
#   'series_position': 0,
#   'subgenres': 'Hard SF; Space opera; Thriller SF',
#   'themes': 'Decay; Corruption; Identity; Revenge',
#   'summary': 'In the decaying city of Chasm City, a man seeks vengeance and uncovers conspiracies tied to past events, city corruption, and the overlapping histories of spacefaring factions.',
#   'page_count': 416,
#   'publication_year': 2001,
#   'publisher': 'Gollancz / Tor',
#   'target_audience': 'Adult / SF fans',
#   'pacing': 'Moderate; mix of mystery and action',
#   'tone': 'Dark; Atmospheric; Intense',
#   'writing_style': 'Rich; Descriptive; Layered',
#   'setting_type': 'City on alien planet; space connections',
#   'technology_focus': 'Cybernetics; Nanotech; Biotech',
#   'content_warnings': 'Violence; Crime; Intrigue'},
#  {'id': 31,
#   'book_name': 'Perdido Street Station',
#   'author_name': 'China Miéville',
#   'series_name': 'Bas-Lag / New Crobuzon',
#   'series_position': 1,
#   'subgenres': 'New Weird; Dark fantasy / SF',
#   'themes': 'Urban decay; Power; Body horror; Oppression',
#   'summary': 'In the city of New Crobuzon, a scientist takes on a dangerous commission involving a winged creature, unleashing monstrous forces and political tensions in the city’s underbelly.',
#   'page_count': 744,
#   'publication_year': 2000,
#   'publisher': 'Macmillan / Del Rey',
#   'target_audience': 'Adult / speculative fiction readers',
#   'pacing': 'Moderate with bursts of intensity',
#   'tone': 'Grotesque; Lyrical; Dark; Urban',
#   'writing_style': 'Rich; Imaginative; Genre-blending',
#   'setting_type': 'Weird city / fantasy + SF hybrid',
#   'technology_focus': 'Alchemy; Biomechanical creatures; Weird science',
#   'content_warnings': 'Body horror; Violence; Political oppression'},
#  {'id': 32,
#   'book_name': 'The Scar',
#   'author_name': 'China Miéville',
#   'series_name': 'Bas-Lag / New Crobuzon',
#   'series_position': 2,
#   'subgenres': 'New Weird; Dark fantasy / SF',
#   'themes': 'Exploration; Freedom vs control; Pirate politics; Identity',
#   'summary': 'A floating pirate city of ships sails across strange seas. A group from New Crobuzon becomes embroiled in its politics, facing strange creatures, mutiny, and quests for power.',
#   'page_count': 717,
#   'publication_year': 2002,
#   'publisher': 'Macmillan / Del Rey',
#   'target_audience': 'Adult / speculative readers',
#   'pacing': 'Moderate; combines exploration and tension',
#   'tone': 'Surreal; Mysterious; Dark; Adventurous',
#   'writing_style': 'Lush; Imaginative; Genre-blending',
#   'setting_type': 'Fantastic seas; pirate city; weird world',
#   'technology_focus': 'Weird science; Ship tech; Biomechanics',
#   'content_warnings': 'Violence; Political intrigue; Strange creatures'},
#  {'id': 33,
#   'book_name': 'Iron Council',
#   'author_name': 'China Miéville',
#   'series_name': 'Bas-Lag / New Crobuzon',
#   'series_position': 3,
#   'subgenres': 'New Weird; Fantasy-SF hybrid; Political fantasy',
#   'themes': 'Revolution; Labor rights; Imperialism; Solidarity; Sacrifice',
#   'summary': 'Decades after *Perdido Street Station*, war and social unrest engulf New Crobuzon. The revolutionary ‘Iron Council’ returns to the city amidst uprisings, as dissidents, workers, and radicals thread resistance and betrayal.',
#   'page_count': 564,
#   'publication_year': 2004,
#   'publisher': 'Del Rey / Macmillan',
#   'target_audience': 'Adult / political fantasy & weird fiction readers',
#   'pacing': 'Moderate to slow; interwoven plots',
#   'tone': 'Dark; Politically charged; Melancholic; Hopeful tension',
#   'writing_style': 'Dense; Poetic; Multi-stranded',
#   'setting_type': 'City-state + frontier zones in Bas-Lag',
#   'technology_focus': 'Steampunk tech; Railroads; Magical / weird science',
#   'content_warnings': 'Revolutionary violence; Oppression; Death'},
#  {'id': 34,
#   'book_name': 'American Gods',
#   'author_name': 'Neil Gaiman',
#   'series_name': 'N/A',
#   'series_position': 0,
#   'subgenres': 'Fantasy; Mythic fiction',
#   'themes': 'Belief and faith; Identity; Change and memory; Mythology vs modernity',
#   'summary': 'Shadow Moon, freshly released from prison after his wife’s death, is drawn into a conflict between old gods and new gods—manifestations of ancient myth and modern forces—across America.',
#   'page_count': 465,
#   'publication_year': 2001,
#   'publisher': 'William Morrow / Headline',
#   'target_audience': 'Adult / fantasy readers',
#   'pacing': 'Moderate with introspective and episodic interludes',
#   'tone': 'Darkly mythical; Reflective; Tense',
#   'writing_style': 'Lyrical; Interwoven narrative threads; Symbolic use of myth',
#   'setting_type': 'Modern America blended with mythic landscapes',
#   'technology_focus': 'Pre-industrial base; Magic systems; Alchemy; Mechanical devices',
#   'content_warnings': 'Violence; Death; Mythic conflict; Occult themes'},
#  {'id': 35,
#   'book_name': 'Neverwhere',
#   'author_name': 'Neil Gaiman',
#   'series_name': 'N/A',
#   'series_position': 0,
#   'subgenres': 'Urban fantasy; Portal fantasy',
#   'themes': 'Hidden worlds; Identity; Belonging; Power in anonymity',
#   'summary': 'A man from London stumbles into an underground realm (“London Below”) of strange characters, gods, and forgotten people. He must navigate its dangers to find his place and survive.',
#   'page_count': 400,
#   'publication_year': 1996,
#   'publisher': 'BBC Books / HarperCollins',
#   'target_audience': 'Adult / fantasy readers',
#   'pacing': 'Steady with bursts of action',
#   'tone': 'Mysterious; Dark; Whimsical',
#   'writing_style': 'Accessible; Mythic imagery; Character-driven',
#   'setting_type': 'Modern city + hidden magical realm',
#   'technology_focus': 'Modern consumer tech; Internet/phones; Magic interfaces',
#   'content_warnings': 'Violence; Themes of abandonment and danger'},
#  {'id': 36,
#   'book_name': 'Good Omens',
#   'author_name': 'Neil Gaiman & Terry Pratchett',
#   'series_name': 'N/A',
#   'series_position': 0,
#   'subgenres': 'Comic fantasy; Apocalyptic fantasy',
#   'themes': 'Good vs evil; Fate and free will; Humor in apocalypse',
#   'summary': 'An angel and a demon reluctantly team up to prevent the apocalypse when the Antichrist is born on Earth. Their friendship and comedic mishaps challenge divine plans.',
#   'page_count': 432,
#   'publication_year': 1990,
#   'publisher': 'Workman Publishing / Gollancz',
#   'target_audience': 'Adult / fantasy readers',
#   'pacing': 'Fast; witty pace',
#   'tone': 'Humorous; Satirical; Playful',
#   'writing_style': 'Light; Dialog-heavy; Satirical narrative',
#   'setting_type': 'Contemporary Earth with supernatural overlays',
#   'technology_focus': 'Scavenged tech; Survival engineering; Ad hoc communications',
#   'content_warnings': 'Violence; Apocalyptic themes; Mischief'},
#  {'id': 37,
#   'book_name': 'Small Gods',
#   'author_name': 'Terry Pratchett',
#   'series_name': 'Discworld',
#   'series_position': 13,
#   'subgenres': 'Comic fantasy; Philosophical fantasy',
#   'themes': 'Religion and faith; Power and corruption; Individual insight',
#   'summary': 'On the Discworld, the Great God Om is trapped in the form of a tortoise, with only one believer left. A novice and the god work together to rekindle belief and challenge institutional religion.',
#   'page_count': 399,
#   'publication_year': 1992,
#   'publisher': 'Victor Gollancz / HarperCollins',
#   'target_audience': 'Adult / fantasy readers',
#   'pacing': 'Moderate; contemplative with humorous moments',
#   'tone': 'Satirical; Thoughtful; Wry',
#   'writing_style': 'Accessible; Humor + philosophical commentary',
#   'setting_type': 'Fantasy realm (Discworld) with theological overlay',
#   'technology_focus': 'Pre-industrial base; Magic; Early mechanics; Semaphore/printing in wider world',
#   'content_warnings': 'Religious critique; Violence'},
#  {'id': 38,
#   'book_name': 'The Colour of Magic',
#   'author_name': 'Terry Pratchett',
#   'series_name': 'Discworld',
#   'series_position': 1,
#   'subgenres': 'Comic fantasy; Satirical fantasy',
#   'themes': 'Adventure; Satire of fantasy tropes; Chaos in order',
#   'summary': 'A naive tourist and a failed wizard travel the Discworld, encountering bizarre lands, gods, and monsters in a satirical take on classic fantasy tropes.',
#   'page_count': 210,
#   'publication_year': 1983,
#   'publisher': 'Colin Smythe / Corgi / Doubleday',
#   'target_audience': 'Adult / fantasy readers',
#   'pacing': 'Light and episodic',
#   'tone': 'Humorous; Satirical; Whimsical',
#   'writing_style': 'Playful; Parody; Light narrative',
#   'setting_type': 'Fantasy world (Discworld)',
#   'technology_focus': 'Pre-industrial base; Magic; Early mechanics; Semaphore/printing in wider world',
#   'content_warnings': 'Mild fantasy violence'},
#  {'id': 39,
#   'book_name': 'Guards! Guards!',
#   'author_name': 'Terry Pratchett',
#   'series_name': 'Discworld',
#   'series_position': 8,
#   'subgenres': 'Comic fantasy; Satirical fantasy',
#   'themes': 'Authority and rebellion; Heroism; Institutional folly',
#   'summary': 'In Ankh-Morpork, a secret society summons a dragon to overthrow the Patrician. The city watch must rise to the challenge and protect the city.',
#   'page_count': 288,
#   'publication_year': 1989,
#   'publisher': 'Victor Gollancz / HarperCollins',
#   'target_audience': 'Adult / fantasy readers',
#   'pacing': 'Moderate with comedic tension',
#   'tone': 'Humorous; Satirical; Adventurous',
#   'writing_style': 'Witty; Ensemble cast; Parodic fantasy',
#   'setting_type': 'Fantasy city (discworld)',
#   'technology_focus': 'Pre-industrial base; Magic; Early mechanics; Semaphore/printing in wider world',
#   'content_warnings': 'Fantasy violence; Political satire'},
#  {'id': 40,
#   'book_name': 'The Lies of Locke Lamora',
#   'author_name': 'Scott Lynch',
#   'series_name': 'Gentleman Bastard',
#   'series_position': 1,
#   'subgenres': 'Fantasy; Heist / crime fantasy',
#   'themes': 'Friendship; Betrayal; Identity; Deception; Power',
#   'summary': 'In the city of Camorr, master thief Locke Lamora leads the Gentleman Bastards, pulling off cons against nobles while confronting dangerous rival criminals and hidden plots.',
#   'page_count': 499,
#   'publication_year': 2006,
#   'publisher': 'Bantam Spectra',
#   'target_audience': 'Adult / fantasy readers',
#   'pacing': 'Fast to moderate; tense heist and reveal structure',
#   'tone': 'Clever; Gritty; Darkly humorous',
#   'writing_style': 'Intricate plotting; Rich worldbuilding; Dialogue and internal monologue',
#   'setting_type': 'City-state fantasy (Camorr) with criminal underworld',
#   'technology_focus': 'Pre-industrial city tech; Alchemy; Mechanical devices; Naval technology',
#   'content_warnings': 'Violence; Torture; Betrayal; Criminal activity'},
#  {'id': 41,
#   'book_name': 'Red Seas Under Red Skies',
#   'author_name': 'Scott Lynch',
#   'series_name': 'Gentleman Bastard',
#   'series_position': 2,
#   'subgenres': 'Fantasy; Pirate / nautical fantasy',
#   'themes': 'Adventure; Loyalty; Risk; Revenge',
#   'summary': 'Locke Lamora and Jean Tannen sail to distant seas, navigate piracy, politics, and lost treasure while facing enemies from their past.',
#   'page_count': 592,
#   'publication_year': 2007,
#   'publisher': 'Gollancz / Bantam Spectra',
#   'target_audience': 'Adult / fantasy readers',
#   'pacing': 'Moderate to fast; sailing adventure + intrigue',
#   'tone': 'Adventurous; Tense; Wry',
#   'writing_style': 'Vivid world detail; Dual threads; Voiceful characters',
#   'setting_type': 'Seas and coastal cities in fantasy world',
#   'technology_focus': 'Pre-industrial city tech; Alchemy; Mechanical devices; Naval technology',
#   'content_warnings': 'Violence; Sea battles; Betrayal'},
#  {'id': 42,
#   'book_name': 'The Republic of Thieves',
#   'author_name': 'Scott Lynch',
#   'series_name': 'Gentleman Bastard',
#   'series_position': 3,
#   'subgenres': 'Fantasy; Political intrigue; Heist fantasy',
#   'themes': 'Trust & betrayal; Politics; Identity; Love and loyalty',
#   'summary': 'Locke Lamora returns to infiltrate politics in a rival city to influence an election, while wrestling with his complicated past and a cunning adversary.',
#   'page_count': 544,
#   'publication_year': 2013,
#   'publisher': 'Gollancz / Bantam Spectra',
#   'target_audience': 'Adult / fantasy readers',
#   'pacing': 'Moderate with tension and political maneuvering',
#   'tone': 'Clever; Tense; Emotional undercurrents',
#   'writing_style': 'Intricate plotting; Dialogue; Political scheming',
#   'setting_type': 'City-state politics and intrigue',
#   'technology_focus': 'Pre-industrial city tech; Alchemy; Mechanical devices; Naval technology',
#   'content_warnings': 'Violence; Manipulation; Political deceit'},
#  {'id': 43,
#   'book_name': 'The Blade Itself',
#   'author_name': 'Joe Abercrombie',
#   'series_name': 'First Law',
#   'series_position': 1,
#   'subgenres': 'Grimdark fantasy; Epic fantasy',
#   'themes': 'Power and corruption; Violence; Morality',
#   'summary': 'In a brutal world, a crippled torturer, a barbarian, a nobleman, and an inquisitor’s apprentice find their fates entwined in war, intrigue, and moral compromise.',
#   'page_count': 515,
#   'publication_year': 2006,
#   'publisher': 'Gollancz / HarperCollins',
#   'target_audience': 'Adult / dark fantasy readers',
#   'pacing': 'Moderate to fast; character and action mix',
#   'tone': 'Dark; Cynical; Gritty',
#   'writing_style': 'Realistic dialogue; Multiple POVs; Harsh realism',
#   'setting_type': 'Grim fantasy world with political and war zones',
#   'technology_focus': 'Pre-industrial technology; Blacksmithing; Magic artifacts',
#   'content_warnings': 'Violence; Brutality; War; Moral ambiguity'},
#  {'id': 44,
#   'book_name': 'Before They Are Hanged',
#   'author_name': 'Joe Abercrombie',
#   'series_name': 'First Law',
#   'series_position': 2,
#   'subgenres': 'Grimdark fantasy; Epic fantasy',
#   'themes': 'Sacrifice; Resilience; Conflict; Morality',
#   'summary': 'The protagonists embark on dangerous missions: one to defend a city under siege, another into enemy territory, and one journeys toward mysterious lands, all while war escalates.',
#   'page_count': 608,
#   'publication_year': 2007,
#   'publisher': 'Gollancz / HarperCollins',
#   'target_audience': 'Adult / dark fantasy readers',
#   'pacing': 'Fast with perilous missions',
#   'tone': 'Dark; High-stakes; Gritty',
#   'writing_style': 'Tense; Multi-threaded; Harsh realism',
#   'setting_type': 'Warfare-ridden fantasy world',
#   'technology_focus': 'Pre-industrial technology; Blacksmithing; Magic artifacts',
#   'content_warnings': 'Violence; War; Torture; Loss'},
#  {'id': 45,
#   'book_name': 'Last Argument of Kings',
#   'author_name': 'Joe Abercrombie',
#   'series_name': 'First Law',
#   'series_position': 3,
#   'subgenres': 'Grimdark fantasy; Epic fantasy',
#   'themes': 'War; Betrayal; Redemption; Leadership',
#   'summary': 'The factions converge for final confrontation. Alliances fracture, heroes fall, and the brutal costs of war become evident as kingdoms fight for survival.',
#   'page_count': 592,
#   'publication_year': 2008,
#   'publisher': 'Gollancz / HarperCollins',
#   'target_audience': 'Adult / dark fantasy readers',
#   'pacing': 'Fast and climactic',
#   'tone': 'Bleak; Intense; Brutal',
#   'writing_style': 'Unflinching; Multi-POV; Grim realism',
#   'setting_type': 'Fantasy battlefields; political realms',
#   'technology_focus': 'Pre-industrial technology; Black powder weapons; Siege engines',
#   'content_warnings': 'Violence; Death; Betrayal'},
#  {'id': 46,
#   'book_name': 'The Gunslinger',
#   'author_name': 'Stephen King',
#   'series_name': 'The Dark Tower',
#   'series_position': 1,
#   'subgenres': 'Dark fantasy; Western fantasy',
#   'themes': 'Obsession; Quest; Reality vs illusion',
#   'summary': 'The lone gunslinger Roland pursues the Man in Black across a bleak world, seeking the Dark Tower, encountering strange lands and tests along the way.',
#   'page_count': 224,
#   'publication_year': 1982,
#   'publisher': 'Donald M. Grant / Later editions by New English Library',
#   'target_audience': 'Adult / fantasy readers',
#   'pacing': 'Slow to moderate; meditative and atmospheric',
#   'tone': 'Haunting; Ambiguous; Questing',
#   'writing_style': 'Sparse; Mythic; Blends genres',
#   'setting_type': 'Post-apocalyptic fantasy world with Western elements',
#   'technology_focus': 'Mixed pre/post-industrial tech; Firearms; Magical artifacts',
#   'content_warnings': 'Violence; Psychological tension'},
#  {'id': 47,
#   'book_name': 'The Drawing of the Three',
#   'author_name': 'Stephen King',
#   'series_name': 'The Dark Tower',
#   'series_position': 2,
#   'subgenres': 'Dark fantasy; Horror fantasy; Quest fantasy',
#   'themes': 'Companionship; Fate; Identity; Sacrifice',
#   'summary': 'Roland opens doors to draw three companions into his quest in order to continue toward the Dark Tower, each pulled from different worlds and times with their own conflicts.',
#   'page_count': 400,
#   'publication_year': 1987,
#   'publisher': 'Donald M. Grant / Later editions',
#   'target_audience': 'Adult / fantasy & horror readers',
#   'pacing': 'Moderate; character introspection + conflict',
#   'tone': 'Dark; Reflective; Strange',
#   'writing_style': 'Hybrid – horror, fantasy, psychological',
#   'setting_type': 'Multiple interconnected worlds',
#   'technology_focus': 'Mixed pre/post-industrial tech; Firearms; Magical artifacts',
#   'content_warnings': 'Violence; Supernatural horror'},
#  {'id': 48,
#   'book_name': 'The Waste Lands',
#   'author_name': 'Stephen King',
#   'series_name': 'The Dark Tower',
#   'series_position': 3,
#   'subgenres': 'Dark fantasy; Post-apocalyptic fantasy',
#   'themes': 'Decay; Journey; Memory; Time',
#   'summary': 'Roland and his companions travel through a desolate land toward the Dark Tower, confronting monstrous threats, inner conflicts, and strange phenomena.',
#   'page_count': 336,
#   'publication_year': 1991,
#   'publisher': 'Donald M. Grant / Later editions',
#   'target_audience': 'Adult / fantasy & horror readers',
#   'pacing': 'Moderate; episodic journey with danger',
#   'tone': 'Bleak; Mysterious; Foreboding',
#   'writing_style': 'Blended; atmospheric; nonlinear elements',
#   'setting_type': 'Post-apocalyptic world and fantasy landscape',
#   'technology_focus': 'Scavenged tech; Survival engineering; Ad hoc communications',
#   'content_warnings': 'Violence; Horror elements; Psychological stress'},
#  {'id': 49,
#   'book_name': 'Wizard and Glass',
#   'author_name': 'Stephen King',
#   'series_name': 'The Dark Tower',
#   'series_position': 4,
#   'subgenres': 'Dark fantasy; Fantasy; Western fantasy',
#   'themes': 'Memory; Obsession; Love and loss; Destiny',
#   'summary': 'Roland and his ka-tet travel through a world that is collapsing, and Roland tells the story of his youth, his first love, and how he became obsessed with the Dark Tower.',
#   'page_count': 787,
#   'publication_year': 1997,
#   'publisher': 'Grant',
#   'target_audience': 'Adult / fantasy readers',
#   'pacing': 'Slow to moderate; weighted with backstory',
#   'tone': 'Melancholic; Reflective; Epic',
#   'writing_style': 'Rich; Lyrical; Multi-layered narrative',
#   'setting_type': 'Post-apocalyptic / fantasy world; desert, baronies, inner kingdoms',
#   'technology_focus': 'Mixed pre/post-industrial tech; Firearms; Magical artifacts',
#   'content_warnings': 'Violence; Loss; Trauma; Obsession'},
#  {'id': 50,
#   'book_name': 'It',
#   'author_name': 'Stephen King',
#   'series_name': 'N/A',
#   'series_position': 0,
#   'subgenres': 'Horror; Supernatural horror',
#   'themes': 'Fear and memory; Childhood vs adulthood; Evil incarnate',
#   'summary': 'In the town of Derry, a group of friends reunite as adults to confront the evil entity ‘It’ that tormented them as children and continues to haunt the town.',
#   'page_count': 1138,
#   'publication_year': 1986,
#   'publisher': 'Viking / Putnam',
#   'target_audience': 'Adult / horror readers',
#   'pacing': 'Moderate with episodic jumps',
#   'tone': 'Dark; Terrifying; Nostalgic',
#   'writing_style': 'Detailed; Multi-POV; Psychological horror',
#   'setting_type': 'Small town with supernatural overlay',
#   'technology_focus': 'Period-appropriate tools; Communication media; Occult/magical artifacts',
#   'content_warnings': 'Violence; Child endangerment; Trauma; Psychological horror'},
#  {'id': 51,
#   'book_name': 'The Stand',
#   'author_name': 'Stephen King',
#   'series_name': 'N/A',
#   'series_position': 0,
#   'subgenres': 'Post-apocalyptic; Horror; Epic fantasy elements',
#   'themes': 'Good vs evil; Community; Sacrifice; Destiny',
#   'summary': 'After a plague wipes out most of humanity, survivors align with forces of good or evil and wage a final confrontation to shape the world’s future.',
#   'page_count': 1153,
#   'publication_year': 1978,
#   'publisher': 'Doubleday',
#   'target_audience': 'Adult / speculative & horror readers',
#   'pacing': 'Moderate to slow; broad scope',
#   'tone': 'Epic; Hopeful; Dark',
#   'writing_style': 'Ensemble cast; Descriptive; Multiple POVs',
#   'setting_type': 'Post-apocalyptic Earth',
#   'technology_focus': 'Scavenged tech; Survival engineering; Ad hoc communications',
#   'content_warnings': 'Violence; Disease; Death; Moral extremes'},
#  {'id': 52,
#   'book_name': 'Dracula',
#   'author_name': 'Bram Stoker',
#   'series_name': 'N/A',
#   'series_position': 0,
#   'subgenres': 'Gothic horror; Vampire fiction',
#   'themes': 'Immortality; Fear of the unknown; Victorian anxieties; Power',
#   'summary': 'Jonathan Harker visits Count Dracula’s castle and uncovers the vampire’s plan to move to England. A group bands together to stop Dracula’s reign of terror.',
#   'page_count': 418,
#   'publication_year': 1897,
#   'publisher': 'Archibald Constable & Co.',
#   'target_audience': 'Adult / horror & gothic readers',
#   'pacing': 'Moderate; epistolary structure',
#   'tone': 'Atmospheric; Eerie; Romantic dread',
#   'writing_style': 'Epistolary (letters, journals); formal Victorian prose',
#   'setting_type': 'Victorian England; Transylvanian castle',
#   'technology_focus': 'Period-appropriate tools; Communication media; Occult/magical artifacts',
# ...
#   'content_warnings': 'Violence; Danger'},
#  {'id': 174,
#   'book_name': 'The Silver Chair',
#   'author_name': 'C.S. Lewis',
#   'series_name': 'The Chronicles of Narnia',
#   'series_position': 4,
#   'subgenres': 'Children’s fantasy; Quest fantasy',
#   'themes': 'Truth and deception; Perseverance; Friendship',
#   'summary': 'Eustace and Jill search for a missing prince through marshes, underworlds, and trials while battling enchantments and deception.',
#   'page_count': 208,
#   'publication_year': 1953,
#   'publisher': 'Geoffrey Bles',
#   'target_audience': 'Children / fantasy readers',
#   'pacing': 'Moderate; mystery + peril',
#   'tone': 'Suspenseful; Mythic; Steady',
#   'writing_style': 'Third-person; quest structure',
#   'setting_type': 'Underlands; magical realms',
#   'technology_focus': 'Pre-industrial base; Magic systems; Alchemy; Mechanical devices',
#   'content_warnings': 'Violence; Enchantment; Peril'},
#  {'id': 175,
#   'book_name': 'The Horse and His Boy',
#   'author_name': 'C.S. Lewis',
#   'series_name': 'The Chronicles of Narnia',
#   'series_position': 5,
#   'subgenres': 'Children’s fantasy; Coming-of-age',
#   'themes': 'Belonging; Identity; Refuge; Destiny',
#   'summary': 'A boy named Shasta and a talking horse escape from Calormen to Narnia. They learn truths about themselves and play a part in thwarting invasion.',
#   'page_count': 227,
#   'publication_year': 1954,
#   'publisher': 'Geoffrey Bles',
#   'target_audience': 'Children / fantasy readers',
#   'pacing': 'Moderate; character + adventure',
#   'tone': 'Hopeful; Reflective; Adventurous',
#   'writing_style': 'Third-person; dual POV',
#   'setting_type': 'Desert lands; Narnia; kingdoms',
#   'technology_focus': 'Pre-industrial base; Magic systems; Alchemy; Mechanical devices',
#   'content_warnings': 'Violence; Peril'},
#  {'id': 176,
#   'book_name': 'The Magician’s Nephew',
#   'author_name': 'C.S. Lewis',
#   'series_name': 'The Chronicles of Narnia',
#   'series_position': 6,
#   'subgenres': 'Children’s fantasy; Creation myth',
#   'themes': 'Origins; Choice; Curiosity; Consequence',
#   'summary': 'Digory and Polly use magical rings to travel between worlds. They witness Narnia’s creation, unwittingly unleash evil, and learn responsibility.',
#   'page_count': 208,
#   'publication_year': 1955,
#   'publisher': 'Geoffrey Bles',
#   'target_audience': 'Children / fantasy readers',
#   'pacing': 'Moderate; creation + peril',
#   'tone': 'Mythical; Reflective; Tense',
#   'writing_style': 'Third-person; descriptive mythic prose',
#   'setting_type': 'Multiple worlds; creation realm',
#   'technology_focus': 'Magical rings; creation magic',
#   'content_warnings': 'Violence; Sacrifice'},
#  {'id': 177,
#   'book_name': 'The Last Battle',
#   'author_name': 'C.S. Lewis',
#   'series_name': 'The Chronicles of Narnia',
#   'series_position': 7,
#   'subgenres': 'Children’s fantasy; Apocalypse fantasy',
#   'themes': 'Faith; End and renewal; Truth and deception',
#   'summary': 'Narnia faces a false Aslan and invasion. The final struggles usher in the end of Narnia and a new beginning beyond.',
#   'page_count': 212,
#   'publication_year': 1956,
#   'publisher': 'Geoffrey Bles',
#   'target_audience': 'Children / fantasy readers',
#   'pacing': 'Moderate; escalating conflict',
#   'tone': 'Somber; Mythical; Sublime',
#   'writing_style': 'Third-person; mythic closing narration',
#   'setting_type': 'Narnia; end-time landscape',
#   'technology_focus': 'Pre-industrial base; Magic systems; Alchemy; Mechanical devices',
#   'content_warnings': 'Violence; Apocalypse'},
#  {'id': 178,
#   'book_name': 'Watership Down',
#   'author_name': 'Richard Adams',
#   'series_name': 'N/A',
#   'series_position': 0,
#   'subgenres': 'Animal fantasy; Adventure',
#   'themes': 'Survival; Community; Exile; Freedom',
#   'summary': 'A group of rabbits flee destruction of their warren and seek a new home, facing perils, diplomacy, myths, and leadership challenges along the way.',
#   'page_count': 448,
#   'publication_year': 1972,
#   'publisher': 'Rex Collings / Scribner',
#   'target_audience': 'Young adult / fantasy readers',
#   'pacing': 'Moderate; journey + conflict',
#   'tone': 'Mythic; Tense; Reflective',
#   'writing_style': 'Third-person anthropomorphic narrative',
#   'setting_type': 'English countryside; warren lands; wilderness',
#   'technology_focus': 'Pre-industrial base; Magic systems; Alchemy; Mechanical devices',
#   'content_warnings': 'Violence; Death; Predation'},
#  {'id': 179,
#   'book_name': 'The Black Company',
#   'author_name': 'Glen Cook',
#   'series_name': 'The Black Company',
#   'series_position': 1,
#   'subgenres': 'Military fantasy; Dark fantasy',
#   'themes': 'Loyalty; Corruption; Survival; Morality in war',
#   'summary': 'The Black Company, a band of mercenaries, serves powerful sorcerers in a land torn by war. They chronicle their missions amid shifting allegiances and dark magic.',
#   'page_count': 319,
#   'publication_year': 1984,
#   'publisher': 'N/A',
#   'target_audience': 'Adult / fantasy readers',
#   'pacing': 'Moderate; battlefield and intrigue',
#   'tone': 'Gritty; Cynical; Reflective',
#   'writing_style': 'First-person journal narration by the Company’s annalist',
#   'setting_type': 'War-ravaged land; magical battlegrounds',
#   'technology_focus': 'Magic; siegecraft; enchantments',
#   'content_warnings': 'Violence; Death; Moral ambiguity'},
#  {'id': 180,
#   'book_name': 'Shadows Linger',
#   'author_name': 'Glen Cook',
#   'series_name': 'The Black Company',
#   'series_position': 2,
#   'subgenres': 'Military fantasy; Dark fantasy',
#   'themes': 'Aftermath; Secrets; Legacy; Power struggles',
#   'summary': 'Following *The Black Company*, the mercenaries deal with political fallout, betrayals, and unearthly threats in a land still unstable.',
#   'page_count': 312,
#   'publication_year': 1984,
#   'publisher': 'N/A',
#   'target_audience': 'Adult / fantasy readers',
#   'pacing': 'Moderate; tension + action',
#   'tone': 'Dark; Brooding; Strategic',
#   'writing_style': 'First-person annalist voice; layered narrative',
#   'setting_type': 'Cities; war zones; magical enclaves',
#   'technology_focus': 'Magic; dark powers',
#   'content_warnings': 'Violence; Betrayal'},
#  {'id': 181,
#   'book_name': 'The White Rose',
#   'author_name': 'Glen Cook',
#   'series_name': 'The Black Company',
#   'series_position': 3,
#   'subgenres': 'Military fantasy; Dark fantasy',
#   'themes': 'Resistance; Hope; Sacrifice; Redemption',
#   'summary': 'The Black Company joins forces with rebels against tyrannical evil, facing moral choices and supernatural dangers as the battle intensifies.',
#   'page_count': 310,
#   'publication_year': 1985,
#   'publisher': 'N/A',
#   'target_audience': 'Adult / fantasy readers',
#   'pacing': 'Moderate to fast; battles and strategy',
#   'tone': 'Gritty; Hopeful; Intense',
#   'writing_style': 'First-person annalist with collected perspectives',
#   'setting_type': 'Rebellion zones; strongholds; wilderness',
#   'technology_focus': 'Magic; military tactics',
#   'content_warnings': 'Violence; Death; Sacrifice'},
#  {'id': 182,
#   'book_name': 'Gardens of the Moon',
#   'author_name': 'Steven Erikson',
#   'series_name': 'Malazan Book of the Fallen',
#   'series_position': 1,
#   'subgenres': 'Epic fantasy; Military fantasy',
#   'themes': 'Empire; War; Memory; God and mortals',
#   'summary': 'In the vast Malazan Empire, the Bridgeburners invade the city of Pale, setting off complex plots, betrayals, and the clash of gods and mortals.',
#   'page_count': 713,
#   'publication_year': 1999,
#   'publisher': 'Bantam / Tor',
#   'target_audience': 'Adult / fantasy readers',
#   'pacing': 'Moderate to dense; layered plots',
#   'tone': 'Epic; Dark; Complex',
#   'writing_style': 'Third-person multiple POV; nonlinear time jumps',
#   'setting_type': 'Terrestrial world with cities, warrens, magical zones',
#   'technology_focus': 'Magic; warrens; ancient artifacts',
#   'content_warnings': 'Violence; Mass death; Intrigue'},
#  {'id': 183,
#   'book_name': 'Deadhouse Gates',
#   'author_name': 'Steven Erikson',
#   'series_name': 'Malazan Book of the Fallen',
#   'series_position': 2,
#   'subgenres': 'Epic fantasy; Military fantasy',
#   'themes': 'Rebellion; Sacrifice; Survival; Leadership',
#   'summary': 'On the continent of Seven Cities the Whirlwind rebellion rages. Meanwhile, Coltaine leads the Malazan 7th Army on a desperate march to save refugees—known as the Chain of Dogs. Multiple POVs converge in conflict, destiny, and loss.',
#   'page_count': 864,
#   'publication_year': 2000,
#   'publisher': 'Bantam (UK); Tor (US)',
#   'target_audience': 'Adult / epic fantasy readers',
#   'pacing': 'Fast; multiple converging arcs',
#   'tone': 'Grim; Heroic; Tragic',
#   'writing_style': 'Third-person multiple POV; dense epic prose',
#   'setting_type': 'Continent-wide war zones; desert marches; cities',
#   'technology_focus': 'Magic; military tactics; warrens',
#   'content_warnings': 'Violence; Death; Mass suffering'},
#  {'id': 184,
#   'book_name': 'Memories of Ice',
#   'author_name': 'Steven Erikson',
#   'series_name': 'Malazan Book of the Fallen',
#   'series_position': 3,
#   'subgenres': 'Epic fantasy; Cosmic fantasy',
#   'themes': 'Memory; Unity and division; Sacrifice; War and legacy',
#   'summary': 'On Genabackis, ancient powers awaken and old alliances shift. The Malazan 2nd Army, allied forces, and gods confront the rising Pannion Domin in a struggle where history, identity, and sacrifice collide.',
#   'page_count': 1187,
#   'publication_year': 2001,
#   'publisher': 'Bantam (UK); Tor (US)',
#   'target_audience': 'Adult / epic fantasy readers',
#   'pacing': 'Moderate to dense; shifting scales',
#   'tone': 'Epic; Somber; Mythic',
#   'writing_style': 'Third-person; sprawling multi-POV',
#   'setting_type': 'Cities, battlefields, warrens, wilds',
#   'technology_focus': 'Magic; ancient artifacts; warrens',
#   'content_warnings': 'Violence; Death; Horror'},
#  {'id': 185,
#   'book_name': 'House of Chains',
#   'author_name': 'Steven Erikson',
#   'series_name': 'Malazan Book of the Fallen',
#   'series_position': 4,
#   'subgenres': 'Epic fantasy; Military fantasy',
#   'themes': 'Freedom; Power and oppression; Transformation; Rebellion',
#   'summary': 'Karsa Orlong descends from his mountain fastness and confronts civilization. Simultaneously, characters from earlier books wrestle with political and magical upheavals in a changing empire.',
#   'page_count': 1021,
#   'publication_year': 2002,
#   'publisher': 'Bantam (UK); Tor (US)',
#   'target_audience': 'Adult / epic fantasy readers',
#   'pacing': 'Moderate to fast; interleaving arcs',
#   'tone': 'Harsh; Intricate; Epic',
#   'writing_style': 'Third-person multiple POV',
#   'setting_type': 'Wilderness, empires, war fronts',
#   'technology_focus': 'Magic; warrens; cultural conflict',
#   'content_warnings': 'Violence; Brutality; War'},
#  {'id': 186,
#   'book_name': 'Midnight Tides',
#   'author_name': 'Steven Erikson',
#   'series_name': 'Malazan Book of the Fallen',
#   'series_position': 5,
#   'subgenres': 'Epic fantasy; Political fantasy',
#   'themes': 'Empire; Fate; Power struggles; Cost of ambition',
#   'summary': 'On a continent unknown to earlier books, two nations clash and deeper conspiracies emerge around their royal houses, undermining balance and setting the stage for mass conflict.',
#   'page_count': 940,
#   'publication_year': 2004,
#   'publisher': 'Bantam (UK); Tor (US)',
#   'target_audience': 'Adult / epic fantasy readers',
#   'pacing': 'Moderate; political tensions and looming war',
#   'tone': 'Serious; Foreboding; Complex',
#   'writing_style': 'Third-person multiple POV',
#   'setting_type': 'Empire borders, rivers, palaces',
#   'technology_focus': 'Magic; political machinery',
#   'content_warnings': 'Violence; Intrigue; Death'},
#  {'id': 187,
#   'book_name': 'The Bonehunters',
#   'author_name': 'Steven Erikson',
#   'series_name': 'Malazan Book of the Fallen',
#   'series_position': 6,
#   'subgenres': 'Epic fantasy; Military fantasy',
#   'themes': 'Survival; Betrayal; Duty; Endurance',
#   'summary': 'The Malazan armies push deeper into enemy territory while facing internal betrayal, plague, and the spiritual costs of wielding power in war’s aftermath.',
#   'page_count': 1232,
#   'publication_year': 2006,
#   'publisher': 'Bantam (UK); Tor (US)',
#   'target_audience': 'Adult / epic fantasy readers',
#   'pacing': 'Moderate; tension rising',
#   'tone': 'Dark; Gritty; Heroic undertone',
#   'writing_style': 'Third-person; expansive POV',
#   'setting_type': 'Battlefields, cities, warrens, besieged zones',
#   'technology_focus': 'Magic; divine interference; war tech',
#   'content_warnings': 'Violence; Death; Disease'},
#  {'id': 188,
#   'book_name': 'Reaper’s Gale',
#   'author_name': 'Steven Erikson',
#   'series_name': 'Malazan Book of the Fallen',
#   'series_position': 7,
#   'subgenres': 'Epic fantasy; Cataclysmic fantasy',
#   'themes': 'Collapse; Rebirth; Sacrifice; Cosmic stakes',
#   'summary': 'As gods, armies, and ancient machinations converge, characters old and new confront cataclysmic change and existential choice on battered worlds.',
#   'page_count': 1280,
#   'publication_year': 2007,
#   'publisher': 'Bantam (UK); Tor (US)',
#   'target_audience': 'Adult / epic fantasy readers',
#   'pacing': 'Moderate to fast; multiple climaxes',
#   'tone': 'Epic; Tense; Dramatic',
#   'writing_style': 'Third-person multiple POV',
#   'setting_type': 'Continents, warrens, divine realms',
#   'technology_focus': 'Magic; divine-mortal interaction',
#   'content_warnings': 'Violence; Death; Cosmic peril'},
#  {'id': 189,
#   'book_name': 'Toll the Hounds',
#   'author_name': 'Steven Erikson',
#   'series_name': 'Malazan Book of the Fallen',
#   'series_position': 8,
#   'subgenres': 'Epic fantasy; Dark fantasy',
#   'themes': 'Memory; Regret; Fate; Redemption',
#   'summary': 'Amid political and spiritual upheavals in Darujhistan, old friends and enemies return. The past haunts the present as myth, vengeance, and reconciliation collide.',
#   'page_count': 1296,
#   'publication_year': 2008,
#   'publisher': 'Bantam (UK); Tor (US)',
#   'target_audience': 'Adult / epic fantasy readers',
#   'pacing': 'Moderate; deep tension',
#   'tone': 'Somber; Reflective; Dark',
#   'writing_style': 'Third-person multiple POV',
#   'setting_type': 'City, warrens, mythic zones',
#   'technology_focus': 'Magic; prophecy; warrens',
#   'content_warnings': 'Violence; Vengeance; Loss'},
#  {'id': 190,
#   'book_name': 'Dust of Dreams',
#   'author_name': 'Steven Erikson',
#   'series_name': 'Malazan Book of the Fallen',
#   'series_position': 9,
#   'subgenres': 'Epic fantasy; Endgame fantasy',
#   'themes': 'Perseverance; Fate; Transition; Consequence',
#   'summary': 'As the Malazan forces march eastward through the Wastelands, characters reflect on losses and purpose. A gathering storm looms, preparing for the final confrontation.',
#   'page_count': 1280,
#   'publication_year': 2010,
#   'publisher': 'Bantam (UK); Tor (US)',
#   'target_audience': 'Adult / epic fantasy readers',
#   'pacing': 'Moderate; heavy with foreshadowing',
#   'tone': 'Ominous; Reflective; Grim',
#   'writing_style': 'Third-person multiple POV',
#   'setting_type': 'Wastelands, borderlands, rising menace',
#   'technology_focus': 'Magic; ancient weapons; prophecy',
#   'content_warnings': 'Violence; Death; Despair'},
#  {'id': 191,
#   'book_name': 'The Crippled God',
#   'author_name': 'Steven Erikson',
#   'series_name': 'Malazan Book of the Fallen',
#   'series_position': 10,
#   'subgenres': 'Epic fantasy; Apocalyptic fantasy',
#   'themes': 'Fulfillment; Sacrifice; Fate; Renewal',
#   'summary': 'The final battle of the Malazan saga unfolds. Prophecies resolve, destinies intersect, and the cost of everything is laid bare as worlds shake and the fate of mortals and gods is decided.',
#   'page_count': 944,
#   'publication_year': 2011,
#   'publisher': 'Bantam (UK); Tor (US)',
#   'target_audience': 'Adult / epic fantasy readers',
#   'pacing': 'Fast; climactic resolution',
#   'tone': 'Epic; Emotional; Resolute',
#   'writing_style': 'Third-person multiple POV',
#   'setting_type': 'All major battlefronts, realms, warrens',
#   'technology_focus': 'Magic; divine forces; endgame systems',
#   'content_warnings': 'Violence; Death; Epic destruction'}]

# %%
import json

# %%
prompt_template = """
You are creating evaluation questions for a book metadata database.

You will receive ONE record with the fields:
book_name, author_name, series_name, series_position, subgenres, themes, summary,
page_count, publication_year, publisher, target_audience, pacing, tone, writing_style,
setting_type, technology_focus, content_warnings.

TASK:
- Write 5 questions that can be answered **solely** from THIS record.
- DO NOT ask about plot events, character actions, endings, or trivia not present.
- Keep questions specific to this book but metadata-focused.
- Questions must be complete and not too short.

The record:

book_name: {book_name}
author_name: {author_name}
series_name: {series_name}
series_position: {series_position}
subgenres: {subgenres}
themes: {themes}
summary: {summary}
page_count: {page_count}
publication_year: {publication_year}
publisher: {publisher}
target_audience: {target_audience}
pacing: {pacing}
tone: {tone}
writing_style: {writing_style}
setting_type: {setting_type}
technology_focus: {technology_focus}
content_warnings: {content_warnings}

Provide the output in parsable JSON without using code blocks:
{{"questions": ["question1", "question2", ..., "question5"]}}

Make sure they are completely CONSISTENT with each other in format.

""".strip()

# %% [markdown]
# #### Test that the output makes sense

# %%
prompt_test = prompt_template.format(**documents[0])

# %%
def llm(prompt):
    from ollama import chat
    from ollama import ChatResponse

    response: ChatResponse = chat(
        
        model='llama3.2:latest', 
        messages=[ {'role': 'user','content': prompt}]
        )
    
    return response.message.content

# %%
questions = llm(prompt_test)

# %%
import json
json.loads(questions)
# Out:
# {'questions': ["What is the publication year of the book 'Dune'?",
#   "Who is the author of the book series 'Dune Chronicles'?",
#   "What is the target audience for the book 'Dune'?",
#   "How many pages are in the book 'Dune'?",
#   "What subgenres does the book 'Dune' belong to?"]}

# %% [markdown]
# #### Generate all

# %%
def generate_questions(doc):
    prompt = prompt_template.format(**doc)
    
    from ollama import chat
    from ollama import ChatResponse

    response: ChatResponse = chat(
        
        model='llama3.2:latest', # llama3.2:latest, deepseek-r1, qwen3:8b
        messages=[ {'role': 'user','content': prompt}]
        )
    
    json_response = response.message.content
    return json_response

# %%
from tqdm.auto import tqdm

# %%
results = {}

# %%
for doc in tqdm(documents): 
    doc_id = doc['id']
    if doc_id in results:
        continue

    questions = generate_questions(doc)
    results[doc_id] = questions
# Out:
#   0%|          | 0/192 [00:00<?, ?it/s]

# %%
# Outputs the very last one
questions
# Out:
# '{\n  "questions": [\n    "What is the publication year of \'The Crippled God\'?",\n    "Which publisher released \'The Crippled God\' in the UK and the US?",\n    "How many pages does the book \'The Crippled God\' have?",\n    "In what year was \'The Crippled God\' published?",\n    "For whom is the target audience of \'The Crippled God\' designated?"\n  ]\n}'

# %%
# Full results
results
# Out:
# {0: '{\n  "questions": [\n    "What is the publication year of the book Dune?",\n    "In what genre does the book Dune primarily belong?",\n    "Who is the author of the book Dune?",\n    "How many pages are in the hardcover edition of the book Dune?",\n    "Which audience is the target demographic for the book Dune?"\n  ]\n}',
#  1: '{\n    "questions": [\n        {"type": "Metadata", "text": "What is the title of the book in question?", "answerKey": "Neuromancer"},\n        {"type": "Metadata", "text": "Who wrote this book?", "answerKey": "William Gibson"},\n        {"type": "Metadata", "text": "In what series does Neuromancer belong and where is it positioned within that series?", "answerKey": "Sprawl Trilogy, 1st position"},\n        {"type": "Metadata", "text": "What genres or subgenres categorize this book?", "answerKey": "Cyberpunk"},\n        {"type": "Metadata", "text": "How many pages does the book contain?", "answerKey": "271"}\n    ]\n}',
#  2: '{"questions": [\n    "What is the page count of the book \'The Left Hand of Darkness\'?",\n    "For which publisher was the book \'The Left Hand of Darkness\' originally published?",\n    "In what year was the book \'The Left Hand of Darkness\' first published?",\n    "Who is the author of the book \'The Left Hand of Darkness\'?",\n    "What is the target audience for the book \'The Left Hand of Darkness\'?"\n]}',
#  3: '{"questions": ["What is the publication year of the book \\"Foundation\\"?", "Which publisher released the book \\"Foundation\\" in 1951?", "Who is the author of the book \\"Foundation\\"?", "How many pages does the book \\"Foundation\\" have?", "In what year was the first book in the Foundation Series published?"]}',
#  4: '{"questions": ["What is the publication year of the book \'The Hobbit\'?", \n"Who is the author of the book \'The Hobbit\'?", \n"What is the series position of the book \'The Hobbit\' within the \'Middle-earth\' series?", \n"How many pages does the book \'The Hobbit\' contain?", \n"What are some notable themes present in the book \'The Hobbit\'?"]}',
#  5: '{\n  "questions": [\n    "What is the publication year of the book \'A Game of Thrones\'?",\n    "Who is the author of the book series \'A Song of Ice and Fire\', to which \'A Game of Thrones\' belongs, and what is the position of this book in the series?",\n    "How many pages does the book \'A Game of Thrones\' have, and from which subgenres is it classified?",\n    "For what age range or audience is the book \'A Game of Thrones\' primarily targeted, according to the metadata provided?",\n    "What writing style can be identified as characteristic of this book, given its detailed, descriptive, and multi-perspective nature?"\n  ]\n}',
#  6: '{"questions": [\n"Is \'Mistborn: The Final Empire\' part of a larger series, and if so, what is the position of this book within that series?",\n"What genre classification would you assign to \'Mistborn: The Final Empire\', based on its provided subgenres?",\n"Who is the primary character in \'Mistborn: The Final Empire\', according to the provided summary?",\n"How many pages are contained within the book \'Mistborn: The Final Empire\' as per its page count?",\n"What year was the book \'Mistborn: The Final Empire\' first published, based on the provided publication date?"',
#  7: '{\n    "questions": [\n        "What is the page count of The Way of Kings?",\n        "In what year was The Way of Kings published?",\n        "Who is the author of The Way of Kings?",\n        "To what extent does The Way of Kings focus on hard magic systems in its world-building, according to the metadata?",\n        "Is The Way of Kings targeted towards a specific age range based on the metadata?"\n    ]\n}',
#  8: '{\n  "questions": [\n    "What is the publication year of the book \'The Fifth Season\'?",\n    "In what order is this book part of its series, and how many books does the series have in total?",\n    "Which genres are most commonly associated with this book, according to the metadata?",\n    "Is this book primarily targeted towards a specific age range or demographic group?",\n    "What literary technique is employed in the writing style of \'The Fifth Season\' as described by the author?"\n  ]\n}',
#  9: '{"questions": ["What is the publication year of Ender\'s Game?", "Who is the author of the book Ender\'s Game?", "How many pages does the book Ender\'s Game have?", "For what target audience is the book Ender\'s Game primarily intended?", "What is the main subgenre of the book series Ender Saga?"]}',
#  10: '{\n  "questions": [\n    "What is the number of pages in the book \'Hyperion\'?",\n    "Who is the author of the book series \'Hyperion Cantos\', and what is the first position of the series?",\n    "What genres of fiction does the book \'Hyperion\' belong to, according to its metadata record?",\n    "What themes are explored in the book \'Hyperion\', as identified by its metadata record?",\n    "In what year was the book \'Hyperion\' originally published?"\n  ]\n}',
#  11: '{\n  "questions": [\n    "What is the publication year of the book \'Leviathan Wakes\'?",\n    "Which author wrote the book \'Leviathan Wakes\'?",\n    "How many pages does the book \'Leviathan Wakes\' have?",\n    "Who are the target audience for the book \'Leviathan Wakes\'?",\n    "What is the primary technology focus of the book \'Leviathan Wakes\'?"\n  ]\n}',
#  12: '{\n  "questions": [\n    "What is the publication year of this book?",\n    "Which publisher released \'The Obelisk Gate\'?",\n    "How many pages does the book contain?",\n    "For which series does \'The Obelisk Gate\' belong and its position within it?",\n    "What type of setting does the story take place in?"\n  ]\n}',
#  13: '{"questions": ["What is the page count of the book \'The Stone Sky\'?", "Who is the author of the series and book \'The Stone Sky\'? ", "In what position is \'The Stone Sky\' within its respective series?", "What genres does the book \'The Stone Sky\' belong to?", "When was the book \'The Stone Sky\' published?"]}',
#  14: '{\n  "questions": [\n    "What is the target audience for the book \'Children of Time\'?",\n    "Which subgenres does the book \'Children of Time\' belong to?",\n    "How many pages does the book \'Children of Time\' contain?",\n    "In what year was the book \'Children of Time\' published?",\n    "Who is the author of the book \'Children of Time\'?"\n  ]\n}',
#  15: '{\n  "questions": [\n    "What is the total page count of \'Children of Ruin\'?",\n    "In what year was the book \'Children of Ruin\' published?",\n    "Who is the author of the book series \'Children of Time\', and which position is this book in the series?",\n    "Can you identify the primary subgenres associated with the book \'Children of Ruin\'?",\n    "What is the recommended target audience for the book \'Children of Ruin\'?"\n  ]\n}',
#  16: '{\n  "questions": [\n    "What is the publication year of the book \'The Forever War\'?",\n    "Who is the author of the book series \'The Forever War\', and what is the position of this specific book within the series?",\n    "How many pages are in the hardcover edition of \'The Forever War\'?",\n    "In which subgenres is the book \'The Forever War\' primarily classified?",\n    "What is the recommended age range for readers of \'The Forever War\'?"\n  ]\n}',
#  17: '{\n  "questions": [\n    "What is the publication year of the book \'Old Man\'s War\'?",\n    "Which publisher released the book \'Old Man\'s War\' in 2005?",\n    "How many pages does the book \'Old Man\'s War\' contain?",\n    "To what type of audience is the book \'Old Man\'s War\' primarily targeted?",\n    "What are some of the themes present in the book \'Old Man\'s War\'?"\n  ]\n}',
#  18: '{\n  "questions": [\n    "What is the title of the first book in Kim Stanley Robinson\'s Mars Trilogy?",\n    "In what year was \'Red Mars\' published by Bantam Books?",\n    "How many pages does the book \'Red Mars\' contain?",\n    "To which subgenres of science fiction does the book \'Red Mars\' belong?",\n    "What is a primary theme explored in Kim Stanley Robinson\'s novel \'Red Mars\'?"\n  ]\n}',
#  19: '{\n  "questions": [\n    "What is the publication year of the book \'Green Mars\'?",\n    "Which publisher released the book \'Green Mars\'?",\n    "How many pages does the book \'Green Mars\' have?",\n    "What are the primary subgenres associated with the book \'Green Mars\'?",\n    "Is \'Green Mars\' targeted towards a specific age range or audience group?"\n  ]\n}',
#  20: '{"questions": ["What is the series position of \'Blue Mars\' within its respective series?", "In what year was \'Blue Mars\' published by Bantam Spectra?", "How many pages does \'Blue Mars\' contain?", "Who is the author of \'Blue Mars\'?", "What are the primary content warnings associated with reading \'Blue Mars\'?"]}',
#  21: '{\n  "questions": [\n    "What is the page count of the book \'Snow Crash\'?",\n    "Which publisher released the book \'Snow Crash\' in 1992?",\n    "What is the target audience for readers according to the metadata, and what type of content does it specify?",\n    "How would you describe the writing style of Neal Stephenson in the book \'Snow Crash\', and what aspects of technical knowledge does it incorporate?",\n    "In which technological field(s) or environment(s) is the virtual Metaverse highlighted as a significant aspect of the story?"\n  ]',
#  22: '{"questions":\n    [\n        {"question": "What is the total number of pages in the book Cryptonomicon?", \n         "answer_key": 918},\n        \n        {"question": "In what year was the book Cryptonomicon first published?", \n         "answer_key": 1999},\n        \n        {"question": "What are the two primary settings for the story in Cryptonomicon?", \n         "answer_key": ["20th century", "late 20th century"]},\n        \n        {"question": "How would you describe the writing style of Neal Stephenson in Cryptonomicon?", \n         "answer_key": "Highly detailed; multiple narrative threads"},\n        \n        {"question": "What genres or categories are most prominently featured in the metadata for Cryptonomicon?", \n         "answer_key": ["Historical fiction", "Techno-thriller", "Speculative SF"]}',
#  23: '{"questions":\n["What is the publication year of \'The Three-Body Problem\'?",\n"The series position where this book fits within the \'Remembrance of Earth\'s Past\' series.",\n"Which subgenres categorize this book: Hard SF, First-contact SF, and Astrophysical SF?",\n"What are the themes explored in this novel?",\n"How many pages does the book have?"]',
#  24: '{\n  "questions": [\n    "What is the publication year of the book \'The Dark Forest\', and who published it?",\n    "How many pages does the book \'The Dark Forest\' contain, and what was its original language?",\n    "In which series position does the book \'The Dark Forest\' fit, and how would you describe its target audience?",\n    "What is the technology focus of the book \'The Dark Forest\', and are there any content warnings that readers should be aware of?",\n    "How many books are in the \'Remembrance of Earth\'s Past\' series, and what genre classification does the book \'The Dark Forest\' fall under?"\n  ]\n}',
#  25: '{"questions": [\n"Who is the author of the book \'Death\'s End\'?",\n"How many pages does the book contain?",\n"What is the publication year of the book?",\n"In what series position does \'Death\'s End\' fit within?",\n"What are some of the subgenres associated with this book?"\n]}',
#  26: '{\n  "questions": [\n    "What is the publication year of the book \'Ringworld\'?",\n    "In what subgenres is the book \'Ringworld\' classified?",\n    "How many pages does the book \'Ringworld\' contain?",\n    "Who is the author of the book \'Ringworld\'?",\n    "What type of technology does the book \'Ringworld\' focus on?"\n  ]\n}',
#  27: '{\n    "questions": [\n        "What is the publication year of the book \'The Mote in God\'s Eye\'?",\n        "Who co-authored the book \'The Mote in God\'s Eye\'?",\n        "In what series position does the book \'The Mote in God\'s Eye\' sit?",\n        "How many pages are in the book \'The Mote in God\'s Eye\'?",\n        "What is the target audience for the book \'The Mote in God\'s Eye\'?"\n    ]\n}',
#  28: '{\n  "questions": [\n    "What is the publication year of the book Altered Carbon?",\n    "In what position is the book Altered Carbon part of a series?",\n    "Who is the target audience for the book Altered Carbon?",\n    "How many pages are in the edition of Altered Carbon?",\n    "What genre categorizations does the book Altered Carbon belong to?"\n  ]\n}',
#  29: '{\n  "questions": [\n    "What is the publication year of the book \'Revelation Space\'?",\n    "Which two subgenres are associated with the book \'Revelation Space\'?",\n    "What is the page count of the book \'Revelation Space\'?",\n    "Who is the author of the book \'Revelation Space\'?",\n    "What type of technology does the book \'Revelation Space\' focus on?"\n  ]\n}',
#  30: '{\n  "questions": [\n    "What is the publication year of the book \'Chasm City\'?",\n    "Who wrote the book \'Chasm City\'?",\n    "In what position is \'Chasm City\' located within the Revelation Space universe series?",\n    "How many pages does the book \'Chasm City\' contain?",\n    "For which target audience is the book \'Chasm City\' primarily intended?"\n  ]\n}',
#  31: '{\n  "questions": [\n    "What is the publication year of Perdido Street Station?",\n    "Who is the author of the book Perdido Street Station?",\n    "In what series does the book Perdido Street Station belong, and what is its position within the series?",\n    "What are the primary subgenres associated with the book Perdido Street Station?",\n    "At what page count can readers find Perdido Street Station?"\n  ]',
#  32: '{\n  "questions": [\n    "What is the page count of the book \'The Scar\'?",\n    "Who is the author of the book \'The Scar\' and what is the series it belongs to?",\n    "In which year was the book \'The Scar\' published?",\n    "What type of content warnings does the book \'The Scar\' have, according to its metadata?",\n    "At what position in the Bas-Lag / New Crobuzon series does \'The Scar\' fall?"\n  ]\n}',
#  33: '{"questions": ["What is the publication year of the book \'Iron Council\'?", "Which publisher released \'Iron Council\' in 2004?", "Who is the author of the book \'Iron Council\'?", "What genre classification would you categorize the themes of \'Iron Council\' under?", "How many pages are in the hardcover edition of \'Iron Council\'?"]}',
#  34: '{\n  "questions": [\n    "What is the publication year of this book?",\n    "How many pages does this book contain?",\n    "Who is the author of \'American Gods\'?",\n    "What is the target audience for readers of \'American Gods\'?",\n    "In what subgenres can the book \'American Gods\' be classified?"\n  ]\n}',
#  35: '{\n  "questions": [\n    "What are the subgenres associated with this book?",\n    "For which series is this book considered a part of, and what position does it hold?",\n    "How many pages are in this book, according to its metadata?",\n    "In what year was this book first published, as indicated by its metadata?",\n    "Who is the publisher that released this book, and how do they collaborate with HarperCollins?"\n  ]\n}',
#  36: '{\n  "questions": [\n    "What is the publication year of the book Good Omens?",\n    "Which publisher released the book Good Omens, and what is their respective imprint?",\n    "How many pages does the book Good Omens have?",\n    "What are the target audience for readers of the book Good Omens?",\n    "What is the estimated page count range of books in this series, given that Good Omens is at position 0?"\n  ]\n}',
#  37: '{"questions": ["What is the publication year of the book Small Gods?", "What is the page count of the book Small Gods?", "For what target audience is the book Small Gods intended?", "In which series position does the book Small Gods fall within?", "What are some of the subgenres associated with the book Small Gods?"]}\n\nThese questions can be answered solely based on the provided record, and they cover various aspects of metadata such as publication details, target audience, series placement, and genre classification.',
#  38: '{"questions": [\n"Who is the author of \'The Colour of Magic\'?",\n"What is the publication year of the book \'The Colour of Magic\'?",\n"In what position does \'The Colour of Magic\' sit within the Discworld series?",\n"What are the subgenres associated with \'The Colour of Magic\', and how would you categorize them?", \n"Who is the target audience for reading \'The Colour of Magic\' as recommended by the publisher?", \n"What is the page count of \'The Colour of Magic\'?"]',
#  39: '{\n    "questions": [\n        "What is the publication year of the book \'Guards! Guards!\'?",\n        "Who is the author of the Discworld series, to which \'Guards! Guards!\' belongs?",\n        "In what position does \'Guards! Guards!\' stand within the Discworld series?",\n        "What are some of the subgenres associated with \'Guards! Guards!\', according to the book\'s metadata?",\n        "At what page count is the book \'Guards! Guards!\' printed?"\n    ]\n}',
#  40: '{\n    "questions": [\n        "What is the title of the book and who is its author?",\n        "In which position within a series does \'The Lies of Locke Lamora\' stand?",\n        "What genres and themes are primarily associated with this book, according to the metadata?",\n        "How many pages long is the book, as stated in the publication information?",\n        "For what type of audience is the book targeted, based on the provided metadata?"\n    ]\n}',
#  41: '{"questions": ["What is the publication year of the book Red Seas Under Red Skies?", "Who is the author of this book and which series does it belong to?", "How many pages does the book have?", "To what target audience is the book primarily aimed at?", "In what subgenres can the book be classified?"]}',
#  42: '{\n    "questions": [\n        "What is the title of the book being evaluated?",\n        "Who is the author of the book, and what series does it belong to?",\n        "In what position is The Republic of Thieves within its respective series?",\n        "Which subgenres categorize The Republic of Thieves, and how many are present?",\n        "What themes are central to understanding the book\'s content?"\n    ]\n}',
#  43: '{"questions": ["What is the publication year of the book \\"The Blade Itself\\"?", "Who is the author of this book?", "In what position is \'The Blade Itself\' placed within its series, \\"First Law\\"?", "How many pages are in the edition of \'The Blade Itself\'?", "At what pace does the reading of \'The Blade Itself\' generally fall?"]}',
#  44: '{\n  "questions": [\n    "What is the publication year of the book?",\n    "Who is the author of this book, and what is the series it belongs to?",\n    "How many pages does the book contain, and what type of content warnings should readers be aware of?",\n    "In which subgenres does this fantasy novel belong, and to what extent does it focus on technology?",\n    "What are some of the key themes explored in this epic fantasy novel?"\n  ]\n}',
#  45: '{"questions": ["What is the publication year of the book \'Last Argument of Kings\'?", "How many pages does the book \'Last Argument of Kings\' contain?", "Which publisher released the book \'Last Argument of Kings\'?", "For which age group is the target audience of the book \'Last Argument of Kings\'?", "What are the primary subgenres associated with the book \'Last Argument of Kings\'?"]}',
#  46: '{\n  "questions": [\n    "What is the publication year of the book The Gunslinger?",\n    "Who is the author of the book The Gunslinger?",\n    "In what position is The Gunslinger within its respective series?",\n    "How many pages are in the book The Gunslinger?",\n    "By which publisher was The Gunslinger initially released?"\n  ]\n}',
#  47: '{"questions": ["What is the position of this book within its series?", "What are some of the subgenres associated with this book?", "At what page count was this book published?", "Who is the publisher of this book\'s initial publication edition?", "In what year was this book first released?"]}',
#  48: '{\n  "questions": [\n    "What is the series position of the book within its overall series?",\n    "Which subgenres are commonly associated with this book, and how would you categorize them?",\n    "To what extent does the publication year influence the content or themes of this book, according to available metadata?",\n    "How does the target audience for this book align with its content and themes, as indicated by metadata?",\n    "What tone can be inferred from the publisher\'s description of the writing style used in this book?"\n  ]\n}',
#  49: '{"questions": [\n    "What is the page count of the book \'Wizard and Glass\'?",\n    "In what year was the book \'Wizard and Glass\' published by Grant?",\n    "Who is the target audience for the book \'Wizard and Glass\'?",\n    "What are the primary themes present in the book \'Wizard and Glass\'?",\n    "What type of setting does Roland\'s story take place within, as described in the summary?"\n],',
#  50: '{\n  "questions": [\n    "What is the page count of the book, and was it published by a single publisher or multiple publishers?",\n    "In what year was this book first published, and which subgenres does it belong to?",\n    "Who is the target audience for this book, and what is its estimated age range?",\n    "How would you describe the tone of the book, and are there any specific themes explored in the story?",\n    "Is there a particular type of technology that is emphasized or featured within the narrative, such as communication media or period-appropriate tools?"\n  ]\n}',
#  51: '{"questions":\n["What is the publication year of The Stand?",\n"Who is the author of the book The Stand?",\n"The Stand is classified under which subgenres?",\n"What is the estimated page count of the book?",\n"In what year was the book The Stand published by Doubleday?"]}',
#  52: '{"questions": ["What is the publication year of the book Dracula?", "Who is the author of the book Dracula?", "What type of writing style was used by Bram Stoker in Dracula?", "In what setting does the majority of the story take place?", "What are some subgenres that describe the book Dracula?"]}',
#  53: '{"questions":\n["What is the primary genre of the book \'Frankenstein\', as indicated by its metadata?", \n"Who is the author credited for writing the book \'Frankenstein\' according to its metadata?",\n"What position does \'Frankenstein\' hold within a series, based on its metadata?", \n"What are the subgenres associated with the book \'Frankenstein\', according to its metadata?", \n"Is the target audience for the book \'Frankenstein\' explicitly stated in its metadata as adult or classic literature fans?"}',
#  54: '{"questions": [\n"Is the book part of a series, and if so, what is its position within that series?",\n"Are there any genres listed for this book, and if so, how many?",\n"What are the primary themes explored in this novel, as identified by the author?",\n"How long was the book published for, as measured in the number of pages?", \n"Who is the target audience for this work, according to the publisher\'s description?"',
#  55: '{\n  "questions": [\n    "What is the estimated number of pages in this book?",\n    "In what year was this dystopian novel first published?",\n    "Who is the author of this classic work of political fiction?",\n    "What are the main themes explored in this totalitarian state novel?",\n    "Is this book suitable for readers under 18 years old?"\n  ]\n}',
#  56: '{"questions": ["What is the publication year of Fahrenheit 451?", "Who is the author of Fahrenheit 451?", "How many pages does the book Fahrenheit 451 have?", "In what type of future setting is the story of Fahrenheit 451 set?", "Is Fahrenheit 451 targeted towards a specific audience?"]}',
#  57: '{"questions": ["What is the publication year of \'Something Wicked This Way Comes\'?", \n"Who is the author of the book \'Something Wicked This Way Comes\'?",\n"What is the target audience for the book \'Something Wicked This Way Comes\'?",\n"What genre categories does the book \'Something Wicked This Way Comes\' belong to?",\n"Is there a series that includes the book \'Something Wicked This Way Comes\', and if so, what is its position within the series?"]}',
#  58: '{\n  "questions": [\n    "What is the page count of this book?",\n    "Which publisher released \'The Martian\'?",\n    "In what year was \'The Martian\' first published?",\n    "Who is the author of \'The Martian\'?",\n    "Is \'The Martian\' a part of any series?"\n  ]\n}',
#  59: '{"questions": ["What is the author of the book \'Project Hail Mary\'?", "In what year was the book \'Project Hail Mary\' published by Ballantine Books?", "Who is the target audience for the book \'Project Hail Mary\'?", "How many pages does the book \'Project Hail Mary\' have in total?", "What are the primary subgenres of the book \'Project Hail Mary\'?"]}\n\nThese questions can be answered solely from the provided record and focus on metadata aspects, such as authorship, publication date, target audience, page count, and subgenres.',
#  60: '{"questions": ["What is the publication year of \'The Expanse: Caliban\'s War\'?", \n"Who is the author of \'The Expanse: Caliban\'s War\'?", \n"What series position does \'The Expanse: Caliban\'s War\' hold in The Expanse series?", \n"What are the primary subgenres associated with \'The Expanse: Caliban\'s War\'? ", \n"What is the page count of \'The Expanse: Caliban\'s War\'?"}]',
#  61: '{\n  "questions": [\n    "What is the publication year of the book \'Abaddon\'s Gate\'?",\n    "Who is the author of the book series \'The Expanse\', which includes \'Abaddon\'s Gate\'?",\n    "In what position does \'Abaddon\'s Gate\' stand within its respective series, \'The Expanse\'?",\n    "What are the primary subgenres associated with the book \'Abaddon\'s Gate\'?",\n    "What is the approximate page count of the book \'Abaddon\'s Gate\'?"\n  ]\n}',
#  62: '{\n    "questions": [\n        "What is the publication year of \'Cibola Burn\', and was it published by a major publisher?",\n        "In what position does \'Cibola Burn\' stand within The Expanse series, and by whom was it written?",\n        "What are the subgenres associated with \'Cibola Burn\', and how does its target audience fit into this classification?",\n        "How many pages does \'Cibola Burn\' contain, and was it originally published as a hardcover book?",\n        "Is there a notable focus on terraforming or conflict technology in \'Cibola Burn\', and if so, is it the primary technology focus of The Expanse series?"\n    ]\n}',
#  63: '{"questions": [\n"Is this book part of a series, and if so, what is the title of that series?",\n"What is the publication year of this book, as indicated on its metadata record?",\n"The page count of this book is 536 pages, which suggests that it falls into which category of book length?",\n"This book was published by Orbit Books, which is part of which larger publishing house?",\n"Is this book targeted towards a specific age range or demographic group, according to the metadata provided?"',
#  64: '{"questions": [\n"Is this book part of a series, and if so, what is its position within the series?",\n"The book\'s target audience includes adult readers interested in science fiction.",\n"What is the estimated page count for this book?",\n"This publication was released by Orbit Books in 2017.",\n"What genre categories does the book belong to?"',
#  65: '{\n  "questions": [\n    "What is the publication year of the book \'Tiamat\'s Wrath\'?",\n    "How many pages does the book \'Tiamat\'s Wrath\' contain?",\n    "In what series position does \'Tiamat\'s Wrath\' stand among the books in The Expanse series?",\n    "Who is the author of the book \'Tiamat\'s Wrath\', and what genre does the book belong to?",\n    "What are some content warnings that readers should be aware of while reading \'Tiamat\'s Wrath\'?"\n  ]\n}',
#  66: '{"questions": [\n"Is this book part of a series, and if so, what is the position of this book within that series?",\n"This book\'s subgenres include which specific categories?",\n"What are the major themes explored in this book, according to its metadata?",\n"The page count of this book is ", \n"This book was published by ", \n"Is this book primarily intended for a young adult audience?"]',
#  67: '{"questions":\n["What is the publication year of the book \'Storm Front\'?",\n"What genre category does the book \'Storm Front\' belong to?",\n"Who is the target audience for reading \'Storm Front\'?",\n"What type of narrative style is used by the author Jim Butcher in \'Storm Front\'?",\n"What theme or subject matter is explicitly stated as a major concern in the book \'Storm Front\'?"]',
#  68: '{"questions": ["What is the publication year of the book \'Fool Moon\'?", "In what series position does \'Fool Moon\' fit within the Dresden Files?", "How many pages are in the hardcover edition of \'Fool Moon\'?", "Who is the target audience for the adult fantasy readers of \'Fool Moon\'?", "What are some of the subgenres associated with \'Fool Moon\'?"]}',
#  69: '{"questions": ["What is the publication year of the book \'Grave Peril\'?", "In what position does the book \'Grave Peril\' sit within its series, The Dresden Files?", "What are the primary genres associated with the book \'Grave Peril\'?", "How many pages does the book \'Grave Peril\' have?", "Who is the author of the book \'Grave Peril\'?"]}',
#  70: '{"questions": ["What is the series position of the book within The Dresden Files series?", "Who is the author of the book Summer Knight?", "What is the publication year of the book Summer Knight?", "In what subgenres can the book Summer Knight be classified?", "How many pages are in the book Summer Knight?"]}',
#  71: '{"questions": ["What is the publication year of \'Blood Rites\'?", "In what series position does \'Blood Rites\' fall within?", "How many pages are in the book \'Blood Rites\'?", "Who is the author of the book \'Blood Rites\'?", "What type of setting is present in \'Blood Rites\'?"]}\n\nThese questions can be answered solely from the provided record and are focused on metadata about the book.',
#  72: '{\n  "questions": [\n    "What is the position of \'Dead Beat\' within \'The Dresden Files\' series?",\n    "In what year was \'Dead Beat\' published?",\n    "How many pages does the book \'Dead Beat\' have?",\n    "Who is the target audience for \'Dead Beat\', according to its metadata?",\n    "What type of technology focus is present in \'Dead Beat\', as described by its author\'s intent?"\n  ]\n}',
#  73: '{\n  "questions": [\n    "What is the series position of \'Proven Guilty\' within The Dresden Files?",\n    "Who is the author of \'Proven Guilty\', and what is the publication year of this book?",\n    "How many pages are in the book \'Proven Guilty\', and what is its target audience?",\n    "In which subgenres is \'Proven Guilty\' categorized, and what themes does it explore?",\n    "What type of setting does \'Proven Guilty\' have, as described by the author?"\n  ]\n}',
#  74: '{\n    "questions": [\n        "What is the publication year of the book \'Changes\'?",\n        "Who is the author of the book \'Changes\', and what is the series position within The Dresden Files?",\n        "How many pages does the book \'Changes\' contain, and in what subgenres is it classified?",\n        "What are the primary themes present in the book \'Changes\', as stated by the author?",\n        "What type of tone can be expected from reading the book \'Changes\', according to its metadata?"\n    ]\n}',
#  75: '{"questions": [\n    {"text": "What is the publication year of the book Skin Game?", \n     "answer_key": "2014"},\n    {"text": "Which publisher released the book Skin Game?", \n     "answer_key": "Roc / Penguin"},\n    {"text": "How many pages does the book Skin Game contain?", \n     "answer_key": "448"},\n    {"text": "For which series is the book Skin Game part of?", \n     "answer_key": "The Dresden Files"},\n    {"text": "What genre classification would best describe the book Skin Game?", \n     "answer_key": "Urban fantasy; Heist fantasy"}\n]}',
#  76: '{\n  "questions": [\n    "What is the publication year of \'The Hunger Games\'?",\n    "Who is the author of \'The Hunger Games\' and what is the series position?",\n    "How many pages does the book \'The Hunger Games\' contain?",\n    "In what genres is \'The Hunger Games\' primarily classified?",\n    "Is the target audience for \'The Hunger Games\' specifically defined as young adult readers?"\n  ]\n}',
#  77: '{"questions": ["What is the publication year of the book \'Catching Fire\'?", "Who is the author of the series and book \'Catching Fire\'? ", "In what position does the book \'Catching Fire\' fall within its respective series?", "What are some subgenres associated with the book \'Catching Fire\'? ", "How many pages does the book \'Catching Fire\' have?"]}',
#  78: '{"questions":\n    [\n        "What is the publication year of \'Mockingjay\', a book in The Hunger Games series?",\n        "For what age range is \'Mockingjay\' primarily intended, according to its publisher?",\n        "In terms of pacing, how would one describe the tempo of \'Mockingjay\'?",\n        "Which writing style can readers expect when reading \'Mockingjay\', as indicated by the author\'s choice for narrative voice?",\n        "What type of technology is highlighted in the dystopian world of Panem, according to the book\'s content warnings?"',
#  79: '{"questions": [\n  "What is the number of pages in the book Divergent?",\n  "In what year was the book Divergent published?",\n  "Who is the author of the book Divergent?",\n  "How many books are part of the Divergent Trilogy series, and what is their order?", \n  "Which subgenres does the book Divergent belong to?" \n]}',
#  80: '{"questions":\n["What is the page count of the book \'Insurgent\'?", \n"Who is the author of the book \'Insurgent\' and what genre(s) does she write in?", \n"What series does the book \'Insurgent\' belong to and its position within that series?", \n"In what year was the book \'Insurgent\' published and by which publisher?", \n"What are some content warnings associated with reading this young adult dystopian novel?"]',
#  81: '{\n  "questions": [\n    "What is the publication year of the book Allegiant?",\n    "How many pages does the book Allegiant have?",\n    "For which series, as part of which position, was Allegiant published?",\n    "Which subgenres categorize Allegiant in terms of genre classification?",\n    "What are some of the themes explored in the book Allegiant?"\n  ]\n}',
#  82: '{"questions": [\n  "What is the page count of the book Annihilation?",\n  "In what year was the book Annihilation published?",\n  "For which audience is the book Annihilation primarily intended?",\n  "How would you describe the tone of the book Annihilation?",\n  "What type of technology are featured in the setting of Area X, as described in the book\'s metadata?"\n]}',
#  83: '{"questions": ["What is the publication year of the book \'Authority\'?", "Who is the author of the book \'Authority\'?", "What series does the book \'Authority\' belong to and its position in the series?", "Are there any content warnings for the book \'Authority\' that include psychological distress?", "What is the estimated page count of the book \'Authority\'?"]}',
#  84: '{"questions": [\n"Is this book part of a larger series?", \n"What are the primary genres associated with this book?", \n"Which themes does this book explore according to its metadata?", \n"Can readers expect a moderate pacing when engaging with this book?", \n"Are there any specific warnings about content or subject matter that should be considered by potential readers?"',
#  85: '{"questions": ["What is the publication year of this book?", "For what audience is this book primarily intended?", "How many pages does this book have?", "Who is the author of this book?", "In what genre does \'The City & The City\' belong?"]}',
#  86: '{"questions":\n["What is the number of pages in the book \'World War Z\'?", \n"Who is the author of the book \'World War Z\'?",\n"How many series positions does the book \'World War Z\' hold?", \n"What are the subgenres associated with the book \'World War Z\'?", \n"What type of writing style is used in the book \'World War Z\'?"]}',
#  87: '{"questions": ["What is the page count of \'The Passage\'?", "In what year was \'The Passage\' published?", "Who is the author of \'The Passage\'?", "What type of genre classification would you categorize \'The Passage\' under? (Select all that apply)", "Is \'The Passage\' considered a target audience for adult/speculative readers only?"]}',
#  88: '{"questions": ["What is the publication year of \'The Twelve\'?", "How many pages does the book \'The Twelve\' contain?", "Who is the author of \'The Twelve\'?", "In what position is \'The Twelve\' within The Passage Trilogy?", "What are the genres associated with \'The Twelve\'?"]}',
#  89: '{"questions": ["What is the publication year of The City of Mirrors?", "Who is the author of The Passage Trilogy, and what is the position of this book within the series?", "In what genre categories is The City of Mirrors classified?", "What themes are explored in The City of Mirrors according to the provided metadata?", "What type of technology focus can be found in the post-apocalyptic world of The City of Mirrors?"]}',
#  90: '{\n    "questions": [\n        "What is the publication year of The Silmarillion?",\n        "Who is the author of The Silmarillion and what is the name of the series they belong to?",\n        "How many pages does the book contain?",\n        "For which target audience was The Silmarillion published, and by whom?",\n        "What are some of the key themes explored in The Silmarillion?"\n    ]\n}',
#  91: '{"questions": [\n"Is the book \'Unfinished Tales\' a part of the Middle-earth Legendarium series?",\n"The publication year of the book \'Unfinished Tales\' is 1980.",\n"Does the target audience for the book \'Unfinished Tales\' include adult readers and Tolkien scholars?",\n"What is the approximate page count of the book \'Unfinished Tales\'?",\n"Is the tone of the book \'Unfinished Tales\' characterized as mythic, scholarly, and reflective?"',
#  92: '{"questions": [\n"Is \'The Once and Future King\' a part of an existing series, and if so, what is its position within that series?",\n"The primary themes of the book include education and ethics, power and responsibility, love and betrayal, and idealism vs realpolitik. Which theme(s) does the book focus on most heavily?",\n"How would you categorize the tone of \'The Once and Future King\', considering it includes elements of wryness, romanticism, and tragedy?",\n"What is the approximate page count of the book in its original publication edition?",\n"Which publisher released \'The Once and Future King\' in both the UK and the US?"',
#  93: '{\n  "questions": [\n    "What is the publication year of the book \'The Eye of the World\'?",\n    "What genre classification best describes \'The Wheel of Time\' series?",\n    "In what position within their respective series does \'The Eye of the World\' fall?",\n    "How many pages are contained within the book \'The Eye of the World\'?",\n    "Who is the publisher responsible for releasing \'The Eye of the World\' in the United States and the United Kingdom?"\n  ]\n}',
#  94: '{\n  "questions": [\n    "What is the publication year of the book \'The Great Hunt\'?",\n    "Who is the author of the series \'The Wheel of Time\' and the individual book \'The Great Hunt\'?",\n    "In what position does the book \'The Great Hunt\' stand within the \'Wheel of Time\' series?",\n    "How many pages are in the book \'The Great Hunt\'?",\n    "What is the target audience for which the book \'The Great Hunt\' is recommended?"\n  ]\n}',
#  95: '{"questions": [\n"Is The Dragon Reborn part of a series that is considered epic fantasy?", \n"What is the page count of The Dragon Reborn?", \n"In what year was The Dragon Reborn published?", \n"For what target audience is The Dragon Reborn generally recommended?", \n"What is the primary focus of technology in this book?", \n"Are there any content warnings for this book?", \n"Is the writing style used in The Dragon Reborn primarily third-person limited?", \n"What are some key themes explored in The Dragon Reborn?", \n"What is the tone predominantly associated with The Dragon Reborn?", \n"In what subgenres does The Dragon Reborn fall under?"]}',
#  96: '{"questions": ["What is the series name of this book?", "Which author wrote The Shadow Rising?", "In what position is The Shadow Rising within its respective series?", "How many pages does the book contain?", "When was The Shadow Rising published?"]}',
#  97: '{\n    "questions": [\n        "What is the page count of \'The Fires of Heaven\'?",\n        "Which publisher released \'The Fires of Heaven\' in the United Kingdom?",\n        "At what position in its series is \'The Fires of Heaven\' published?",\n        "What are the subgenres associated with \'The Fires of Heaven\', according to the book\'s metadata?",\n        "In what year was \'The Fires of Heaven\' originally published?"\n    ]\n}',
#  98: '{"questions": ["What is the publication year of the book \'Lord of Chaos\'?", "Who is the author of the book series \'The Wheel of Time\'? \'book_name\': \'Lord of Chaos\', \'author_name\': \'Robert Jordan\'", "In what position is the book \'Lord of Chaos\' within its respective series?", "What is the page count of the book \'Lord of Chaos\'? \'page_count\': 720", "Which publisher released the book \'Lord of Chaos\' in the United States?"}}',
#  99: '{"questions": ["What is the page count of the book \'A Crown of Swords\'?", "In what publication year was \'A Crown of Swords\' released?", "Who is the author of the series and book \'A Crown of Swords\'? ", "In which position within the series does \'A Crown of Swords\' fall?", "What subgenres are associated with the book \'A Crown of Swords\'?"]}',
#  100: '{"questions": ["What is the publication year of the book?", "Who is the author of the book?", "In what position is the book within its series?", "How many pages does the book contain?", "What publisher originally released the book in the United States?"]}',
#  101: '{\n  "questions": [\n    "What is the publication year of the book \'Winter\'s Heart\', and which regions it was published in?",\n    "Who is the author of the book \'Winter\'s Heart\', and what genre category does this work fall under?",\n    "In what position is \'Winter\'s Heart\' located within The Wheel of Time series?",\n    "What are the primary genres associated with the book \'Winter\'s Heart\', and what themes do they commonly explore in epic fantasy works like this one?",\n    "How many pages are there in the book \'Winter\'s Heart\', and to which audience is it primarily targeted?"\n  ]\n}',
#  102: '{"questions": ["What is the publication year of the book \'Crossroads of Twilight\'?", "Who is the author of \'Crossroads of Twilight\'?", "How many pages does the book \'Crossroads of Twilight\' have?", "In what year was the book \'Crossroads of Twilight\' first published?", "By whom was the book \'Crossroads of Twilight\' originally published?"]}',
#  103: '{\n  "questions": [\n    "What is the page count of the book \'Knife of Dreams\'?",\n    "Which publisher released \'Knife of Dreams\' in the United States and the United Kingdom?",\n    "In what year was \'Knife of Dreams\' published?",\n    "For which series does \'Knife of Dreams\' belong, and in what position is it within that series?",\n    "What genre classification can be associated with the book \'Knife of Dreams\'?"\n  ]\n}',
#  104: '{"questions": [\n"Is the book \'The Gathering Storm\' part of a series?",\n"Who are the authors of this book?",\n"What is the publication year of \'The Gathering Storm\'?",\n"What genre categories does the book belong to?",\n"How many pages does the book \'The Gathering Storm\' have?"\n]}',
#  105: '{\n  "questions": [\n    "What is the book title of the 13th installment in The Wheel of Time series?",\n    "Who are the co-authors of Towers of Midnight, and what genre(s) does their work belong to?",\n    "In what year was Towers of Midnight published by Tor Books and Orbit Books?",\n    "How many pages long is the book, Towers of Midnight?",\n    "To whom would you recommend reading Towers of Midnight, as indicated by its target audience?"\n  ]\n}',
#  106: '{"questions": ["What is the total page count of book \'A Memory of Light\'?", "Who are the authors credited for \'A Memory of Light\'?", "In what position within the series is \'A Memory of Light\' published?", "Which subgenres categorize \'A Memory of Light\'?", "What are the primary themes explored in \'A Memory of Light\'?"]}',
#  107: '{"questions": ["What is the publication year of the book Elantris?", "Who is the publisher of the book Elantris?", "In what year was the book Elantris first published?", "To whom is the target audience of the book Elantris specified?", "How many pages are in the book Elantris?"}}',
#  108: '{"questions": ["What is the publication year of Warbreaker?", \n"Who is the author of Warbreaker?", \n"What is the page count of Warbreaker?", \n"In what genre category does Warbreaker primarily belong?", \n"To which book series and position is Warbreaker part of?"]}',
#  109: '{"questions": [\n"Was the book \'Starsight\' written by Brandon Sanderson?", \n"What is the position of the book \'Starsight\' within its series?", \n"Does the book \'Starsight\' belong to the subgenre Science fiction and YA sci-fi?", \n"For which audience is the book \'Starsight\' primarily targeted?", \n"How many pages does the book \'Starsight\' have?"',
#  110: '{"questions": [\n"Was this book part of a series?", \n"Can you identify the target audience for this young adult science fiction novel?", \n"What is the estimated page count of this publication?", \n"In what year was Cytonic published by Delacorte Press?", \n"Are there any content warnings associated with reading this book?"',
#  111: '{"questions": ["What is the page count of the book \'To Sleep in a Sea of Stars\'?", "Who is the author of the book \'To Sleep in a Sea of Stars\'?", "In what year was the book \'To Sleep in a Sea of Stars\' published by Tor Books?", "What is the target audience for the book \'To Sleep in a Sea of Stars\'?", "How many pages long is the book \'To Sleep in a Sea of Stars\'?"]}',
#  112: '{"questions": ["What is the book\'s publication year?", "Who is the author of the book \'Eragon\'?", "In what series does \'Eragon\' belong and where is it positioned?", "What are the primary themes associated with this book?", "How many pages does the hardcover edition of \'Eragon\' contain?"]}',
#  113: '{\n    "questions": [\n        "What is the title of the second book in The Inheritance Cycle series?",\n        "Who wrote the book \'Eldest\' and what is their occupation?",\n        "How many pages does the book \'Eldest\' contain?",\n        "In what year was the book \'Eldest\' first published?",\n        "For which age group is the book \'Eldest\' primarily intended?"\n    ]\n}',
# ...
#  152: '{\n  "questions": [\n    "What is the publication year of the book \'The Dispossessed\'?",\n    "How many pages does the book \'The Dispossessed\' have?",\n    "What genre classification(s) best describes the book \'The Dispossessed\'?",\n    "Who is the author of the book \'The Dispossessed\', and what is their pen name?",\n    "For which target audience was the book \'The Dispossessed\' intended?"\n  ]\n}',
#  153: '{"questions": ["What is the series name of the book \'A Wizard of Earthsea\'?", "In what year was the book \'A Wizard of Earthsea\' published by Parnassus Press?", "Who is the author of the book \'A Wizard of Earthsea\'?", "How many pages does the book \'A Wizard of Earthsea\' contain?", "What age range is the target audience for readers of \'A Wizard of Earthsea\'?"]}',
#  154: '{\n  "questions": [\n    "What is the publication year of the book \'The Tombs of Atuan\'?",\n    "Who is the author of the series \'Earthsea Cycle\', which includes \'The Tombs of Atuan\'?",\n    "In what position is \'The Tombs of Atuan\' within the \'Earthsea Cycle\' series?",\n    "What are some of the themes explored in \'The Tombs of Atuan\', as identified by the author?",\n    "How many pages does the book \'The Tombs of Atuan\' contain?"\n  ]\n}',
#  155: '{"questions": ["What is the title of the book?", "Who is the author of this book?", "In what position does this book sit within its respective series?", "How many pages does the book have?", "In what year was the book first published?"]}',
#  156: '{\n    "questions": [\n        "What is the series position of this book within the Earthsea Cycle?"\n    ],\n    "questions": [\n        "In what year was this book published?"\n    ],\n    "questions": [\n        "How many pages does this book contain?"\n    ],\n    "questions": [\n        "Who is the author of this book?"\n    ],\n    "questions": [\n        "What genre categories best describe the subgenres listed for this book?"\n    ]}',
#  157: '{"questions": [\n"Is \'Tales from Earthsea\' a collection of short and linked tales set in the world of Earthsea?",\n"The number of pages in \'Tales from Earthsea\' is",\n"What was the publication year for \'Tales from Earthsea\'?",\n"To whom is the target audience for \'Tales from Earthsea\' primarily directed?",\n"What type of technology focus can be found in the magical systems of \'Tales from Earthsea\'?"',
#  158: '{"questions": ["What is the publication year of \'The Other Wind\'?", "Which author wrote \'The Other Wind\'? ", "What is the target audience for \'The Other Wind\'?", "How many pages does \'The Other Wind\' have?", "What are the subgenres of \'The Other Wind\'?" ]}',
#  159: '{"questions": ["What is the series to which The Golden Compass belongs?", \n"Which subgenres does The Golden Compass primarily belong to?", \n"What is the target audience for The Golden Compass book?", \n"How many pages does the book contain?", \n"In what year was The Golden Compass first published?"]}',
#  160: '{\n    "questions": [\n        "What is the publication year of \'The Subtle Knife\' book?",\n        "For what target audience is \'The Subtle Knife\' book intended?",\n        "How many pages does \'The Subtle Knife\' book contain?",\n        "In which position is \'The Subtle Knife\' within its respective series?",\n        "What are some of the subgenres associated with \'The Subtle Knife\' book?"\n    ]\n}',
#  161: '{\n  "questions": [\n    "What is the publication year of \'The Amber Spyglass\', and how many pages does it have?",\n    "Who is the author of \'The Amber Spyglass\', and what series does this book belong to?",\n    "In which position within its series does \'The Amber Spyglass\' fall, according to the metadata?",\n    "What genres or subgenres is \'The Amber Spyglass\' classified under, based on the provided information?",\n    "Is the target audience of \'The Amber Spyglass\' primarily focused towards young adult readers, and what genre-specific categories can be found within this metadata?"\n  ]}',
#  162: '{\n  "questions": [\n    "What is the title of the book and its position within a series?",\n    "What genres does this book belong to, according to the provided metadata?",\n    "In what themes can readers expect to find themselves while reading this book?",\n    "How many pages are in the hardcover edition of La Belle Sauvage?",\n    "In what year was La Belle Sauvage first published?"\n  ]\n}',
#  163: '{\n  "questions": [\n    "What is the series name of this book, and what is its position within that series?",\n    "In what subgenres is this book classified, according to its metadata?",\n    "How many pages does this book contain, as stated by its publisher?",\n    "Who is the target audience for this book, based on its metadata?",\n    "What is the tone of this book\'s writing style, as described by its author?"\n  ]\n}',
#  164: '{"questions": [\n"Is \'Jonathan Strange & Mr Norrell\' part of a larger series?",\n"Who is the author of the book",\n"What type of genre does the book belong to (e.g. Historical fantasy, Magical realism)?",\n"How many pages are in the book?",\n"When was the book published?"\n]}',
#  165: '{"questions": ["What is the publication year of the book \'Piranesi\'?", "What is the target audience for the book \'Piranesi\'?", "How many pages does the book \'Piranesi\' have?", "In what year was the book \'Piranesi\' published by its original publisher?", "Which subgenres are associated with the book \'Piranesi\'?"]}',
#  166: '{"questions": ["What is the target audience for this book according to its metadata?", "How many pages does the book have?", "In what year was this book first published?", "What style of writing is used in this book as described by its author?", "To what extent is technology emphasized in this book\'s setting?"]}',
#  167: '{\n  "questions": [\n    "What is the position of the Hogfather book within its respective series?",\n    "What genres and themes does this Discworld book belong to?",\n    "How many pages long is this edition of the book?",\n    "In what year was this book first published by N/A publisher?",\n    "Which audience type does this fantasy novel primarily cater to?"\n  ]\n}',
#  168: '{"questions": [\n"Is this book part of a series?",\n"Was Terry Pratchett the sole author of this book?",\n"What is the position of this book within its respective series?",\n"What genres or subgenres does this book belong to?",\n"What year did the publisher release this book?"\n]}',
#  169: '{\n  "questions": [\n    "What is the page count of the book \'Going Postal\'?",\n    "In what year was the book \'Going Postal\' published?",\n    "Who is the author of the book \'Going Postal\'?",\n    "What is the target audience for the book \'Going Postal\'?",\n    "How would you describe the tone of the book \'Going Postal\', based on the provided metadata?"\n  ]\n}',
#  170: '{"questions": ["What is the page count of the book Thud!", "In what year was the book Thud! published?", "Who is the target audience for the book Thud!", "How many books are in the Discworld series that includes Thud!", "What genre classification best describes the writing style of the book Thud!"]}',
#  171: '{\n    "questions": [\n        "What is the publication year of the book \'The Lion, the Witch and the Wardrobe\'?",\n        "Which publisher released the book \'The Lion, the Witch and the Wardrobe\' in 1950?",\n        "To what extent is the target audience for \'The Lion, the Witch and the Wardrobe\' described as children or fantasy readers?",\n        "What is the page count of the book \'The Lion, the Witch and the Wardrobe\', according to its metadata?",\n        "Which technology focus is depicted in the magical land of Narnia, as described in the book\'s metadata?"\n    ]\n}',
#  172: '{\n  "questions": [\n    "What is the page count of Prince Caspian?",\n    "In what year was Prince Caspian published by Geoffrey Bles?",\n    "To whom is Prince Caspian primarily targeted, according to the book\'s metadata?",\n    "Which subgenres categorize Prince Caspian within the world of children’s fantasy and Christian allegory?",\n    "How many pages long is the book Prince Caspian?"\n  ]\n}',
#  173: '{"questions": ["What is the publication year of the book?", \n"Who is the author of this book?",\n"What is the target audience for this book?", \n"How many pages does the book have?", \n"In what series does this book belong?"]}',
#  174: '{\n  "questions": [\n    "What is the publication year of the book \'The Silver Chair\'?",\n    "In what position does the book \'The Silver Chair\' stand within \'The Chronicles of Narnia\' series?",\n    "What are some of the subgenres associated with the book \'The Silver Chair\'?",\n    "How many pages are in the book \'The Silver Chair\'?",\n    "Who is the publisher of the book \'The Silver Chair\'?"\n  ]\n}',
#  175: '{"questions": ["What is the publication year of \'The Horse and His Boy\'?", "In what position does \'The Horse and His Boy\' fall within The Chronicles of Narnia series?", "What is the approximate page count of the book \'The Horse and His Boy\'? ", "Who is the target audience for the book \'The Horse and His Boy\'? ", "Is \'The Horse and His Boy\' considered to have a technological focus on pre-industrial base, magic systems, alchemy, or mechanical devices?"]}',
#  176: '{"questions": ["What is the publication year of The Magician’s Nephew?", "Who is the author of The Magician’s Nephew?", "How many pages does the book have?", "What type of content warnings does the book contain?", "In what series position does The Magician’s Nephew fall?"]}',
#  177: '{"questions": [\n"Is The Last Battle a part of \'The Chronicles of Narnia\' series?",\n"The publication year of the book is 1956.",\n"Which subgenres does the book belong to?",\n"What is the page count of The Last Battle?",\n"The target audience for this book includes both children and fantasy readers."\n]}',
#  178: '{\n  "questions": [\n    "What is the total page count of Watership Down?",\n    "In what year was Watership Down published by Rex Collings / Scribner?",\n    "What type of narrative style is used in Watership Down?",\n    "How many rabbits are part of the main group that flees their warren, according to the metadata provided?", // Note: This answer cannot be determined with the given data\n    "Is violence a content warning for Watership Down?"\n  ]\n}',
#  179: '{"questions": [\n  "The book \'The Black Company\' by Glen Cook was published in what year?",\n  "What is the approximate page count of \'The Black Company\' book?",\n  "Who is the narrator of \'The Black Company\', and what type of narration do they use?",\n  "What is the main focus of \'The Black Company\' from a technological standpoint?",\n  "To whom would you recommend \'The Black Company\' primarily, based on its target audience?"\n]}',
#  180: '{\n    "questions": [\n        "What is the publication year of Shadows Linger?",\n        "Which author wrote Shadows Linger, and what is their series position within The Black Company?",\n        "How many pages are in Shadows Linger?",\n        "In what genre does Shadows Linger primarily fall under, according to its subgenres?",\n        "Is Shadows Linger suitable for adult readers and fantasy fans?"\n    ]\n}',
#  181: '{\n    "questions": [\n        "What is the position of The White Rose within Glen Cook\'s series, The Black Company?",\n        "In what year was The White Rose published?",\n        "To what extent is violence depicted in The White Rose according to its content warnings?",\n        "Which subgenres categorize The White Rose, as per its metadata?",\n        "What is the target audience for which The White Rose is primarily intended, based on the publisher\'s information?"\n    ]\n}',
#  182: '{"questions": [\n"Is \'Gardens of the Moon\' part of the Malazan Book of the Fallen series?",\n"The publication year of \'Gardens of the Moon\' is",\n"What is the total number of pages in \'Gardens of the Moon\'?",\n"In what type of fantasy genre does \'Gardens of the Moon\' primarily fall?",\n"Who is the author of the book \'Gardens of the Moon\'?"]',
#  183: '{"questions": ["What is the series position of the book \'Deadhouse Gates\' within the Malazan Book of the Fallen series?", \n"Who is the author of the book \'Deadhouse Gates\'?", \n"What is the page count of the book \'Deadhouse Gates\'?", \n"In what year was the book \'Deadhouse Gates\' published?", \n"What is the target audience for the book \'Deadhouse Gates\'?"]}',
#  184: '{\n    "questions": [\n        "What is the publication year of the book \'Memories of Ice\'?",\n        "Who is the author of the book \'Memories of Ice\'?",\n        "In what position does the book \'Memories of Ice\' fall within its series, the Malazan Book of the Fallen?",\n        "How many pages are in the book \'Memories of Ice\'?",\n        "What is the intended audience for the book \'Memories of Ice\', according to the publisher?"\n    ]}',
#  185: '{\n  "questions": [\n    "What is the total page count of \'House of Chains\'?",\n    "In what year was \'House of Chains\' published by Bantam (UK)?",\n    "Which author wrote the book \'House of Chains\'?",\n    "To which series does \'House of Chains\' belong and in what position is it?",\n    "What subgenres categorize \'House of Chains\' as a part of?"\n  ]\n}',
#  186: '{\n  "questions": [\n    "What is the publication year of \'Midnight Tides\'?",\n    "For which series does \'Midnight Tides\' belong and what is its position within that series?",\n    "To whom is the book primarily targeted by the author, based on the publisher\'s information?",\n    "How many pages are there in \'Midnight Tides\'?",\n    "In which subgenres can \'Midnight Tides\' be classified?"\n  ]\n}',
#  187: '{\n  "questions": [\n    "What is the number of pages in the book The Bonehunters?",\n    "Who published \'The Bonehunters\' in both the UK and US markets?",\n    "In what position is \'The Bonehunters\' located within the Malazan Book of the Fallen series?",\n    "Which genres categorize \'The Bonehunters\' according to its subgenres?",\n    "What are some of the themes explored in the book The Bonehunters?"\n  ]\n}',
#  188: '{"questions": [\n"Does the book \'Reaper\'s Gale\' by Steven Erikson belong to the Malazan Book of the Fallen series?", \n"What is the page count of the book \'Reaper\'s Gale\'?", \n"Who is the publisher of the book \'Reaper\'s Gale\' in the UK and US?", \n"What is the target audience for the book \'Reaper\'s Gale\'? ", \n"How many pages are in the 7th installment of the Malazan Book of the Fallen series, titled \'Reaper\'s Gale\'? "\n]}',
#  189: '{\n  "questions": [\n    "What is the publication year of the book \'Toll the Hounds\'?",\n    "Which publisher released the book \'Toll the Hounds\' in the United States?",\n    "How many pages does the book \'Toll the Hounds\' contain?",\n    "What type of technology focus is prominent in the writing of \'Toll the Hounds\'?",\n    "Who is the author of the book \'Toll the Hounds\'?"\n  ]\n}',
#  190: '{"questions": ["What is the publication year of \'Dust of Dreams\'?", \n"Who is the author of the book \'Dust of Dreams\'?", \n"In what series position does \'Dust of Dreams\' fall within?", \n"What are the subgenres associated with the book \'Dust of Dreams\'?", \n"How many pages are in the book \'Dust of Dreams\'?"]}',
#  191: '{\n  "questions": [\n    "What is the publication year of \'The Crippled God\'?",\n    "Which publisher released \'The Crippled God\' in the UK and the US?",\n    "How many pages does the book \'The Crippled God\' have?",\n    "In what year was \'The Crippled God\' published?",\n    "For whom is the target audience of \'The Crippled God\' designated?"\n  ]\n}'}

# %% [markdown]
# #### The results are of course not fully consistent + the following gives errors.

# %%
'''final_results = []

for doc_id, questions in results.items():
    for q in questions:
        final_results.append((doc_id, q))

final_results[0]

df_results = pd.DataFrame(final_results, columns=['id', 'question'])
df_results.to_csv('data/ground-truth-retrieval.csv', index=False)
'''

# %% [markdown]
# ### ChatGPT cleaning script to fix the above and give a correct output.

# %%
import json, re, ast
import pandas as pd

def parse_any(text_or_obj):
    """Return a Python object from possibly-messy LLM output."""
    x = text_or_obj
    if isinstance(x, (list, dict)):
        return x
    if not isinstance(x, str):
        return None

    s = x.strip()
    # Strip ```json fences
    s = re.sub(r"^```(?:json)?\s*|\s*```$", "", s, flags=re.IGNORECASE|re.MULTILINE)
    # Normalize quotes
    s = s.replace("“","\"").replace("”","\"").replace("’","'").replace("‘","'")

    # Try direct JSON
    try:
        return json.loads(s)
    except Exception:
        pass

    # Try to extract the first [...] array
    m = re.search(r"\[(?:.|\n)*\]", s)
    if m:
        arr = m.group(0)
        try:
            return json.loads(arr)
        except Exception:
            try:
                return ast.literal_eval(arr)
            except Exception:
                pass

    # As a last resort, return the raw string
    return s

def normalize_questions(obj):
    """Always return List[str] of questions."""
    if obj is None: return []

    # Already a list
    if isinstance(obj, list):
        out = []
        for item in obj:
            if isinstance(item, str):
                out.append(item.strip())
            elif isinstance(item, dict) and "question" in item:
                out.append(str(item["question"]).strip())
        return [q for q in out if q]

    # Dict forms
    if isinstance(obj, dict):
        if "questions" in obj and isinstance(obj["questions"], list):
            return normalize_questions(obj["questions"])
        # keys like question1, question2, ...
        numbered = [obj[k] for k in sorted(obj) if k.lower().startswith("question")]
        if numbered:
            return [str(v).strip() if not isinstance(v, dict) else str(v.get("question","")).strip()
                    for v in numbered if v]
        # look for nested list
        for v in obj.values():
            n = normalize_questions(v)
            if n: return n
        return []

    # Raw string: split by newlines/bullets if needed
    if isinstance(obj, str):
        # Try to parse again as JSON array if it looks like one
        if obj.strip().startswith("["):
            try:
                return normalize_questions(json.loads(obj))
            except Exception:
                pass
        # Fallback: naive split (keeps only question-like lines)
        lines = [ln.strip(" -•\t") for ln in obj.splitlines()]
        return [ln for ln in lines if ln.endswith("?") and len(ln) > 3]

    return []

# Build a tidy dataframe
rows = []
for doc_id, raw in results.items():
    parsed = parse_any(raw)
    qs = normalize_questions(parsed)
    for q in qs:
        rows.append((doc_id, q))

df_results = pd.DataFrame(rows, columns=["id", "question"])

# Optional cleaning
df_results["question"] = (
    df_results["question"]
      .astype(str)
      .str.replace(r"\s+", " ", regex=True)
      .str.strip()
)

# Drop empties/very short entries
df_results = df_results[df_results["question"].str.len() > 5]

# Save safely (handles commas/newlines with proper quoting)
df_results.to_csv("data/ground-truth-retrieval.csv", index=False)

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Generate embeddings

# %%
import pandas as pd
df_question = pd.read_csv('data/ground-truth-retrieval.csv')

# %%
df_question.head()
# Out:
#    id                                           question
# 0   0     What is the publication year of the book Dune?
# 1   0  In what genre does the book Dune primarily bel...
# 2   0                Who is the author of the book Dune?
# 3   0  How many pages are in the hardcover edition of...
# 4   0  Which audience is the target demographic for t...

# %%
ground_truth = df_question.to_dict(orient='records')

# %%
ground_truth[0]
# Out:
# {'id': 0, 'question': 'What is the publication year of the book Dune?'}

# %%
from sentence_transformers import SentenceTransformer

model_name = 'multi-qa-MiniLM-L6-cos-v1'
model = SentenceTransformer(model_name)

# %%
from tqdm.auto import tqdm

vectors = []

for doc in tqdm(ground_truth):
    question = doc['question']
    vector = model.encode(question)
    vectors.append(vector)
# Out:
#   0%|          | 0/838 [00:00<?, ?it/s]

# %%
import numpy as np

vectors = np.array(vectors)

# %%
from minsearch import VectorSearch

vindex = VectorSearch(keyword_fields=['id'])
vindex.fit(vectors, ground_truth)

# %% [markdown]
# ### Retrieval evaluation

# %%
def minsearch_vector_search(vector, question):
    return vindex.search(
        vector,
        filter_dict={'question': question},
        num_results=5
    )

def question_text_vector(q):
    question = q['question']
    v_q = model.encode(question)

    return minsearch_vector_search(v_q, question)

# %%
question_text_vector(dict(
    question='What themes does the Dune series follow?'
))
# Out:
# [{'id': 0, 'question': 'In what genre does the book Dune primarily belong?'},
#  {'id': 0, 'question': 'Who is the author of the book Dune?'},
#  {'id': 0,
#   'question': 'Which audience is the target demographic for the book Dune?'},
#  {'id': 0, 'question': 'What is the publication year of the book Dune?'},
#  {'id': 112,
#   'question': 'What are the primary themes associated with this book?'}]

# %%
prompt_template = """
You are an assistant for helping people decide on which fantasy and sci-fi books to read. 
Answer the QUESTION based on the CONTEXT (book metadata from the provided database).
Use only the facts from the CONTEXT when answering the QUESTION.

QUESTION: {question}
CONTEXT: {context}
""".strip()
    

def build_prompt(query, search_results):
    context = ""
    
    for doc in search_results:
        context = context
    
    prompt = prompt_template.format(question=query, context=context).strip()
    return prompt

# %%
def llm(prompt):
    from ollama import chat
    from ollama import ChatResponse

    response: ChatResponse = chat(
        
        model='llama3.2:latest', 
        messages=[ {'role': 'user','content': prompt}]
        )
    
    return response.message.content

# %%
def rag(query: dict) -> str:
    search_results = question_text_vector(query)
    prompt = build_prompt(query['question'], search_results)
    answer = llm(prompt)
    return answer

# %%
ground_truth[20]
# Out:
# {'id': 5,
#  'question': "What is the publication year of the book 'A Game of Thrones'?"}

# %%
rag(ground_truth[20])
# Out:
# 'The publication year of the book "A Game of Thrones" by George R.R. Martin is 1996.'

# %% [markdown]
# #### I don't have original "reference answers" to these questions readily available in order to use a cosine similarity metric, and as such we move on to LLM-as-a-Judge evaluation immediately.

# %% [markdown]
# ### LLM-as-a-Judge

# %%
prompt2_template = """
You are an expert evaluator for a Retrieval-Augmented Generation (RAG) system.
Your task is to analyze the relevance of the generated answer to the given question.
Based on the relevance of the generated answer, you will classify it
as "NON_RELEVANT", "PARTLY_RELEVANT", or "RELEVANT".

Here is the data for evaluation:

Question: {question}
Generated Answer: {answer_llm}

Please analyze the content and context of the generated answer in relation to the question
and provide your evaluation in parsable JSON without using code blocks:

{{
  "Relevance": "NON_RELEVANT" | "PARTLY_RELEVANT" | "RELEVANT",
  "Explanation": "[Provide a brief explanation for your evaluation]"
}}
""".strip()

# %%
prompt2_template = """
You are an expert evaluator for a Retrieval-Augmented Generation (RAG) system.
Classify the generated answer's relevance to the given question as one of:
"NON_RELEVANT", "PARTLY_RELEVANT", or "RELEVANT".

QUESTION:
{question}

GENERATED_ANSWER:
{answer_llm}

Reply ONLY with a single JSON object (no markdown, no explanation outside JSON), exactly:
{{
  "Relevance": "NON_RELEVANT" | "PARTLY_RELEVANT" | "RELEVANT",
  "Explanation": "a brief reason"
}}
""".strip()

# %% [markdown]
# #### Test

# %%
len(ground_truth)
# Out:
# 838

# %%
record = ground_truth[0]
record
# Out:
# {'id': 0, 'question': 'What is the publication year of the book Dune?'}

# %%
answer_llm = rag(record)
print(answer_llm)
# Out:
# The publication year of the book "Dune" by Frank Herbert is 1965.

# %%
prompt = prompt2_template.format(
    question=question, answer_llm=answer_llm)
print(prompt)
# Out:
# You are an expert evaluator for a Retrieval-Augmented Generation (RAG) system.
# Your task is to analyze the relevance of the generated answer to the given question.
# Based on the relevance of the generated answer, you will classify it
# as "NON_RELEVANT", "PARTLY_RELEVANT", or "RELEVANT".
#
# Here is the data for evaluation:
#
# Question: For whom is the target audience of 'The Crippled God' designated?
# Generated Answer: The publication year of the book "Dune" by Frank Herbert is 1965.
#
# Please analyze the content and context of the generated answer in relation to the question
# and provide your evaluation in parsable JSON without using code blocks:
#
# {
#   "Relevance": "NON_RELEVANT" | "PARTLY_RELEVANT" | "RELEVANT",
#   "Explanation": "[Provide a brief explanation for your evaluation]"
# }

# %% [markdown]
# #### Actual

# %%
import json

# %%
evaluations = {}

for record in tqdm(ground_truth):
    id = record['id']
    question = record["question"]   

    if id in evaluations:
        continue

    answer_llm = rag(record) 

    prompt = prompt2_template.format(
        question=question, 
        answer_llm=answer_llm
        )
    
    evaluation = llm(prompt)
    eval_json = json.loads(evaluation)  # parse output   
    evaluations[id] = {
        "id": id,
        "question": question,
        "answer_llm": answer_llm,
        "evaluation": eval_json
    }

# %% [markdown]
# #### ChatGPT script for parsing JSON without any LLM-induced errors and incosistencies to avoid crashing the run.

# %%
import re

# --- robust parser for "JSON-ish" model outputs ---
def parse_judge_json(text: str):
    raw = text.strip()

    # strip code fences if any
    if raw.startswith("```"):
        raw = raw.strip("`")
        raw = re.sub(r"^\s*json\s*", "", raw, flags=re.IGNORECASE)

    # extract first {...} block if there's surrounding prose
    start = raw.find("{")
    end = raw.rfind("}")
    candidate = raw[start:end+1] if (start != -1 and end != -1 and end > start) else raw

    # normalize common issues
    sane = (candidate
            .replace("\u201c", '"').replace("\u201d", '"')   # smart quotes
            .replace("\u2018", "'").replace("\u2019", "'")
            .replace("True", "true").replace("False", "false").replace("None", "null"))

    # remove trailing commas before } or ]
    sane = re.sub(r",\s*([}\]])", r"\1", sane)

    # if it used single quotes for keys/strings, try swapping
    if "'" in sane and '"' not in sane[:80]:
        sane = sane.replace("'", '"')

    try:
        obj = json.loads(sane)
        # minimal validation
        if obj.get("Relevance") not in {"NON_RELEVANT", "PARTLY_RELEVANT", "RELEVANT"}:
            raise ValueError("bad enum")
        return obj
    except Exception:
        # fallback: keep raw text but don't crash the run
        return {"Relevance": None, "Explanation": raw[:1000]}

# %%
evaluations = {}   # dict keyed by id
seen = set()
ckpt_path = "evaluations_checkpoint.json"
save_every = 25

for i, record in enumerate(tqdm(ground_truth)):
    rid = record["id"]
    if rid in seen:
        continue

    question = record["question"]
    answer_llm = rag(record)

    prompt = prompt2_template.format(question=question, answer_llm=answer_llm)
    judge_text = llm(prompt)  # set temperature=0 on your client if possible

    eval_json = parse_judge_json(judge_text)

    evaluations[rid] = {
        "id": rid,
        "question": question,
        "answer_llm": answer_llm,
        "evaluation": eval_json
    }
    seen.add(rid)

    # checkpoint periodically so one bad item doesn’t waste the run
    if (i + 1) % save_every == 0:
        with open(ckpt_path, "w", encoding="utf-8") as f:
            json.dump([evaluations[k] for k in sorted(evaluations)], f, ensure_ascii=False, indent=2)

# final save
with open("evaluations.json", "w", encoding="utf-8") as f:
    json.dump([evaluations[k] for k in sorted(evaluations)], f, ensure_ascii=False, indent=2)
# Out:
#   0%|          | 0/838 [00:00<?, ?it/s]

# %%
evaluations
# Out:
# {0: {'id': 0,
#   'question': 'What is the publication year of the book Dune?',
#   'answer_llm': 'The context does not provide information about a specific book titled "Dune". However, it does mention that there are multiple books and adaptations associated with the name "Dune".\n\nIf you\'d like to know the publication years for different titles related to the "Dune" franchise, I can help with that.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': "Does not provide relevant publication year for a specific 'Dune' book title"}},
#  2: {'id': 2,
#   'question': "What is the page count of the book 'The Left Hand of Darkness'?",
#   'answer_llm': 'According to the metadata, "The Left Hand of Darkness" by Ursula K. Le Guin has 272 pages.',
#   'evaluation': {'Relevance': 'RELEVANT',
#    'Explanation': 'The answer directly addresses the question about page count.'}},
#  3: {'id': 3,
#   'question': 'What is the publication year of the book "Foundation"?',
#   'answer_llm': 'The publication year of the book "Foundation" by Isaac Asimov was 1951.',
#   'evaluation': {'Relevance': None,
#    'Explanation': '{\n  "Relevance": "PARTLY_RELEVANT",\n  "Explanation": "The answer provides the publication year, but not all the information requested (author) in the original question."'}},
#  4: {'id': 4,
#   'question': "What is the publication year of the book 'The Hobbit'?",
#   'answer_llm': 'The publication year of "The Hobbit" by J.R.R. Tolkien is 1937.',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'the year is correct but the question was not about a specific edition or translation of the book'}},
#  5: {'id': 5,
#   'question': "What is the publication year of the book 'A Game of Thrones'?",
#   'answer_llm': "The publication year of the book 'A Game of Thrones' is 1996.",
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': "The generated answer only provides the publication year, but not any context or information about the book 'A Game of Thrones', which is likely a series. The question specifically asks for the publication year of the first book in the series."}},
#  7: {'id': 7,
#   'question': 'What is the page count of The Way of Kings?',
#   'answer_llm': 'Based on the context, I don\'t have a specific page count for "The Way of Kings". However, according to my knowledge cutoff in December 2023, the page count for "The Way of Kings" by Brandon Sanderson is approximately 1,083 pages.',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': "The answer provides the page count, but it's not a direct answer to the question about the page count itself."}},
#  8: {'id': 8,
#   'question': "What is the publication year of the book 'The Fifth Season'?",
#   'answer_llm': 'The publication year of the book "The Fifth Season" is 2015.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': "The question asked for the book's publication year, but the answer only provided the author's name."}},
#  9: {'id': 9,
#   'question': "What is the publication year of Ender's Game?",
#   'answer_llm': "The publication year of Ender's Game is 1985.",
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': "The question asks for the publication year of Ender's Game, but the answer does not specify which work it refers to (book or film), making the information partially relevant."}},
#  10: {'id': 10,
#   'question': "What is the number of pages in the book 'Hyperion'?",
#   'answer_llm': 'I don\'t see any information about the page count for "Hyperion" in the provided context. However, I can suggest that you provide more context or details about the book, such as its author (Dan Simmons) and publication date, which might help me find the correct information.\n\nIf you meant to ask about another book, please provide more context, and I\'ll do my best to assist you!',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'contains some relevant information but lacks specific page count'}},
#  11: {'id': 11,
#   'question': "What is the publication year of the book 'Leviathan Wakes'?",
#   'answer_llm': 'The publication year of the book "Leviathan Wakes" is 2011.',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'The answer mentions the book title and publication year, but lacks context about the book itself.'}},
#  12: {'id': 12,
#   'question': 'What is the publication year of this book?',
#   'answer_llm': "I'm ready to help, but I don't see any book metadata in the context you provided. Please provide the context or the book's title, author, and any other relevant information so I can assist you with determining the publication year.",
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'Context not provided for the book metadata'}},
#  13: {'id': 13,
#   'question': "What is the page count of the book 'The Stone Sky'?",
#   'answer_llm': 'I don\'t see any information about the book "The Stone Sky" in the provided context. Could you please provide more details or metadata about this book, such as the author or publisher? I\'ll be happy to help you with your question once I have more information.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'the question asks for a specific piece of information not present in the provided context'}},
#  14: {'id': 14,
#   'question': "What is the target audience for the book 'Children of Time'?",
#   'answer_llm': 'I don\'t have any information about a book titled "Children of Time" in the provided context. Could you please provide more metadata or details about the book, such as author or publication date? I\'ll be happy to help with my next question.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'No information about the book was provided in the query.'}},
#  15: {'id': 15,
#   'question': "What is the total page count of 'Children of Ruin'?",
#   'answer_llm': 'The context does not provide information about the book "Children of Ruin". However, it does mention that I can help with fantasy and sci-fi books. If you provide more context or information about a specific book, such as its title, author, or genre, I\'d be happy to try and assist you further.',
#   'evaluation': {'Relevance': None,
#    'Explanation': '{\n  "Relevance": "NON_RELEVANT",\n  "Explanation": "The question asks for a specific page count, which is not provided in the response."'}},
#  16: {'id': 16,
#   'question': "What is the publication year of the book 'The Forever War'?",
#   'answer_llm': "The publication year of the book 'The Forever War' is 1974.",
#   'evaluation': {'Relevance': 'NON_RELEVANT', 'Explanation': ''}},
#  17: {'id': 17,
#   'question': "What is the publication year of the book 'Old Man's War'?",
#   'answer_llm': "The publication year of the book 'Old Man's War' is 2005.",
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': "The generated answer provides a specific year, but lacks context about the book 'Old Man's War'."}},
#  18: {'id': 18,
#   'question': "What is the title of the first book in Kim Stanley Robinson's Mars Trilogy?",
#   'answer_llm': 'The title of the first book in Kim Stanley Robinson\'s Mars Trilogy is "Red Mars".',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'The answer provides the title, but it does not specify which one in the trilogy (e.g., first book)'}},
#  19: {'id': 19,
#   'question': "What is the publication year of the book 'Green Mars'?",
#   'answer_llm': 'The publication year of the book "Green Mars" by Kim Stanley Robinson is 1994.',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'It provides the book title, but not its publication year.'}},
#  20: {'id': 20,
#   'question': "What is the series position of 'Blue Mars' within its respective series?",
#   'answer_llm': 'I\'m not seeing any context or information about a book titled "Blue Mars". Can you please provide more information about the book, such as the author or publication date? I\'ll be happy to help answer your question once I have that context.',
#   'evaluation': {'Relevance': 'RELEVANT',
#    'Explanation': 'The response asks for context to answer the question, which is provided'}},
#  21: {'id': 21,
#   'question': "What is the page count of the book 'Snow Crash'?",
#   'answer_llm': "The page count of the book 'Snow Crash' is 416 pages.",
#   'evaluation': {'Relevance': 'RELEVANT', 'Explanation': ''}},
#  23: {'id': 23,
#   'question': "What is the publication year of 'The Three-Body Problem'?",
#   'answer_llm': 'The publication year of "The Three-Body Problem" is 2008.',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'The answer provides the publication year, but does not mention the title or author.'}},
#  24: {'id': 24,
#   'question': "What is the publication year of the book 'The Dark Forest', and who published it?",
#   'answer_llm': 'Based on the provided context, I couldn\'t find the exact information about "The Dark Forest" book. However, I found that "The Dark Forest" by Yangsze Choo was published in 2020. The publisher of this book is HarperCollins UK (for the British market) and HarperCollins Publishers (in the United States).',
#   'evaluation': {'Relevance': None,
#    'Explanation': '{\n  "Relevance": "PARTLY_RELEVANT",\n  "Explanation": "it partially answers the first part of the question (publication year), but not the second part"'}},
#  25: {'id': 25,
#   'question': "Who is the author of the book 'Death's End'?",
#   'answer_llm': 'The context doesn\'t provide enough information about a specific book called "Death\'s End". However, based on my general knowledge, I can tell you that Liu Cixin wrote the science fiction novel "Death\'s End", which was the final book in his Remembrance of Earth\'s Past trilogy.',
#   'evaluation': {'Relevance': 'RELEVANT',
#    'Explanation': "The answer provides the correct author, meeting the question's requirements."}},
#  26: {'id': 26,
#   'question': "What is the publication year of the book 'Ringworld'?",
#   'answer_llm': 'The publication year of the book "Ringworld" by Larry Niven is 1970.',
#   'evaluation': {'Relevance': None,
#    'Explanation': '{\n  "Relevance": "NON_RELEVANT",\n  "Explanation": "The answer only provides the publication year, but it does not directly address the question of relevance to the context of the Ringworld series or its impact on the science fiction genre."'}},
#  27: {'id': 27,
#   'question': "What is the publication year of the book 'The Mote in God's Eye'?",
#   'answer_llm': "The publication year of the book 'The Mote in God's Eye' is 1974.",
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'Answer provides the correct publication year but lacks additional context or details.'}},
#  28: {'id': 28,
#   'question': 'What is the publication year of the book Altered Carbon?',
#   'answer_llm': 'The publication year of the book "Altered Carbon" by Richard K. Morgan is 2002.',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': "The answer provides the publication year, but it does not fully address the question's request for the book's title as well."}},
#  29: {'id': 29,
#   'question': "What is the publication year of the book 'Revelation Space'?",
#   'answer_llm': 'The publication year of the book "Revelation Space" by Alastair Reynolds is 2000.',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': "Answer provides the publication year, but doesn't address the book title in the question"}},
#  30: {'id': 30,
#   'question': "What is the publication year of the book 'Chasm City'?",
#   'answer_llm': 'The context doesn\'t provide enough information about the book "Chasm City". However, I can tell you that Chasm City is a novel by China Miéville, and according to my knowledge, it was published in 2001. If this isn\'t the correct publication year for the specific book from your database, please provide more context or details, and I\'ll do my best to help.',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': "Answer provides the book title, but lacks specific publication year for the query's database"}},
#  31: {'id': 31,
#   'question': 'What is the publication year of Perdido Street Station?',
#   'answer_llm': 'The publication year of Perdido Street Station is 2000.',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'Year and book title mentioned, but not exact answer.'}},
#  32: {'id': 32,
#   'question': "What is the page count of the book 'The Scar'?",
#   'answer_llm': 'I don\'t have any information about a book called "The Scar" in the provided context. Can you please provide more details or clarify which book\'s metadata you would like me to access?',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'Context of the question is not provided in the system metadata.'}},
#  33: {'id': 33,
#   'question': "What is the publication year of the book 'Iron Council'?",
#   'answer_llm': 'The publication year of the book "Iron Council" by China Miéville is 2004.',
#   'evaluation': {'Relevance': 'RELEVANT',
#    'Explanation': 'Answer directly addresses the question'}},
#  34: {'id': 34,
#   'question': 'What is the publication year of this book?',
#   'answer_llm': "I'm ready to help. Please provide the book metadata, and I'll answer your question based on the context.",
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'The answer requires a specific piece of metadata about the book, but the generated response is asking for more context instead of providing the answer.'}},
#  35: {'id': 35,
#   'question': 'What are the subgenres associated with this book?',
#   'answer_llm': "I'm ready to help. Please provide the book metadata so I can answer your question about its subgenres.",
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'The answer is asking for information about the book, but the generated response asks for metadata instead of providing subgenres.'}},
#  36: {'id': 36,
#   'question': 'What is the publication year of the book Good Omens?',
#   'answer_llm': 'The publication year of the book "Good Omens" is 1990.',
#   'evaluation': {'Relevance': None,
#    'Explanation': '{\n  "Relevance": "PARTLY_RELEVANT",\n  "Explanation": "The answer provides the publication year, but lacks information about the book\'s title, author, or relevance to other books."'}},
#  37: {'id': 37,
#   'question': 'What is the publication year of the book Small Gods?',
#   'answer_llm': 'The publication year of the book "Small Gods" by Terry Pratchett is 1992.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'The question asks for the publication year, which is a specific detail about the book. The answer only provides this information without addressing how to find more details or context.'}},
#  38: {'id': 38,
#   'question': "Who is the author of 'The Colour of Magic'?",
#   'answer_llm': "The author of 'The Colour of Magic' is Terry Pratchett.",
#   'evaluation': {'Relevance': None,
#    'Explanation': '{\n  "Relevance": "NON_RELEVANT",\n  "Explanation": "The answer is too specific, only addressing the question about a book title without providing any additional relevant context or information."'}},
#  39: {'id': 39,
#   'question': "What is the publication year of the book 'Guards! Guards!'?",
#   'answer_llm': "The publication year of the book 'Guards! Guards!' is 1989.",
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': "The answer provides the publication year, but does not directly address a question about the book's content or plot."}},
#  40: {'id': 40,
#   'question': 'What is the title of the book and who is its author?',
#   'answer_llm': "I'm ready to help! However, I don't see any context provided. Please provide the book metadata or a brief description, and I'll be happy to answer your question about the title and author of the book.",
#   'evaluation': {'Relevance': None,
#    'Explanation': '{\n  "Relevance": "NON_RELEVANT",\n  "Explanation": "Answer requires additional context to provide a relevant response"'}},
#  41: {'id': 41,
#   'question': 'What is the publication year of the book Red Seas Under Red Skies?',
#   'answer_llm': 'The publication year of the book "Red Seas Under Red Skies" is 2007.',
#   'evaluation': {'Relevance': None,
#    'Explanation': '{\n  "Relevance": "RELEVANT",\n  "Explanation": "The answer directly addresses the question about the publication year of the book \'Red Seas Under Red Skies\'"'}},
#  42: {'id': 42,
#   'question': 'What is the title of the book being evaluated?',
#   'answer_llm': "I'm ready to help. Please go ahead and provide the context, including any relevant metadata about the book you'd like me to evaluate. I'll do my best to answer your question based on the facts from the context.",
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'The response is too general and does not directly address the question about the title of the book.'}},
#  43: {'id': 43,
#   'question': 'What is the publication year of the book "The Blade Itself"?',
#   'answer_llm': 'The publication year of the book "The Blade Itself" is 2006.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': "The generated answer provides the publication year, but it's not clear if it's referring to the specific book 'The Blade Itself' without more context."}},
#  44: {'id': 44,
#   'question': 'What is the publication year of the book?',
#   'answer_llm': "I'm ready to help. However, I don't see any book metadata in the context you provided. Could you please provide more information about the book, such as its title or author? That way, I can help answer your question based on that specific book's publication year.",
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'Generated answer asks for clarification on the context of the question instead of providing a direct answer.'}},
#  45: {'id': 45,
#   'question': "What is the publication year of the book 'Last Argument of Kings'?",
#   'answer_llm': 'The publication year of the book "Last Argument of Kings" by Joe Abercrombie is 2008.',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': "The answer provides the publication year, but does not address the book's plot or any specific question related to it."}},
#  46: {'id': 46,
#   'question': 'What is the publication year of the book The Gunslinger?',
#   'answer_llm': 'The publication year of the book "The Gunslinger" is 1982.',
#   'evaluation': {'Relevance': None,
#    'Explanation': '{\n  "Relevance": "PARTLY_RELEVANT",\n  "Explanation": "The answer provides the publication year, but it\'s not specified which book \'The Gunslinger\' refers to, as there are multiple books with that title."'}},
#  47: {'id': 47,
#   'question': 'What is the position of this book within its series?',
#   'answer_llm': "I'm ready to help. Please go ahead and provide the book metadata, and I'll be happy to answer the question about the position of the book within its series.",
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'Answer requires additional context or metadata about the book series.'}},
#  48: {'id': 48,
#   'question': 'What is the series position of the book within its overall series?',
#   'answer_llm': "I'm ready to help. However, I don't see any context provided in your question. Could you please provide the book metadata (series position) information so I can assist you accordingly?",
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'The answer is related to the book, but it asks for a different piece of information (series metadata)'}},
#  49: {'id': 49,
#   'question': "What is the page count of the book 'Wizard and Glass'?",
#   'answer_llm': 'I don\'t see a mention of the book "Wizard and Glass" in the context. The context seems to be empty. Can you please provide more information about the book or its metadata? I\'ll do my best to help once I have that information.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'The generated answer is not relevant because it requests additional information instead of providing a solution to the question.'}},
#  50: {'id': 50,
#   'question': 'What is the page count of the book, and was it published by a single publisher or multiple publishers?',
#   'answer_llm': "You haven't provided any context yet. Please provide the book metadata from the database, such as the title, author, publication date, and any other relevant information, and I'll be happy to help answer your question about the page count and publishing history of the book.",
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'Does not address the question directly'}},
#  51: {'id': 51,
#   'question': 'What is the publication year of The Stand?',
#   'answer_llm': 'The publication year of "The Stand" is 1958.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': "The generated answer is partially relevant as it provides the publication year, but not the specific book 'The Stand' which might be a different work from Stephen King's novel with the same title."}},
#  52: {'id': 52,
#   'question': 'What is the publication year of the book Dracula?',
#   'answer_llm': 'The publication year of the book "Dracula" is 1897.',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': "The answer is partially relevant, as it provides the publication year of Dracula, but does not address a specific question about the book's impact or context."}},
#  55: {'id': 55,
#   'question': 'What is the estimated number of pages in this book?',
#   'answer_llm': "I'm ready to help. Please provide the book metadata, and I'll do my best to answer your question based on the context.",
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'The answer asks for metadata, but the RAG system is ready to help without specific context.'}},
#  56: {'id': 56,
#   'question': 'What is the publication year of Fahrenheit 451?',
#   'answer_llm': 'The answer is not explicitly stated in the provided context, but according to my knowledge outside of this conversation, the publication year of Fahrenheit 451 by Ray Bradbury is 1953.',
#   'evaluation': {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer provides the exact information requested, despite being outside of the provided context.'}},
#  57: {'id': 57,
#   'question': "What is the publication year of 'Something Wicked This Way Comes'?",
#   'answer_llm': "The publication year of 'Something Wicked This Way Comes' is 1983.",
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': "The question asks for the publication year of a specific book, but the answer only provides this information without referencing the book's title."}},
#  58: {'id': 58,
#   'question': 'What is the page count of this book?',
#   'answer_llm': "I'm ready to help. Please provide the book metadata, and I'll answer your question about the page count.",
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'the generated answer requires input to function, which is not provided in the question.'}},
#  59: {'id': 59,
#   'question': "What is the author of the book 'Project Hail Mary'?",
#   'answer_llm': 'The author of the book "Project Hail Mary" is Andy Weir.',
#   'evaluation': {'Relevance': 'RELEVANT',
#    'Explanation': "Directly answers the question about the book's author."}},
#  61: {'id': 61,
#   'question': "What is the publication year of the book 'Abaddon's Gate'?",
#   'answer_llm': 'The publication year of the book "Abaddon\'s Gate" is 2013.',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'The question asks for a book title and publication year, while the answer only provides the publication year.'}},
#  62: {'id': 62,
#   'question': "What is the publication year of 'Cibola Burn', and was it published by a major publisher?",
#   'answer_llm': 'The CONTEXT mentions "Cibola Burn", but no specific details are provided. However, I can tell you that "Cibola Burn" is actually the second book in the Illuminae Files trilogy.\n\nAccording to my knowledge, the first book in the trilogy, "Illuminae", was published in 2015 by Flux and Orbit Books (a major publisher).\n\nThe publication year of "Cibola Burn" is 2016, and it was also published by a major publisher, specifically Orbit Books.',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': "Answer provides the correct publication year and publisher, but does not address the first part of the question regarding 'Cibola Burn' itself."}},
#  65: {'id': 65,
#   'question': "What is the publication year of the book 'Tiamat's Wrath'?",
#   'answer_llm': "The publication year of the book 'Tiamat's Wrath' is 2019.",
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'The answer provides the publication year, but lacks the title of the book.'}},
#  66: {'id': 66,
#   'question': 'Is this book part of a series, and if so, what is the position of this book within that series?',
#   'answer_llm': "I'm ready to help. Please go ahead and provide the book metadata (context) for the question, and I'll answer based on that information.",
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'it prompts the user to provide more context'}},
#  67: {'id': 67,
#   'question': "What is the publication year of the book 'Storm Front'?",
#   'answer_llm': 'The publication year of the book "Storm Front" is 1999.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'The question asked for the book title, not publication year.'}},
#  68: {'id': 68,
#   'question': "What is the publication year of the book 'Fool Moon'?",
#   'answer_llm': "The context doesn't specify a title for the book, but it does mention 'Fool Moon'. Unfortunately, there isn't enough information to determine the publication year.",
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'The answer provides some information about the title, but lacks necessary details to pinpoint the publication year.'}},
#  69: {'id': 69,
#   'question': "What is the publication year of the book 'Grave Peril'?",
#   'answer_llm': 'The publication year of the book "Grave Peril" is 2000.',
#   'evaluation': {'Relevance': None,
#    'Explanation': '{\n  "Relevance": "PARTLY_RELEVANT",\n  "Explanation": "The answer provides the publication year, but lacks a direct response to \'what\' about the book \'Grave Peril\'"'}},
#  70: {'id': 70,
#   'question': 'What is the series position of the book within The Dresden Files series?',
#   'answer_llm': "I'm ready to help. Please go ahead and provide the context, which includes the metadata for a specific book in the Dresden Files series. I'll answer the question about its series position based on that information.",
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'The answer provides context for answering the question but does not directly state the series position of the book.'}},
#  71: {'id': 71,
#   'question': "What is the publication year of 'Blood Rites'?",
#   'answer_llm': 'I don\'t have information about a book titled "Blood Rites" in my context. Can you please provide more details or clarify which book you are referring to? I\'d be happy to try and assist you with reading recommendations based on your preferences.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'No publication year provided for a specific book titled "Blood Rites"'}},
#  72: {'id': 72,
#   'question': "What is the position of 'Dead Beat' within 'The Dresden Files' series?",
#   'answer_llm': 'I\'m ready to help. However, I don\'t see any context provided. Could you please provide the book metadata for "Dead Beat" in the "Dresden Files" series? I\'ll be happy to answer your question based on that information.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'The answer does not address the question directly and instead requests additional context.'}},
#  73: {'id': 73,
#   'question': "What is the series position of 'Proven Guilty' within The Dresden Files?",
#   'answer_llm': 'Based on the provided context, I don\'t have any information about a book titled "Proven Guilty" within The Dresden Files. However, I can tell you that James Marsters played the role of Thomas Raith in the TV series based on The Dresden Files.\n\nIf you could provide more context or clarify which book "Proven Guilty" is actually referring to, I would be happy to try and help you with the question.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': "The answer does not provide information about 'Proven Guilty' in The Dresden Files."}},
#  74: {'id': 74,
#   'question': "What is the publication year of the book 'Changes'?",
#   'answer_llm': 'I\'m not able to answer your question about the publication year of "Changes" based on the context you provided, as no information about the book\'s metadata was included in your query. \n\nHowever, I can tell you that there are multiple books with the title "Changes". Could you provide more context or specify which book you are referring to?',
#   'evaluation': {'Relevance': 'RELEVANT',
#    'Explanation': 'The answer provides a valid but incomplete response.'}},
#  76: {'id': 76,
#   'question': "What is the publication year of 'The Hunger Games'?",
#   'answer_llm': 'The context does not mention "The Hunger Games". However, I can try to find information about it based on general knowledge. According to my knowledge, the publication year of "The Hunger Games" by Suzanne Collins is 2008.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'The question asks for a specific publication year, but the generated answer does not have that information.'}},
#  77: {'id': 77,
#   'question': "What is the publication year of the book 'Catching Fire'?",
#   'answer_llm': 'The context does not provide information about a specific book titled "Catching Fire". However, it\'s worth noting that "Catching Fire" is the second book in The Hunger Games trilogy by Suzanne Collins. According to general knowledge, the publication year of the first book in the series, "The Hunger Games", is 2008, and the publication year of the third book in the series, also titled "Catching Fire", is 2009.\n\nIf you\'re referring to a different book with the same title, could you please provide more context or information about it?',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': "does not provide the specific publication year of 'Catching Fire'"}},
#  79: {'id': 79,
#   'question': 'What is the number of pages in the book Divergent?',
#   'answer_llm': 'The page count for "Divergent" by Veronica Roth is not specified in the provided context.',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'The answer mentions the book, but not its page count specifically.'}},
#  80: {'id': 80,
#   'question': "What is the page count of the book 'Insurgent'?",
#   'answer_llm': 'I couldn\'t find any information about the page count of the book "Insurgent" in the provided context. However, I can suggest that you check a reliable source such as the book\'s publisher or a bookstore website for the most up-to-date and accurate page count information.\n\nAlternatively, if you provide more context or details about the book "Insurgent", such as its author or publication date, I may be able to help you find the page count.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'Lack of specific information about the book'}},
#  81: {'id': 81,
#   'question': 'What is the publication year of the book Allegiant?',
#   'answer_llm': 'The publication year of the book "Allegiant" is 2013.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': "The answer provides the year, but the question asks for the book title 'Allegiant', which is not specified in the response."}},
#  82: {'id': 82,
#   'question': 'What is the page count of the book Annihilation?',
#   'answer_llm': 'According to the context, I couldn\'t find any specific information about the page count of "Annihilation". However, I can tell you that "Annihilation" is a science fiction novel by Jeff VanderMeer, published in 2014. The book is part of the Southern Reach Trilogy, and it won the Nebula Award for Best Novel in 2014.\n\nIf you\'re looking for more information about this book or would like to ask another question, feel free to ask!',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': "Answer does not provide the specific page count of 'Annihilation'"}},
#  83: {'id': 83,
#   'question': "What is the publication year of the book 'Authority'?",
#   'answer_llm': 'The context doesn\'t provide enough information about a specific book titled "Authority". However, I can tell you that Robert Jordan has a series called "Wheel of Time", and one of its books titled "New Spring" has a companion novel titled "The Gathering Storm\'s" predecessor - the book "A Crown of Swords"\'s precursor in timeline, titled \'Crossroad\' was not published. But then came  the actual book "Authority" , which is also part of Robert Jordan\'s series. According to my knowledge, that book "Authority" actually has a publication year of 2003.',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': "Answers the specific question about book 'Authority' but requires prior context to be fully relevant"}},
#  85: {'id': 85,
#   'question': 'What is the publication year of this book?',
#   'answer_llm': "I'm ready to help. However, I don't see any context provided in your question. Please provide the book metadata from the database, and I'll do my best to answer your question about the publication year.",
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'The answer provides an alternative solution to the problem, rather than directly answering the question.'}},
#  86: {'id': 86,
#   'question': "What is the number of pages in the book 'World War Z'?",
#   'answer_llm': 'I don\'t see any information about the page count of "World War Z" in the provided context. Could you please provide more details or context about the book, such as its author or publication date? I\'ll do my best to help you find the answer based on the available data.',
#   'evaluation': {'Relevance': None,
#    'Explanation': '{\n  "Relevance": "PARTLY_RELEVANT",\n  "Explanation": "generated answer acknowledges the question but requests additional context to provide a relevant answer"'}},
#  87: {'id': 87,
#   'question': "What is the page count of 'The Passage'?",
#   'answer_llm': 'According to the context, I don\'t see any information about a book titled "The Passage". However, I can tell you that Justin Cronin wrote a post-apocalyptic epic novel called "The Passage" which is the first book in The Passage trilogy. If you\'d like more information about this book or would like me to suggest similar books based on the author or genre, please let me know!',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'it mentions the book, but not its page count'}},
#  88: {'id': 88,
#   'question': "What is the publication year of 'The Twelve'?",
#   'answer_llm': 'I\'m happy to help you find the publication year of "The Twelve"! However, I don\'t see any information about a book titled "The Twelve" in the provided context. Could you please provide more details or metadata about this book, such as the author or publisher? I\'ll do my best to assist you with your question.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'Lacks specific context to identify the book'}},
#  89: {'id': 89,
#   'question': 'What is the publication year of The City of Mirrors?',
#   'answer_llm': 'The City of Mirrors, a novel by Justin Cronin, was published in 2017.',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'The answer provides the publication year, but does not address the specific question about The City of Mirrors.'}},
#  90: {'id': 90,
#   'question': 'What is the publication year of The Silmarillion?',
#   'answer_llm': 'The publication year of The Silmarillion is 1977.',
#   'evaluation': {'Relevance': 'NON_RELEVANT', 'Explanation': ''}},
#  93: {'id': 93,
#   'question': "What is the publication year of the book 'The Eye of the World'?",
#   'answer_llm': 'Based on the context, I found that "The Eye of the World" is a fantasy novel by Robert Jordan. According to my database, the publication year of this book is 1990.',
#   'evaluation': {'Relevance': 'NON_RELEVANT', 'Explanation': ''}},
#  94: {'id': 94,
#   'question': "What is the publication year of the book 'The Great Hunt'?",
#   'answer_llm': 'Based on the context, I couldn\'t find any information about the specific book "The Great Hunt". However, I can suggest that you provide more context or details about the book, such as the author or series it belongs to. This will help me narrow down the search and provide a more accurate answer.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'No specific book mentioned, too general'}},
#  95: {'id': 95,
#   'question': 'Is The Dragon Reborn part of a series that is considered epic fantasy?',
#   'answer_llm': 'I\'m not seeing any context provided about "The Dragon Reborn". Could you please provide more information or clarify which book this refers to? I\'d be happy to help once I have more details.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'No direct relation to the query, requires context'}},
#  96: {'id': 96,
#   'question': 'What is the series name of this book?',
#   'answer_llm': "I'm ready to help! However, you haven't provided any context for the question about a specific book. Please provide the metadata for the book, such as its title or author, and I'll do my best to answer your question based on that information.",
#   'evaluation': {'Relevance': None,
#    'Explanation': '{"Relevance": " NON_RELEVANT", "Explanation": "The response requires specific book metadata to answer the question." }'}},
#  97: {'id': 97,
#   'question': "What is the page count of 'The Fires of Heaven'?",
#   'answer_llm': 'I don\'t have any information about a book titled "The Fires of Heaven" in my current context. However, I can suggest that "The Fires of Heaven" might be the fourth book in the Wheel of Time series by Robert Jordan. \n\nIf this is the correct book, according to some sources, it has approximately 896 pages, but please note that page counts may vary depending on the edition and publication date.\n\nHowever, without more context or information about the exact book you are referring to, I couldn\'t provide a definitive answer.',
#   'evaluation': {'Relevance': 'RELEVANT',
#    'Explanation': 'The answer provides information about the book title mentioned in the question.'}},
#  99: {'id': 99,
#   'question': "What is the page count of the book 'A Crown of Swords'?",
#   'answer_llm': 'The page count for the book "A Crown of Swords" by Robert Jordan is 864 pages.',
#   'evaluation': {'Relevance': 'RELEVANT', 'Explanation': ''}},
#  100: {'id': 100,
#   'question': 'What is the publication year of the book?',
#   'answer_llm': "I'm ready to help. However, you haven't provided the context with book metadata. Please provide the context or a specific book title and I'll do my best to answer your question about its publication year.",
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': "Answer doesn't address the question about publication year directly"}},
#  101: {'id': 101,
#   'question': "What is the publication year of the book 'Winter's Heart', and which regions it was published in?",
#   'answer_llm': 'Based on the provided database, I can answer that "Winter\'s Heart" is a fantasy novel by Robert Jordan. \n\n The publication year of "Winter\'s Heart" is 2000.\n\nAs for its regions of publication, I do not have this information available.',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': "Partial information about the book's publication year and lack of info on regions of publication."}},
#  102: {'id': 102,
#   'question': "What is the publication year of the book 'Crossroads of Twilight'?",
#   'answer_llm': 'The context does not provide any information about the book "Crossroads of Twilight", so I cannot answer your question. If you could provide more context or details about this book, such as its author or genre, I would be happy to try and help you find the publication year.',
#   'evaluation': {'Relevance': None,
#    'Explanation': '{\n  "Relevance": "PARTLY_RELEVANT",\n  "Explanation": "The answer attempts to provide a solution but lacks the necessary context or information about the book \'Crossroads of Twilight\'"'}},
#  103: {'id': 103,
#   'question': "What is the page count of the book 'Knife of Dreams'?",
#   'answer_llm': 'I don\'t see any information about the book "Knife of Dreams" in the context. Could you please provide more details or clarify which book this refers to? I\'ll do my best to help once I have the correct information.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'Answer is unrelated to the question and requests clarification.'}},
#  104: {'id': 104,
#   'question': "Is the book 'The Gathering Storm' part of a series?",
#   'answer_llm': 'I\'m ready to help! However, I don\'t see any CONTEXT provided. Please share the book metadata for "The Gathering Storm" and I\'ll be happy to answer your question based on the facts from the CONTEXT.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': "The question asks if 'The Gathering Storm' is part of a series, but no metadata for the book was provided."}},
#  105: {'id': 105,
#   'question': 'What is the book title of the 13th installment in The Wheel of Time series?',
#   'answer_llm': 'The answer cannot be determined as there are no additional details in the context.',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'Answer provides information related to the book series, but lacks specific details about the 13th installment.'}},
#  106: {'id': 106,
#   'question': "What is the total page count of book 'A Memory of Light'?",
#   'answer_llm': 'The total page count of "A Memory of Light" by Robert Jordan is 1206 pages.',
#   'evaluation': {'Relevance': 'RELEVANT',
#    'Explanation': 'The answer directly addresses the question about the page count of a specific book.'}},
#  108: {'id': 108,
#   'question': 'What is the publication year of Warbreaker?',
#   'answer_llm': 'The publication year of Warbreaker is 2009.',
#   'evaluation': {'Relevance': None,
#    'Explanation': '{\n  "Relevance": "PARTLY_RELEVANT",\n  "Explanation": "The answer provides the publication year, but lacks context or additional relevant information about Warbreaker."'}},
#  111: {'id': 111,
#   'question': "What is the page count of the book 'To Sleep in a Sea of Stars'?",
#   'answer_llm': 'The page count of the book "To Sleep in a Sea of Stars" by Tom Holt is 416 pages.',
#   'evaluation': {'Relevance': 'RELEVANT',
#    'Explanation': "it provides the requested information about the book's page count"}},
#  112: {'id': 112,
#   'question': "What is the book's publication year?",
#   'answer_llm': "I'm ready to help. Go ahead and provide the context, and I'll answer with the publication year of the book.",
#   'evaluation': {'Relevance': None,
#    'Explanation': '{\n  "Relevance": "NON_RELEVANT",\n  "Explanation": "Answer does not provide a specific publication year for the book."'}},
#  113: {'id': 113,
#   'question': 'What is the title of the second book in The Inheritance Cycle series?',
#   'answer_llm': "Based on the provided context, I do not have enough information to answer your question about The Inheritance Cycle series. However, if you provide more context or clarify which series you are referring to, I'll be happy to try and assist you further.\n\nIf you would like to know more general information about book series, feel free to ask!",
#   'evaluation': {'Relevance': None,
#    'Explanation': '{\n  "Relevance": "NON_RELEVANT",\n  "Explanation": "Does not address the question directly and requires additional information to provide a relevant answer."'}},
#  114: {'id': 114,
#   'question': "What is the page count of the book 'Brisingr'?",
#   'answer_llm': 'I don\'t have any information about the book "Brisingr" in the context. Could you please provide more details or clarify which book you are referring to? I\'ll be happy to try and help once I have that information.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'No information about the book is available'}},
#  115: {'id': 115,
#   'question': "What is the number of pages in the book 'Inheritance'?",
#   'answer_llm': 'I\'m not seeing any information about the book "Inheritance" in the context. Could you please provide more details or metadata about this book, such as its title, author, and publication date? I\'ll be happy to help answer your question once I have that information.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': "Generated answer requests additional information about the book 'Inheritance', rather than providing a direct answer to the question."}},
#  116: {'id': 116,
#   'question': "What is the publication year of the book 'The Sword of Shannara'?",
#   'answer_llm': 'The publication year of the book "The Sword of Shannara" is 1977.',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': "The answer provides the publication year, but it doesn't specify if it's the original or a re-release year."}},
#  117: {'id': 117,
#   'question': "What is the publication year of 'The Elfstones of Shannara'?",
#   'answer_llm': 'The publication year of "The Elfstones of Shannara" by Terry Brooks is 1982.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'The generated answer is not related to the publication year of a book, it is a general statement about book publication years.'}},
#  118: {'id': 118,
#   'question': "What is the publication year of 'The Wishsong of Shannara'?",
#   'answer_llm': 'The publication year of "The Wishsong of Shannara" is 1985.',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT', 'Explanation': ''}},
#  119: {'id': 119,
#   'question': 'What is the publication year of Shadows of Self?',
#   'answer_llm': 'The publication year of Shadows of Self is 2015.',
#   'evaluation': {'Relevance': None,
#    'Explanation': '{\n  "Relevance": "PARTLY_RELEVANT",\n  "Explanation": "The question asks for a specific publication year, but the answer only provides a general statement."'}},
#  120: {'id': 120,
#   'question': 'What is the series name of the book Bands of Mourning, and what is its position within the series?',
#   'answer_llm': 'I\'m ready to help. Please go ahead and provide the context about the book "Bands of Mourning". I\'ll use the metadata from the database to answer your question about the series name and its position.',
#   'evaluation': {'Relevance': 'RELEVANT',
#    'Explanation': 'Answer directly addresses the question about book series name and position.'}},
#  121: {'id': 121,
#   'question': "What is the publication year of 'The Alloy of Law'?",
#   'answer_llm': 'The context doesn\'t provide a specific book, but it does mention "The Alloy of Law". Based on my knowledge, I can tell that "The Alloy of Law" is a fantasy novel by Brandon Sanderson, and its publication year is 2011.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'The question asks for a specific publication year, but the answer provides additional context not requested by the question.'}},
#  123: {'id': 123,
#   'question': 'What is the typical audience for this book, as indicated by the publisher?',
#   'answer_llm': "I'm ready to help. Please go ahead and provide the context, including the book metadata from your database. I'll use that information to answer your question about the typical audience for the book, as indicated by the publisher.",
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': "The question asks for the publisher's indication of the book's audience, but no context is provided."}},
#  124: {'id': 124,
#   'question': 'What is the publication year of the book?',
# ...
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'The answer provides a relevant publication year, but lacks specificity regarding the requested book title.'}},
#  159: {'id': 159,
#   'question': 'What is the series to which The Golden Compass belongs?',
#   'answer_llm': 'The series to which "The Golden Compass" belongs is "His Dark Materials".',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT', 'Explanation': ''}},
#  160: {'id': 160,
#   'question': "What is the publication year of 'The Subtle Knife' book?",
#   'answer_llm': 'Based on the context, I do not have enough information to determine the publication year of "The Subtle Knife". The context only provides metadata for a database that stores books, but it does not contain specific details about this particular book. Can you provide more information or clarify which database you are referring to?',
#   'evaluation': {'Relevance': None,
#    'Explanation': '{\n  "Relevance": "NON_RELEVANT",\n  "Explanation": "The answer does not address the question\'s query directly and instead asks for more context or clarification."'}},
#  161: {'id': 161,
#   'question': "What is the publication year of 'The Amber Spyglass', and how many pages does it have?",
#   'answer_llm': 'I\'m happy to help you with your question, but I don\'t see any context provided. Please provide the book metadata for "The Amber Spyglass", such as author, title, or publisher, and I\'ll be happy to answer your question about its publication year and page count.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': "No context provided to determine publication year and page count of 'The Amber Spyglass'"}},
#  162: {'id': 162,
#   'question': 'What is the title of the book and its position within a series?',
#   'answer_llm': "I'm ready to help. Please go ahead and provide the context, including the book metadata (title and series information), so I can answer your question about the book's title and its position within a series.",
#   'evaluation': {'Relevance': None,
#    'Explanation': '{\n  "Relevance": "NON_RELEVANT",\n  "Explanation": "The answer asks for specific metadata, but the response requires more information to provide a relevant answer."'}},
#  163: {'id': 163,
#   'question': 'What is the series name of this book, and what is its position within that series?',
#   'answer_llm': "I'm ready to help. Please provide the CONTEXT so I can assist with the QUESTION.",
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'Context is needed to assess relevance'}},
#  164: {'id': 164,
#   'question': "Is 'Jonathan Strange & Mr Norrell' part of a larger series?",
#   'answer_llm': 'The context does not provide information about whether "Jonathan Strange & Mr Norrell" is part of a larger series. The metadata only mentions that it is a standalone novel by Susanna Clarke, published in 2004 and adapted into a television miniseries.',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'The answer partially addresses the question, but with a limitation on the context provided by metadata.'}},
#  165: {'id': 165,
#   'question': "What is the publication year of the book 'Piranesi'?",
#   'answer_llm': "The publication year of the book 'Piranesi' is 2020.",
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'The generated answer is too specific, it does not mention the book title.'}},
#  166: {'id': 166,
#   'question': 'What is the target audience for this book according to its metadata?',
#   'answer_llm': "I'm ready to help. Please provide the book metadata, and I'll answer the question about the target audience based on that information.",
#   'evaluation': {'Relevance': None,
#    'Explanation': '{\n  "Relevance": "NON_RELEVANT",\n  "Explanation": "The generated answer doesn\'t provide a direct response to the question and instead requests additional information."'}},
#  167: {'id': 167,
#   'question': 'What is the position of the Hogfather book within its respective series?',
#   'answer_llm': 'I\'m ready to help. Please go ahead and provide the context, including any relevant metadata about the "Hogfather" book, so I can answer your question accurately.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'The question is asking about a book within a series, but the response seeks more context instead of providing an answer.'}},
#  168: {'id': 168,
#   'question': 'Is this book part of a series?',
#   'answer_llm': "I'm ready to help. Please go ahead and provide the book metadata.",
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'Answer does not address the question directly'}},
#  169: {'id': 169,
#   'question': "What is the page count of the book 'Going Postal'?",
#   'answer_llm': 'The page count of the book "Going Postal" by Terry Pratchett is 416 pages.',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'It provides the correct page count, but does not answer if it is a specific edition.'}},
#  170: {'id': 170,
#   'question': 'What is the page count of the book Thud!',
#   'answer_llm': 'The page count of the book "Thud!" by Joe Abercrombie is 416 pages.',
#   'evaluation': {'Relevance': 'RELEVANT',
#    'Explanation': "It answers the specific question about page count of 'Thud!'"}},
#  171: {'id': 171,
#   'question': "What is the publication year of the book 'The Lion, the Witch and the Wardrobe'?",
#   'answer_llm': 'Based on the context provided, I couldn\'t find any information about the specific book "The Lion, the Witch and the Wardrobe". However, I can tell you that C.S. Lewis wrote a series of seven fantasy novels called "The Chronicles of Narnia", which includes "The Lion, the Witch and the Wardrobe".\n\nIf you\'re looking for information on this particular book, could you please provide more context or clarify which specific edition or publication you\'re referring to?',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'Answer does not provide the requested information'}},
#  172: {'id': 172,
#   'question': 'What is the page count of Prince Caspian?',
#   'answer_llm': 'I don\'t see any information about "Prince Caspian" in the context. However, I can tell you that "Prince Caspian" is a book by C.S. Lewis and it is part of "The Chronicles of Narnia". \n\nAccording to the database, "Prince Caspian" has a page count of 304 pages (hardcover edition).',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'The answer refers to a book, not the page count of Prince Caspian'}},
#  173: {'id': 173,
#   'question': 'What is the publication year of the book?',
#   'answer_llm': "I'm happy to help you with your question! However, I don't see any context provided. Could you please provide the context or the database metadata for the book you're interested in? I'll do my best to answer your question based on the facts from the context.",
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'Answer requires context or metadata that is not provided in the question.'}},
#  174: {'id': 174,
#   'question': "What is the publication year of the book 'The Silver Chair'?",
#   'answer_llm': "The publication year of the book 'The Silver Chair' by C.S. Lewis is 1953.",
#   'evaluation': {'Relevance': None,
#    'Explanation': '{\n  "Relevance": "PARTLY_RELEVANT",\n  "Explanation": "The answer provides the publication year, but it\'s not clear how this information relates to the question or the book\'s context."'}},
#  175: {'id': 175,
#   'question': "What is the publication year of 'The Horse and His Boy'?",
#   'answer_llm': 'The publication year of "The Horse and His Boy" by C.S. Lewis is 1954.',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': "The answer provides the publication year, but it is missing any additional context or relation to the question's topic, such as C.S. Lewis' works in general."}},
#  176: {'id': 176,
#   'question': "What is the publication year of The Magician's Nephew?",
#   'answer_llm': 'The publication year of "The Magician\'s Nephew" is 1955.',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': "Answer mentions the publication year, but doesn't provide additional context about the book"}},
#  177: {'id': 177,
#   'question': "Is The Last Battle a part of 'The Chronicles of Narnia' series?",
#   'answer_llm': 'According to the context, I couldn\'t find any information about "The Last Battle" being part of \'The Chronicles of Narnia\' series. However, the context only provides metadata for one book titled "The Last Battle", which might be a standalone novel or part of another series, but it is not explicitly stated that it is part of \'The Chronicles of Narnia\'.',
#   'evaluation': {'Relevance': None,
#    'Explanation': '{\n  "Relevance": "PARTLY_RELEVANT",\n  "Explanation": "Answer provides information about the book, but it is not directly related to \'The Chronicles of Narnia\' series."'}},
#  179: {'id': 179,
#   'question': "The book 'The Black Company' by Glen Cook was published in what year?",
#   'answer_llm': 'According to the context, I don\'t have any information about "The Black Company" by Glen Cook. However, I can tell you that "The Black Company" is a fantasy novel series written by Glen Cook, and it\'s set in a medieval-inspired world with a focus on military adventure.\n\nIf you\'d like to know more about the series or get recommendations based on similar books, feel free to ask!',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'does not provide the answer to the question about publication year'}},
#  180: {'id': 180,
#   'question': 'What is the publication year of Shadows Linger?',
#   'answer_llm': 'I don\'t have enough information in the context to determine the publication year of "Shadows Linger". Can you please provide more context or details about this book, such as its title, author, or any other relevant information? I\'ll do my best to help.',
#   'evaluation': {'Relevance': None,
#    'Explanation': '{"Relevance": "NON_RELEVANT", "Explanation": "No direct context provided about the book"}}'}},
#  181: {'id': 181,
#   'question': "What is the position of The White Rose within Glen Cook's series, The Black Company?",
#   'answer_llm': 'I don\'t have information about "The White Rose" being part of Glen Cook\'s series, The Black Company. However, I do know that "The White Rose" is a novel by C.J. Cherryh and it is not part of the Glen Cook\'s series.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': 'The answer does not mention the series at all, let alone its position within it.'}},
#  182: {'id': 182,
#   'question': "Is 'Gardens of the Moon' part of the Malazan Book of the Fallen series?",
#   'answer_llm': "Yes, 'Gardens of the Moon' is part of the Malazan Book of the Fallen series.",
#   'evaluation': {'Relevance': 'RELEVANT',
#    'Explanation': 'Answer directly addresses the question.'}},
#  183: {'id': 183,
#   'question': "What is the series position of the book 'Deadhouse Gates' within the Malazan Book of the Fallen series?",
#   'answer_llm': 'The series position of "Deadhouse Gates" within the Malazan Book of the Fallen series is 5.',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'Answer includes the series position, but does not provide a direct question answer.'}},
#  184: {'id': 184,
#   'question': "What is the publication year of the book 'Memories of Ice'?",
#   'answer_llm': 'The publication year of the book "Memories of Ice" by Ian C. Esswood cannot be confirmed as it was not provided in the context. However, I can tell you that it\'s a novel from the "Malazan Book of the Fallen" series and consists of four books. The other books in the series are \'Gardens of the Moon\', \'Deadhouse Gates\' and \'House of Chains\'.',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'The answer provides the book title, series information, and some other relevant details, but fails to mention the publication year.'}},
#  185: {'id': 185,
#   'question': "What is the total page count of 'House of Chains'?",
#   'answer_llm': 'I don\'t have any information about a book titled "House of Chains" in the provided context. Can you please provide more details or clarify which book this refers to? I\'d be happy to help once I have more information.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': "No information about the book 'House of Chains' was found"}},
#  186: {'id': 186,
#   'question': "What is the publication year of 'Midnight Tides'?",
#   'answer_llm': 'The publication year of "Midnight Tides" is 2004.',
#   'evaluation': {'Relevance': None,
#    'Explanation': '{\n  "Relevance": "NON_RELEVANT",\n  "Explanation": "The question asks for a specific book, but the answer provides only its publication year, without identifying the book title."'}},
#  187: {'id': 187,
#   'question': 'What is the number of pages in the book The Bonehunters?',
#   'answer_llm': 'I\'m not aware of any information about a book titled "The Bonehunters" in our database. Could you please provide more context or details about this book, such as the author or genre? I\'ll do my best to help you find the answer.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': "The answer does not mention the number of pages in 'The Bonehunters' book."}},
#  188: {'id': 188,
#   'question': "Does the book 'Reaper's Gale' by Steven Erikson belong to the Malazan Book of the Fallen series?",
#   'answer_llm': 'The context does not provide information about a book titled "Reaper\'s Gale" or its author. However, it does mention that Steven Erikson is an author and that there are multiple books mentioned in the database with his name as the author.\n\nIf you\'re looking for information on the Malazan Book of the Fallen series by Steven Erikson, I can tell you that the series includes:\n\n1. Gardens of the Moon\n2. Deadhouse Gates\n3. Memories of Ice\n\nThe context does not provide any information about a book titled "Reaper\'s Gale" being part of this series.\n\nIf you have any more questions or would like to know more about other books in the database, feel free to ask!',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': "the answer does not provide information about 'Reaper's Gale'"}},
#  189: {'id': 189,
#   'question': "What is the publication year of the book 'Toll the Hounds'?",
#   'answer_llm': 'The answer to your question can be found in the given context, but there seems to be a missing part of it. However, I can provide an answer based on general information about "Toll the Hound" which is also known as "Toll the Hounds" by Joe Abercrombie.\n\nAccording to general knowledge, the book "The Blade Itself" is sometimes considered as having a companion story called "Toll the Hounds." But for the standalone novel, there seems to be limited information available.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': "The generated answer does not address the specific question about the publication year of 'Toll the Hounds'."}},
#  190: {'id': 190,
#   'question': "What is the publication year of 'Dust of Dreams'?",
#   'answer_llm': 'The publication year of "Dust of Dreams" by Terry Brooks is 2005.',
#   'evaluation': {'Relevance': 'NON_RELEVANT',
#    'Explanation': "The question asks for the publication year of 'Dust of Dreams', but the answer does not provide a specific year, only mentions it was published by Terry Brooks in 2005."}},
#  191: {'id': 191,
#   'question': "What is the publication year of 'The Crippled God'?",
#   'answer_llm': 'The publication year of "The Crippled God" is 2014.',
#   'evaluation': {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'The question is asking for a publication year, but the answer only provides a year from another book in the same series.'}}}

# %%
# Load JSON
with open("evaluations.json", "r", encoding="utf-8") as f:
    eval_data = json.load(f)

# Convert to DataFrame
df_eval = pd.DataFrame(eval_data)

# Flatten the nested "evaluation" dict into separate columns
df_eval["relevance"]   = df_eval["evaluation"].apply(lambda d: d.get("Relevance") if isinstance(d, dict) else None)
df_eval["explanation"] = df_eval["evaluation"].apply(lambda d: d.get("Explanation") if isinstance(d, dict) else None)

# Drop original nested column if you want
df_eval = df_eval.drop(columns=["evaluation"])

# Inspect
print(df_eval.head())
# Out:
#    id                                           question  \
# 0   0     What is the publication year of the book Dune?
# 1   2  What is the page count of the book 'The Left H...
# 2   3  What is the publication year of the book "Foun...
# 3   4  What is the publication year of the book 'The ...
# 4   5  What is the publication year of the book 'A Ga...
#
#                                           answer_llm        relevance  \
# 0  The context does not provide information about...     NON_RELEVANT
# 1  According to the metadata, "The Left Hand of D...         RELEVANT
# 2  The publication year of the book "Foundation" ...             None
# 3  The publication year of "The Hobbit" by J.R.R....  PARTLY_RELEVANT
# 4  The publication year of the book 'A Game of Th...     NON_RELEVANT
#
#                                          explanation
# 0  Does not provide relevant publication year for...
# 1  The answer directly addresses the question abo...
# 2  {\n  "Relevance": "PARTLY_RELEVANT",\n  "Expla...
# 3  the year is correct but the question was not a...
# 4  The generated answer only provides the publica...

# %%
# Distribution of relevance labels
print(df_eval["relevance"].value_counts(normalize=True))

# Look at some non-relevant cases
print(df_eval[df_eval["relevance"] == "NON_RELEVANT"].sample(5))
# Out:
# relevance
# NON_RELEVANT       0.503497
# PARTLY_RELEVANT    0.370629
# RELEVANT           0.125874
# Name: proportion, dtype: float64
#       id                                           question  \
# 44    47  What is the position of this book within its s...
# 32    35  What are the subgenres associated with this book?
# 123  146  What is the page count of 'Parable of the Tale...
# 70    80    What is the page count of the book 'Insurgent'?
# 39    42     What is the title of the book being evaluated?
#
#                                             answer_llm     relevance  \
# 44   I'm ready to help. Please go ahead and provide...  NON_RELEVANT
# 32   I'm ready to help. Please provide the book met...  NON_RELEVANT
# 123  The page count for "Parable of the Talents" by...  NON_RELEVANT
# 70   I couldn't find any information about the page...  NON_RELEVANT
# 39   I'm ready to help. Please go ahead and provide...  NON_RELEVANT
#
#                                            explanation
# 44   Answer requires additional context or metadata...
# 32   The answer is asking for information about the...
# 123  metadata was not provided for the specific boo...
# 70         Lack of specific information about the book
# 39   The response is too general and does not direc...

# %% [markdown]
# Due to using a free and open-source LLM-as-a-judge (llama3.2 here), we find that half of the answers are not relevant to the questions posed by the user.
#
# The judge is also sometimes being too conservative and marking clearly relevant answers as 'PARTLY RELEVANT'.

# %%
df_eval.to_csv('data/evaluations.csv', index=False)

# %% [markdown]
# ## Monitoring

# %% [markdown]
# ## Interface
